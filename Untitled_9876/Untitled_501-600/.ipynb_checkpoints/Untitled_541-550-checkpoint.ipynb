# %%
import os;import math;import sys;import datetime;
var='\\Untitled_541-550.ipynb'
print (var,':',os.path.getsize(os.path.abspath(os.curdir)+var)/math.pow(2, 20),' мегобайт ',datetime.datetime.now())
# Out:
# \Untitled_541-550.ipynb : 0.11582374572753906  мегобайт  2024-10-22 10:23:06.062928

# %% [markdown]
# # Классы Organizationu FoodProductсзакрытыми полями и методами доступа
#
#     public class Organization
#     {
#         private String name;
#         private double revenue;
#         private boolean isForProfit;
#         public String getName() {return name;}
#         public void setName(String name)
#         { if (!name.equals ("")) { this.name = name;}}
#         public double getRevenue() { return revenue;}
#         public void setRevenue (double revenue) {if (revenue >= 0) { this.revenue = revenue; }}
#         public boolean isForProfit () { return isForProfit; }
#         public void setForProfit (boolean isForProfit) { this.isForProfit = isForProfit;}
#     }
# Стр. 543
#
# ---------------

# %% [markdown]
#     public class Main
#     {
#         public static void main(String[] args)
#         {
#             Organization orgl = new Organization();
#             orgl.setName ("Компания XYZ");
#             orgl.setRevenue (1000000.00);
#             orgl.setForProfit (true) ;
#             Organization org2 = new Organization();
#             org2.setName ("Университет XYZ");
#             org2.setRevenue (100000.00);
#             org2.setForProfit (false);
#             System.out.print (orgl.getName());
#             System.out.print(" имеет годовой доход ");
#             System.out.print (orgl.getRevenue());
#             System.out.print(" и ");
#             System.out.print (orgl.isForProfit() ? "": "не ");
#             System.out.println("коммерческая.");
#             System.out.print (org2.getName());
#             System.out.print(" имеет годовой доход ");
#             System.out.print (org2.getRevenue () );
#             System.out.print (" и ");
#             System.out.print (org2.isForProfit() ? "" : "не ");
#             System.out.print1n("коммерческая.");
#         }
#     }

# %% [markdown]
#     public class FoodProduct
#     {
#         private String type;
#         private double weight;
#         private int servings;
#         private int calories;
#         public String getType() { return type;}
#         public void setType(String type)
#         { if (!type.equals("")) { this.type = type; } }
#         public double getWeight () { return weight; }
#         public void setWeight (double weight)
#         { if (weight > 0) { this.weight = weight; } }
#         public int getServings() { return servings; }
#         public void setServings(int servings)
#         { if (servings > 0) { this.servings = servings; } }
#
#         public int getCalories() { return calories;}
#         public void setCalories(int calories) { if (calories >= 0) { this.calories = calories; } }
#     }
# Стр. 544
#
# ----------

# %% [markdown]
#     public class Main
#     {
#         public static void main(String[] args)
#         {
#             FoodProduct product1 = new FoodProduct();
#             product1.setType ("Кусочки персика");
#             product1.setWeight (500);
#             product1.setServings (4);
#             productl.setCalories (70);
#             FoodProduct product2 = new FoodProduct();
#             product2.setType ("Хлеб");
#             product2.setWeight (500);
#             product2.setServings (10);
#             product2.setCalories (150);

# %% [markdown]
#             System.out.print (product1.getType ());
#             System.out.print(" весит ");
#             System.out.print (productl.getWeight () );
#             System.out.print(" грамм, расфасован на ");
#             System.out.print (product1.getServings());
#             System.out.print (" порций и содержит ");
#             System.out.print (productl.getCalories ());
#             System.out.println(" калорий.");
#             System.out.print (product2.getType ());
#             System.out.print (" весит ");
#             System.out.print (product2.getWeight ());
#             System.out.print(" грамм, pасфасован на ");
#             System.out.print (product2.getServings ());
#             System.out.print(" порций и содержит ");
#             System.out.print (product2.getCalories ());
#             System.out.println(" калорий.");
#         }
#     }
# Стр. 545
#
# ------------

# %% [markdown]
# # После щелчка на кнопке в окне отображается сумма налогов, выплачиваемыхорганизацией
#
#     public class Organization
#     {
#         String name;
#         double revenue;
#         boolean isForProfit;
#     }
#     import com.allmycode.dummiesframe. DummiesFrame;

# %% [markdown]
#
#     public class Main
#     {
#         public static void main(String args[])
#         {
#             DummiesFrame frame = new DummiesFrame("Сведения об организации");
#             frame.addRow("Название");
#             frame.addRow ("Годовой доход");
#             frame.addRow("Коммерческая? (Y/N)");
#             frame.setButtonText ("Показать");
#             frame.go();
#         }
#         public static String calculate (String name, double revenue, String isForProfit)
#         {
#             Organization org = new Organization();
#             org. name = name;
#             org.revenue = revenue;
#             double tax;
#             if (isForProfit.equals ("Y")){ tax = revenue * 0.10; }
#             else { tax = revenue * 0.02; }
#             return "Сумма налогов: " + tax;
#         }
#     }
# Cтр. 546
#
# ----------

# %% [markdown]
# # После щелчка на кнопке в окне отображаются цена за 100 грамм, цена за порцию и общее количество калорий в продукте
#     public class FoodProduct
#     {
#         String type;
#         double weight;
#         double cost;
#         int servings;
#         int calories;
#     }

# %% [markdown]
#     import com.allmycode.dummiesframe.DummiesFrame;
#     public class Main
#     {
#         public static void main(String args[])
#         {
#             DummiesFrame frame = new DummiesFrame("Продукт");
#             frame.addRow("Тип"); frame.addRow("Bec");
#             frame.addRow("Цена");
#             frame.addRow("Порций");
#             frame.addRow("Количество калорий в порции");
#             frame.setButtonText ("Показать");
#             frame.go();
#         }

# %% [markdown]
#         public static String calculate(
#             String type, double weight, double cost, int servings, int calories)
#         {
#             FoodProduct product = new FoodProduct();
#             product.type = type;
#             product.weight = weight;
#             product.cost = cost;
#             product.servings = servings;
#             product.calories = calories;
#             return
#                 "Цена за 100 грамм: "
#                 + (cost / (weight / 100)) + "; "
#                 + "Цена за порцию: " + (cost / servings) + "; "
#                 + "Общее количество калорий: " + (calories * servings)
#             ;
#         }
#     }

# %% [markdown]
# # Глава 8
#     Ваш первый класс PlaceToLive
#     public class PlaceToLive
#     {
#         private String address;
#         private int number0fBedrooms;
#         private double area;
#         public String getAddress(){ return address; }
#
#         public void setAddress(String address) { this.address = address; }
#         public int getNumberOfBedrooms() { return numberOfBedrooms; }
#         public void setNumberOfBedrooms(int numberOfBedrooms)
#         { this.numberOfBedrooms = numberOfBedrooms; }
#         public double getArea() { return area; }
#         public void setArea(double area) { this.area = area; }
#     }
# Стр. 547
#
# ---------

# %% [markdown]
#     import java.util.Scanner;
#     public class DisplayThePlaces
#     {
#         public static void main(String[] args)
#         {
#             Scanner keyboard = new Scanner(System.in);
#             PlaceToLive placel = new PlaceToLive();
#             placel.setAddress("ул. Мэйн Стрит, д. 111");
#             placel.setArea (600);
#             placel.setNumberOfBedrooms (2);
#             System.out.print("Цена " + placel.getAddress() + ": ");
#             double cost1 = keyboard.nextDouble();
#             PlaceToLive place2 = new PlaceToLive();
#             place2.setAddress("ул. Джава Роуд, д. 222");
#             place2.setArea (1000);
#             place2.setNumberOfBedrooms (1);
#             System.out.print("Цена " + place2.getAddress() + ": ");
#             double cost2 = keyboard.nextDouble ();
#             System.out.println(placel.getAddress ());
#             System.out.println(" Цена за единицу площади: " + cost1 / placel.getArea());
#             System.out.println(" Цена за спальню: " + cost1 / placel.getNumberOfBedrooms());
#             System. out.println(place2.getAddress ());
#             System.out.println(" Цена за единицу площади: " + cost2 / place2.getArea());
#             System.out.println(" Цена за спальню: " + cost2 / place2.getNumberOfBedrooms());
#             keyboard.close();
#         }
#     }
# Стр. 548
#
# --------

# %% [markdown]
# # Использование класса PlaceToLive вместе с классом Dummies Frame
#     public class PlaceToLive
#     {
#         private String address;
#         private int numberOfBedrooms;
#         private double area;
#         public String getAddress() { return address; }
#         public void setAddress(String address) { this.address = address; }
#         public int getNumberOfBedrooms() { return numberOfBedrooms; }
#         public void setNumberOfBedrooms(int numberOfBedrooms)
#         { this.numberOfBedrooms = numberOfBedrooms;}
#         public double getArea() { return area; }
#         public void setAre (double area) { this.area = area; }
#     }

# %% [markdown]
#     import com.allmycode.dummiesframe.DummiesFrame;
#     public class Main
#     {
#         public static void main(String args[])
#         {
#             DummiesFrame frame = new DummiesFrame("Жилое помещение");
#             frame.addRow ("Адрес");
#             frame.addRow ("Площадь");
#             frame.addRow("Число спален");
#             frame.addRow ("Цена");
#             frame.setButtonText ("Показать");
#             frame.go();
#         }
#
#         public static String calculate(
#             String address,double area, int numberOfBedrooms, double cost)
#         {
#             PlaceToLive place = new PlaceToLive();
#             place.setAddress(address);
#             place. setArea (area);
#             place.setNumberOfBedrooms (numberOfBedrooms);
#             return address + "; "
#                 + "Цена за единицу площади: "
#                 + (cost / place.getArea()) + "; "
#                 + "Цена за спальню: "
#                 + (cost / place.getNumberOfBedrooms())
#             ;
#         }
#     }
# Стр. 549
#
# --------

# %% [markdown]
# # Получение информации для класса PlaceToLive из дискового файла
#     public class PlaceToLive
#     {
#         private String address;
#         private int numberOfBedrooms;
#         private double area;
#         public String getAddress() { return address; }
#         public void setAddress(String address) { this.address = address; }
#         public int getNumberOfBedrooms() { return numberOfBedrooms; }
#         public void setNumberOfBedrooms(int numberOfBedrooms)
#         { this.numberOfBedrooms = numberOfBedrooms; }
#         public double getArea() { return area; }
#         public void setArea(double area) { this.area = area; }
#     }

# %% [markdown]
#     import java.io.File;
#     import java.io.IOException;
#     import java.util.Scanner;
#
#     public class DisplayThePlaces
#     {
#         public static void main(String(] args) throws I0Exception
#         {
#             Scanner diskScanner = new Scanner (new File("places.txt"));
#             Scanner keyboard = new Scanner(System.in);
#             PlaceToLive placel = new PlaceToLive();
#             placel.setAddress (diskScanner.nextLine ());
#             placel.setArea (diskScanner.next Double());
#             placel.setNumberOfBedrooms (diskScanner.nextInt ());
#             System.out.print ("Цена " + placel.getAddress() + ": ");
#             double costl = keyboard.nextDouble();
#             diskScanner.nextLine ();
#             PlaceToLive place2 = new PlaceToLive();
#             place2.setAddress (diskScanner.nextLine ());
#             place2.setArea (diskScanner.next Double());
#             place2.setNumberOfBedrooms(diskScanner.nextInt ());
#             System.out.print("Цена " + place2.getAddress() + ": ");
#             double cost2 = keyboard.nextDouble();
#             System.out.println(placel.getAddress());
#             System.out.printIn(" Цена за единицу площади: " + costl / placel.getArea());
#             System. out.println(" Цена за спальню: " + costl/ placel.getNumberOfBedrooms());
#             System.out.println (place2.getAddress());
#             System.out.println (" Цена за единицу площади: " + cost2 / place2.getArea());
#             System.out.println (" Цена за спальню: " + cost2 / place2.getNumberOfBedrooms());
#             diskScanner.close();
#             keyboard.close ();
#         }
#     }
# Стр. 550
#
# ----------
