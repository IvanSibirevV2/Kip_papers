# %%
import os;import math;import sys;import datetime;
var='\\Untitled.ipynb'
print (var,':',os.path.getsize(os.path.abspath(os.curdir)+var)/math.pow(2, 20),' мегобайт ',datetime.datetime.now())
# Out:
# \Untitled.ipynb : 0.0009527206420898438  мегобайт  2024-06-20 12:00:39.102205

# %% [markdown]
# 2. На боковой панели окна Finder выберите пункт Applications (Приложения). На главной панели окна Finder появится список приложений.
# 3. Дважды щелкните на пункте Utilities (Утилиты). На главной панели появится список утилит.
# 4. В списке утилит найдите пункт Java Preferences (Предпочтения Java). Если его нет, не спешите огорчаться. Это не обязательно означает, что JDK не установлен. В данном случае перейдите к следующему тесту.
# 5. Дважды щелкните на пункте Java Preferences. Если утилита Java Preferences не решила проблему, воспользуйтесь встроенным в Мас командным окном (терминалом) Unix, как описано в следующем разделе.

# %% [markdown]
# # Командный терминал
# Вот как узнать версию JDK с помощью командного терминала.
# 1. В поле поиска Spotlight введите ключевое слово Terminal.
# 2. Когда пункт Terminal появится в списке, выделите его и нажмите клавишу $<Enter>$. Откроется окно Terminal. Обычно в нем приведен простой черный текст на белом фоне.
# 3. Введите приведенную ниже команду и нажмите клавишу $<Enter>$.
# > javac -version
#
# - внимание - В Macintosh окно Terminal по-разному реагирует на регистр букв. Например, чтобы увидеть список пользователей, в командной строке терминала можно ввести w или w. Чтобы увидеть справочную страницу с описанием команды w, можно ввести man w, MAN w или даже mAn w. Hо если ввести man W, то терминал выдаст сообщение о том, что информация о команде не найдена. Аналогично в команде javac version все буквы слова version должны быть в нижнем pe- гистре. Если ввести javac Version, терминал выдаст сообщение о том, что флажка Version не существует. Если терминал сообщит что-то вроде "команда не найдена", значит, на вашем компьютере выполняется версия Мас OS X 10.7.0 или более поздняя.
#
# Стр. 511
#
# --------

# %% [markdown]
# # Что делать, если нужная версия JDK не установлена
# Как обычно, есть несколько способов решения этой проблемы.
#
# - В меню Apple выберите команду Software Update (Обновление программного обеспечения). В открывшемся окне задайте обновление версии JDK.
# - Hа сайте http://developer.apple.com введите в поле поиска ключевое слово "Java". Найдите версию JDK, соответствующую вашей версии Маc OS X.
# - Поищите Java и Мac OS Х на других сайтах. Если повезет, вы найдете пакет JDK сторонних производителей, подходящий для вашей операционной системы. Если вам не очень повезет, вы найдете подходящий пакет JDK, но который тяжело установить и с которым сложно работать. При его установке будьте осторожны. Я нашел подходящие пакеты по указанному ниже адресу, но не устанавливал и не проверял их поэтому ручаться за них не могу:
# http://openjdk.java.net/projects/bsd-port

# %% [markdown]
# # Загрузка и установка Eclipse
# IDE (Integrated Development Environment -- интегрированная среда разработки) - это приложение, которое предоставляет удобные инструменты для создания программного обеспечения. Разрабатывать программы (в том числе на Java) можно и без интегрированной среды, но тогда вы потратите намного больше времени и усилий, чем при ее использовании (некоторые опытные разработчики не согласны с этим, но то, в чем они правы, относится только к очень опытным разработчикам).
# Согласно официальному сайту Eclipse Foundation приложение Eclipse - это "универсальный инструмент разработки, бесплатная расширяемая интегрированная среда создания программного обеспечения на любой платформе вообще и ни на какой в частности". И действительно, среда Eclipse очень гибкая и разнообразная. Многие разработчики считают, что Eclipse особенно удобна для разработки программ на Java, но она не менее удобна и для работы на С++, PHP и многих других языках. Существуют даже варианты Eclipse, вообще не имеющие ничего общего с разработкой программного обеспечения, например веб-браузер Lively, вкладки которого взяты из Eclipse.
#
# Стр. 512

# %% [markdown]
# # Загрузка Eclipse
# Чтобы загрузить Eclipse, выполните следующие действия.
# 1. Откройте сайт http://eclipse.org .
# 2. Найдите вариант Eclipse, предназначенный для вашей операционной системы. После щелчка на кнопке DOWNLOAD (Загрузить) появится раскрывающийся список с тремя наиболее распространенными операционными системами: Windows, Linuxи Mac OS X. Выберите операционную систему, установленную на вашем компьютере.
# 3. Выберите подходящий пакет Eclipse. На данный момент сайт предлагает множество разнообразных пакетов, удовлетворяющих самые широкие интересы разработчиков. Для вас лучше всего подойдет вариант загрузки Eclipse IDE for Java Developers.
# 4. Выберите 32- или 64-разрядную версию. Для большинства пакетов Eclipse возможен выбор между 32- и 64-разряд- ной версиями. Если на компьютере установлена 64-разрядная операционная система, можете выбрать 32- или 64-разрядную версию Eclipse, но лучше 64-разрядную. Если же установлена 32-разрядная операционная система, можно выбрать только 32-разрядную версию Eclipse. Разрядности JDK и Eclipse должны быть одинаковыми: обе 32-разрядные или обе 64-разрядные. Смешивать их нельзя.
# 5. Щелкните на кнопке Download (Загрузить). На странице может быть предложено несколько зеркальных сайтов загрузки. Выберите ближайший к вашему местоположению.
#
# Стр. 513
#
# -----------

# %% [markdown]
# # Установка Eclipse
# Процесс установки Eclipse зависит от операционной системы и типа файла, который вы загрузили.
# - Вы работаете в Windows и загрузили саморазворачивающийся архив .еxe. Дважды щелкните в Проводнике Windows на файле . exe и разверните файл в любой папке. Рекомендуется скопировать содержимое в папку Program Files, в которой находятся остальные программы.
# - Вы работаете в Windows и загрузили файл архива . zip. Извлеките содержимое архива в любую папку. Для этого откройте Проводник Windows, найдите загруженный файл . zip и дважды щелкните на нем. Архив откроется в программе архивации. Перетащите папку eclipse в любое место файловой системы. Как и в предыдущем случае, рекомендуется перетащить ее в папку Program Files. Инсталлятор и системный реестр Windows при установке Eclipse не используются. Развернув содержимое архива в любой папке на жестком диске, можете сразу запустить программу Eclipse. Для этого дважды щелкните на файле eclipse. exe.
# - Вы работаете в Мaс OS X. Если вы загрузили файл . tar.gz, найдите его в папке Downloads и дважды щелкните на нем. Двойной щелчок приведет к извлечению содержимого архива. После этого в папке Downloads должна появиться папка Eclipse. Перетащите ее в папку Applications. Если вы загрузили файл . dmg, ваш браузер должен открыть его. В противном случае найдите файл . dmg в папке Downloads и дважды щелкните на нем. Выполняйте инструкции, выводимые на экране. После этого перетащите папку Eclipse в папку Applications.
# - Вы работаете в Linux. Вы загрузили либо архив . tar. gz, либо саморазворачивающийся архив . bin. Извлеките содержимое архива или дважды щелкните на саморазворачивающемся архиве.

# %% [markdown]
# # Конфигурирование Eclipse
# После установки Eclipse нужно сконфигурировать рабочую среду. Для этого выполните ряд действий.
# 1. Запустите программу Eclipse. При первом запуске на экране появится диалоговое окно Workspace Launcher (Установка рабочего пространства). В этом окне вам будет задан вопрос"В каком месте файловой системы вы хотите сохранять коды, создаваемые с помощью Eclipse?"
# 2. В диалоговом окне Workspace Launcher щелкните на кнопке OK, чтобы подтвердить путь к папке, предложенный по умолчанию. Можете не щелкать на кнопке ОК и задать другой маршрут. Это не играет особой роли, потому что потом его можно будет изменить. При первом запуске Eclipse в конкретном рабочем пространстве откроется диалоговое окно Welcome (Заставка), в котором есть несколько значков и строк текста.
# 3. При наведении указателя на значки появляются подсказки с их именами. Найдите значок Workbench (Рабочее пространство).
# 4. Щелкните на значке Workbench, чтобы открыть главный экран Eclipse. Будет активизирован главный экран Eclipse с заданным рабочим пространством. На панели Package Explorer (Проводник пакетов) откройте папку с примерами данной книги (рис. А.1).
#
# Стр. 514
#
# ------------

# %% [markdown]
#     Примеры Java -  Java - Eclipse
#     F
#
#     Примеры Java - Java - Eclipse
#     File -  Edit - Source - Refactor - Navigate - Search - Project - Run - Window - Help
#     |Package … - Problem is Javades - Dectaration - Console
#     - 03-01 - No consoles to display at this time.
#     - 03-04
#     - 03-05
#     - 03-06
#     - 04-02
#     - 04-03
#     - 04-04
#     - 04-05
#     - 04-06
#     - 04-07
#     - 04-08
#     - 05-01
# Рис. А.1. Интегрированная среда Eclipse
#
# Теперь все готово для экспериментов с готовыми примерами или создания собственного приложения Java. Ещё больше книг по Java в нашем телеграм канале: https: //t.me/javalib
#
# Стр. 515
#
# ------------

# %% [markdown]
# # Приложение Б Использование Eclipse
# В ЭТОМ ПРИЛОЖЕНИИ…
# - Работа с примерами книги
# - Создание собственного проекта
# Работа с примерами книги
# 1. Запустите программу Eclipse.
# 2. Выберите в главном меню команду File- Switch Workspace=> Other (Файл=>Переключить рабочее пространство-Другое). Откроется диалоговое окно Workspace Launcher (Установка рабочего пространства).
# 3. Введите путь к папке рабочего пространства (рис. Б.1). Укажите любой подходящий путь. Если указанной папки не существует, она будет создана.
# 4. Щелкните на кнопке ОК. В данном случае на диске F: \ создается папка ПримерыJava. Она будет использоваться в качестве рабочего пространства Eclipse при работе с примерами книги.
# 5. Загрузите с сайта книги, адрес которого указан во введении, архивный ZIP-файл с примерами книги.

# %% [markdown]
#     Eclipse Launcher Select a directory as workspace
#     Ecipse uses the workspace directory to store its preferences and development artifacts.
#     Workspace:| F:\ПримерыJaval
#     Browse…
#     > Recent Workspaces
#     >Copy Settings
#     Cancel
# Рис. Б.1. Задание пути к папке рабочего пространства
#
# Рис. Б.2. Списокпроектов спримерами

# %% [markdown]
# 6. Выберите команду File-Import-General- Existing Projects into Workspace (Файл->Импорт->Общие->Существующие проекты в рабочее пространство) и щелкните на кнопке Next (Далее).
# 7. Выберите вариант Select archive file (Выбрать архивный файл). Щелкните на кнопке Browse (Обзор), найдите и выделите загруженный архивный файл с примерами.
# 8. Щелкните на кнопке Finish (Готово).На панели Package Explorer (Проводник пакетов) отобразится список проектов, содержащих примеры книги (рис. Б.2). Первое число в обозначении проекта означает номер главы, второе - номер листинга.
# 9. На панели Package Explorer разверните узел 03-01/src/default package и дважды щелкните на исходном файле Displayer.java. Нажмите клавишу $<F5>$, чтобы загрузить проект (если Eclipse попросит подтвердить загрузку).
# 10. Щелкните на кнопке Run (Выполнить), чтобы запустить программуна выполнение.
#
# На панели Console (Консоль) отобразится результат работы программы (рис. Б.3).
# Чтобы поэкспериментировать с примером, измените выводимую строку в исходном коде и еще раз щелкните на кнопке Run. Чтобы загрузить другой проект, закройте все окна исходных кодов текущего проекта и разверните узел другого проекта на панели Package Explorer. Откройте в окне редактора исходные коды другого проекта (они находятся в папке src/default package), внесите нужные изменения в код и щелкните на кнопке Run.
#
# Стр. 518
#
# -------

# %% [markdown]
# ![image.png](attachment:image.png)
#
# Рис. Б.3. Отображение результата работы программы на консоли
#
# Стр. 519
#
# ---------

# %% [markdown]
# Создание собственного проекта
# 1. Запустите Eclipse.
# 2. Закройте окна исходных кодов текущего проекта.
# 3. Выберите в главном меню команду File New Java Project (Файл Создать ->Проект Java).
# 4. В окне New Java Project (Создание проекта Java) введите имя проекта (например, Proj_1) и щелкните на кнопке Finish (Готово), как показано на рис. Б.4.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# На панели Project Explorer появится пустой проект Proj_1. Теперь нужно создать в папке исходных кодов src пакет, а в пакете - класс, содержащий метод main.
#
# Стр. 520
#
# ----------
