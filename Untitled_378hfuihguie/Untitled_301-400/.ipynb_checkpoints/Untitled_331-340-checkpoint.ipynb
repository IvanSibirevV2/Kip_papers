# %%
import os;import math;import sys;import datetime;
var='\\Untitled_331-340.ipynb'
print (var,':',os.path.getsize(os.path.abspath(os.curdir)+var)/math.pow(2, 20),' мегобайт ',datetime.datetime.now())
# Out:
# \Untitled_331-340.ipynb : 14.724990844726562  мегобайт  2025-01-13 11:36:23.953795

# %% [markdown]
# - Типы данных у математического сопроцесcopa 8087
# - (data types, 8087 math coprocessor) 298
#     - команд (instruction types) 78
# - Трассировка команд программы
# - (tracing through programs) 59
# - Указатель команд (instruction pointer) 23
# - Умножение (multiplication)
# - команды (instructions) 99
# - 32-битовых чисел со знаком
# - (signed 32-bit = 32-bit) 140
# - чисел с повышенной точностью
# - (high-precision) 137

# %% [markdown]
# - Упорядочение чисел по возрастанию
# - (arranging numbers in increasing order) 117
# - Усредиение слов в памяти (averaging
# - words in memory) 142 Файл
#     - логический иомер (file handle) 200
#     - типа COM (COM file) 65
# - Файлы
#     - защищенные от записи (files,
#     - write-protecting) 203
#     - текстовые (text files) 170

# %% [markdown]
# - Флаг
#     - знака SF (Sing Flag (SF)) 25
#     - направления DF (Direction Flag (DF)) 25
#         - использование в командах обработки
#         - строк (use in string instructions) 121"
#
#     - нуля ZF (Zero Flag (ZF)) 25
#     - переноса CF (Carry Flag (CF)) 24
#     - переноса вспомогательный AF
#     - (Auxiliary Carry Flag (AF)) 25
#     - переполиения OF (overflow Flag (OF)) 25
#     - прерывания IF (interrupt Enable Flag (IF)) 25
#     - трассировки TF (trap Flag (TF)) 25
#     - четности PF (parity Flag (PF)) 24

# %% [markdown]
# - Формат хранения чисел в памяти
# - (numbers in memory, format of) 91
#     - чисел с плавающей точкой
#     - (floating-point format) 298
# - Функции DOS 189
#     - для обмена данными
#     - (communications functions, DOS) 188
#     - с всинхроиным последовательным
#     - устройством (asynchronous
#     - communications functions, DOS) 190

# %% [markdown]
# - работы с векторами прерываний
# - (vector functions, DOS) 199
# - датами и пременем (data and time
# - functions, DOS) 196
# - дисплеем (display functions, DOS) 195
# - клавиатурой (keyboard functions, DOS) 194
# - справочниками файлов (directory
# - functions, DOS) 200
# - управления файлами
# - (file management functions, DOS) 196
# - расширенного (extended file
# - management functions, DOS) 200
# - Циклы (looping) 118
# - Цифры (digit(s))
#     - двоичные (binary) 10
#     - шестнадцатеричные (hexadecimal) 14
#         - вeca (weights of)

# %% [markdown]
# - Числа
#     - двоично-десятичные (BCD-числа)
#     - (binary-coded decimal (BCD) numbers) 91
#     - вычитание (subtracting) 97
#     - деление (dividing) 101
#     - неупакованные (unpacked) 91
#     - сложение (adding) 93
#     - умножение (multiplying) 100
#     - упакованные (packed BCD numbers) 91
#     - случайные, генерация
#     - (random numbers, generating) 186
#     - со знаком (signed numbers) 13
#     - отрицательные (negative numbers) 30
#         - ввод (entering) 30
#     - шестнадцатеричные (hexadecimal numbers) 15

# %% [markdown]
# - Шина (bus)
#     - адресная (address bus) 21
#     - данных (data bus) 21
# - Экран, стирание (clear the screen) 231
# - ASCII-коды (ASCII) 205
#     - изображаемые (displaying characters) 222
#     - расширенные (extended) 208
# - BIOS
#     - входные точки (entry points) 175
#     - процедуры пользователя
#     - (user-supplied routines) 187
#     - указатели системных таблиц
#     - (data table pointers) 188

# %% [markdown]
# - Типы данных у математического сопроцесcopa 8087
# - (data types, 8087 math coprocessor) 298
#     - команд (instruction types) 78
# - Трассировка команд программы (tracing through programs) 59
# - Указатель команд (instruction pointer) 23
# - Умножение (multiplication) команды (instructions) 99
#     - 32-битовых чисел со знаком (signed
#     - 32-bit 32-bit) 140
#     - чисел с повышенной точностью (high-precision) 137
# - Упорядочение чисел по возрастанию
# - (arranging numbers in increasing order) 117
# - Усреднение слов в памяти
# - (averaging words in memory) 142
# - Файл
#     - логический номер (file handle) 200
#     - типа COM (COM file) 65
# - Файлы
#     - сзащищенные от записи (files,
#     - write-protecting) 203
#     - текстовые (text files) 170

# %% [markdown]
# - Флаг зиака SF (Sing Flng (SF)) 25
# - направления DF (Direction Flag (DF)) 25
# - использование в командах обработки строк
# - (use in string instructions) 121"
# - нуля ZF (Zero Flag (ZF)) 25
# - переноса CF (Carry Flag (CF)) 24
# - переноса вспомогательный AF
# - (Auxiliary Carry Flag (AF)) 25
# - переполиения OF (overflow Flag (OF)) 25
# - прерывания IF (interrupt Enable Flag (IF)) 25
# - трассировки TF (trap Flag (TF)) 25
# - четности PF (parity Flag (PF)) 24

# %% [markdown]
# - Формат хранения чисел в памяти (numbers
# - in memory, format of) 91
#     - чисел с плавающей точкой
#     - (floating-point format) 298
# - Функции DOS 189
#     - для обмена данными
#     - (communications functions, DOS) 188
#     - с всинхроиным последовательным устройством
#     - (asynchronous communications functions, DOS) 190
#     - работы с векторами прерываний
#     - (vector functions, DOS) 199
#     - датами и временем (data
#     - and time functions, DOS) 196
#     - дисплеем (display functions, DOS) 195
#     - клавиатурой (keyboard functions, DOS) 194
#     - справочниками файлов
#     - (directory functions, DOS) 200
#     - управления файлами
#     - (file management functions, DOS) 196
#     - расширенного (extended file
#     - management functions, DOS) 200

# %% [markdown]
# - Циклы (looping) 118
# - Цифры (digit(s))
#     - двоичные (binary) 10
#     - шестиадцатеричные (hexadecimal) 14
#         - веca (weights of)
# - Числа
#     - двоично-десятичные (BCD-числа)
#     - (binary-coded decimal (BCD) numbers) 91
#     - вычитание (subtracting) 97
#     - деление (dividing) 101
#     - неупакованные (unpacked) 91
#     - сложение (adding) 93
#     - умножение (multiplying) 100
#     - упакованные (packed BCD numbers) 91
#     - случайные, генерация
#     - (random numbers, generating) 186
#     - со знаком (signed numbers) 13
#     - отрицательные (negative numbers) 30
#     - ввод (entering) 30
#     - шестнадцатеричные (hexadecimal numbers) 15

# %% [markdown]
# - Шина (bus)
#     - адресная (address bus) 21
#     - данных (data bus) 21
# - Экраи, стирание (clear the screen) 231
# - ASCII-коды (ASCII) 205
#     - изображаемые (displaying characters) 222
#     - расширенные (extended) 208
# - BIOS
#     - входные точки (entry points) 175
#     - процедуры пользователя
#     - (user-supplied routines) 187
#     - указатели системных таблиц
#     - (data table pointers) 188

# %% [markdown]
# # Указатель команд и псевдооператоров
# КОМАНДЫ
# - ΑΑΑ 93
# - AAD 101
# - AAM 100
# - AAS 97
# - ADC 91
# - ADD 91
# - AND 104

# %% [markdown]
# - CALL 110
# - CBW 102
# - CLC 131
# - CLD 132
# - CLI 132
# - CMC 131
# - CMP 98
# - CMPS 124
# - CMPSB 126
# - CMPSW 126
# - CWD 102

# %% [markdown]
# - DAA 93
# - DAS 97
# - DEC 97
# - DIV 101
# - ESC 132
# - HLT 132
# - IDIV 101
# - IMUL 99
# - IN 87
# - INC 94
# - INT 129
# - INTO 130
# - IRET 130
# - JMP 113

# %% [markdown]
# - Jx 115
# - LAHF 88
# - LDS 88
# - LEA 87
# - LES 88
# - LOCK 133
# - LODS 127
# - LODSB 128
# - LODSW 128
# - LOOP 118
# - LOOPE 118
# - LOOPN 118
# - LOOPNZ 118
# - LOOPZ 118

# %% [markdown]
# - MOV 83
# - MOVS 122
# - MOVSB 123
# - MOVSW 123
# - MUL 99
# - NEG 98
# - NOP 133
# - NOT 105
# - OR 104
# - OUT 87
# - POP 84
# - POPF 89
# - PUSH 84
# - PUSHF 89
# - RCL 108
# - RCR 108
# - RET 110
# - ROL 108
# - ROR 108
# - SAHF 88

# %% [markdown]
# - SAL 107
# - SAR 107
# - SBB 95
# - SCAS 126
# - SCASB 127
# - SCASW 127
# - SHL 107
# - SHR 107
# - STC 131
# - STD 132
# - STI 132
# - STOS 128
# - SUB 95
# - TEST 105
# - WAIT 132
# - XCHG 86
# - XLAT 86
# - XOR 104

# %% [markdown]
# # ПСЕВДООПЕРАТОРЫ
# - %OUT 68
# - .CREF 68
# - LALL 253
# - .LFCOND 69
# - .LIST 68
# - .SALL 253
# - .SFCOND 69
# - .XALL 253
# - .XCREF 68
# - .XLIST 68
# - ASSUME 34
# - DB 34
# - DD 34

# %% [markdown]
# - DW 34
# - END 35
# - ENDP 38
# - ENDS 37
# - EQU 33
# - EVEN 64
# - EXITM 252
# - EXTRN 34
# - GROUP 64
# - IF 66
# - IF1 251
# - IFB 251
# - IFDEF 66

# %% [markdown]
# - IFE 66
# - IFIDF 66
# - IFIDN 66
# - IFNB 251
# - IFNDEF 66
# - INCLUDE 34
# - IRP 250
# - IRPC 250
# - LABEL 64
# - LOCAL 247
# - MACRO 246
# - ORG 64
# - PAGE 42
# - PROC 35
# - PUBLIC 34
# - PURGE 257
# - REPT 250
# - SEGMENT 34
# - SHORT
# - SUBTTL 42
# - TITLE 42

# %% [markdown]
# # Оглавление
# - 5 - Предисловие к русскому изданию…
# - 6 - Предисловие. Зачем нужен язык ассемблера? .
# - 10 - Введение. Интенсивный курс систем счисления для ЭВМ.
# - 10 - B.1. Двоичная система счисления.
#     - 11 - Восемь битов образуют байт.
#     - 12 - Сложение двоичных чисел.
#     - 13 - Числа со знаком
# - 14 - B.2. Шестнадцатеричная система счисления.
# - 15 - Применение шестнадцатеричных чисел.
# - 15 - Упражнения.

# %% [markdown]
# - 16 - Глава 1. Введение в программирование на языке ассемблера.
#     - 16 - 1.1. Что такое язык ассемблера?
#     - 16 - 1.2. Происхождение микропроцессора 8088 .
#     - 18 - 1.3. Общие сведения омикропроцессоре 8088 …
#     - 18 - Адресация.
#     - 19 - Возможности программирования.
#     - 20 - Область портов ввода-вывода.
#     - 20 - Распределение памяти.
#     - 20 - Прерывания.
#     - 21 - Адресная шина и шина данных.

# %% [markdown]
# - 21 - 1.4. Внутренние регистры .
# - 21 - Регистры данных…
# - 22 - Регистры сегментов
# - 23 - Регистры указателей и индексов.
# - 23 - Указатель команд …
# - 24 - Флаги
# - 26 - Упражнения .
#
# Стр. 334
#
# ---------

# %% [markdown]
# - Глава 2. Пользование Ассемблером 26
# - 26 - 2.1. Что такое Ассемблер?
# - 27 - 2.2. Разработка программы на языке ассемблера
# - 27 - Редактор…
# - 28 - Ассемблер Загрузчик LINK.
# - 28 - Отладчик DEBUG,
# - 29 - Разработка программы методом "сверху эниз"
# - 30 - 2.3. Операторы исходной программы.
# - 30 - Константы в операторах исходной программы.

# %% [markdown]
# - 30 - 2.4. Команды языка ассемблера .
#     - 31 - Поле метки.
#     - 31 -Поле мнемокода.
#     - 32 -Поле операнда.
#     - 32 -Поле комментариев.
# - 32 - 2.5. Псевдооператоры.
#     - 33 - Псевдооператоры данных
#     - 41 - Псевдооператоры управления листингом…

# %% [markdown]
# - 42 - 2.6. Операции
#     - 42 - Арифметические операции.
#     - 45 - Логические операции
#     - 46 -Операции отношения.
#     - 47 - Операции, возвращающие значения…
#     - 48 - Операции присваивания атрибутов.

# %% [markdown]
# - 49 - 2.7. Ввод, трансляция и исполнение программы.
#     - 50 - Создание рабочего диска Ассемблера.
#     - 50 - Пример программы.
#     - 52 - Ввод программы.
#     - 53 - Трансляция программы.
#     - 54 - Листинг исходной программы.
#     - 56 - Создание исполняемого файла.
#     - 56 - Исполнение программы.
#     - 60 - Другие виды листинга.

# %% [markdown]
# - 61 - 2.8. Модели структуры программы.
# - 63 - 2.9. Дополнительные псевдооператоры
#     - 63 - Псевдооператоры данных.
#     - 65 - Условные псевдооператоры.
#     - 68 - Листинговые псевдооператоры.
# - 69 - 2.10. Обзор ключевых моментов.
#     - 71 - Упражнения.

# %% [markdown]
# - 72 - Глава 3. Система команд микропроцессора 8088.
# - 72 - 3.1. Об этой главе…
# - 72 - 3.2. Режимы адресации.
#     - 74 - Регистровая и непосредственная адресация.
#     - 75 - Режимы адресации памяти
# - 78 - 3.3. Типы команд.
# - 82 - 3.4. Команды пересылки данных
#     - 83 - Команды общего назначения
#     - 87 - Команды ввода-вывода.
#     - 87 - Команды пересылки адреса
#     - 88 - Команды пересылки флагов

# %% [markdown]
# - 89 - 3.5. Арифметические команды.
#     - 90 - Форматы арифметических данных
#     - 91 - Команды сложения.
#     - 95 - Команды вычитания.
#     - 99 - Команды умножения.
#     - 101 - Команды деления.
#     - 102 - Команды расширения знака.
# - 102 -  3.6. Команды манипулирования битами.
# - 102 - Логические команды.
# - 106 - Команды сдвига и циклического сдвига

# %% [markdown]
# - 108 - 3.7. Команды передачи управления.
# - 110 - Команды безусловной передачи управления.
# - 114 - Команды условной передачи управления.
# - 118 - Команды управления циклами.
# - 119 - 3.8. Команды обработки строк.
# - 121 - Префиксы повторения.
# - 122 - Команды пересылки строк. .
#
# Команды сравнения строк. 124
# Команды сканирования страк . . 126
# Команды загрузки и сохранения строки 127

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
