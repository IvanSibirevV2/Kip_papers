# %%
import os;import math;import sys;import datetime;
var='\\JavaДляЧайниковПаровозиковИСамоваров2019.ipynb'
print (var,':',os.path.getsize(os.path.abspath(os.curdir)+var)/math.pow(2, 20),' мегобайт ',datetime.datetime.now())
# Out:
# \JavaДляЧайниковПаровозиковИСамоваров2019.ipynb : 2.116652488708496  мегобайт  2025-02-20 17:38:36.089362

# %% [markdown]
# # Java Для Чайников Паровозиков И Самоваров 2019
# # !!!Книга Вам может не подойти!!!
# ![image.png](attachment:image.png)
# https://otzovik.com/review_8747329.html
# - Кажется что все будет просто, но почему-то это 7 издание е его там 600 страниц
# - Использование новых инструментов и возможностей Java 9
# - Сохдание объектов Java и повторное использование кода
# - Обработка исключений и реагирование на событие
# - Аффтор ЖЖот, так как это Барри Берд.
# - Лучшая книжка для Синьера это книжка по завариванию чайника....
# - Вы держете в руках ремейк, сделанный с целью компактного хранения и запуска программных кодов прямо отсюда.

# %% [markdown]
# - Некоторые картикни будут присутствовать в виде списков.
# - Вы этого всего не видели. Мы этого всего Вам не давали. Файл вообще не существует. 404
# - Если что PDF уже лежало в интернете, не зависимо отовсего
# - Москва 2019
# - Берд, Барри. Java для чайников, 7-e изд. : Пер. с англ. - СПб.: ООО "Диалектика", 2019. - 624 с.: ил.- Парал. тит. англ.
# - Научно-популярное издание. Барри Берд. Java для чайников. 7-е издание.

# %% [markdown]
# # Барри, спасибо за потраченное время!
#
# Почему эта книга может Вам не подойти. Заранее прошу прощения за удаление большинства скриншотов и собственноручные комментарии в тексте, иногда даже неприличные. В 2000 году, чтобы считать себя программистом, было достаточно уметь устанавливать операционную систему, перезагружать принтер и писать на VBA макросы для Ворда. В 2010 году можно было взять книгу и по ней выучить актуальную версию языка. В 2013 году перестали печатать книги по Pascal и Delphi. В 2018 году было невозможно купить приличную книгу по программированию. Многие школьники и студенты уже выпустились, повалялись в придорожной грязи, выяснив, что воровать можно и через подрастающее поколение, пудря им мозги низкооплачиваемой работой (оплата ниже минималки), пока кормят их родители. Таким образом откровенно и бессовестно обворовываются семейные ресурсы через становление детей «профессионалом», которое не происходит, в счет будущих высоких зарплат, которые не случаются в плоть до 40 и 50 лет.

# %% [markdown]
# Тем временем в 2024 году существуют технологии, позволяющие получить приличный, почти средний скил за 2–3 дня. Программировать способны не все, только 30–15% процентов населения Земли. Вопрос не в том, что человек мало старается или отлынивает. Вопрос во врожденной, в том числе и физ-мат, предрасположенности. В результате в профессии оказываются люди средней готовности, на которых откровенно ездят, по причине того что они слишком много вложили и не могут отказаться от почти достигнутой мечты «кормить себя программированием». Люди с повышенной предрасположенностью быстрее проходят этот путь, за месяц, за полгода или год, и просто уходят из профессии до трудоустройства. «Взлетают единицы». Среди моих знакомых таких нет. Но конец у всех один: смена работы или специальности в первые 5 лет или раньше. Все там будем.

# %% [markdown]
# Так вот вопрос. Место и роль книги, предназначенной для новичков «отрицательного уровня программирования». Сколько уйдет у ленивого и непроснувшегося школьника средних классов на прочтение 600 страниц. Какова вероятность успешного «взлета» после книги?
#
# Тем не менее, мне как новичку в JAVA вызывает вялый интерес 400 страница книги и позднее...
# Напомню, JAVA для меня не первый язык... VBA, VBS, Pascal, C++, C#, HTML, CSS, JavaScript, PHP, CMD/BAT, FASM, Python, Julia, BF... ? «Ждем взлета до сих пор...»
#
# Что-нибудь ещё? Как сказал британский фудболист, бегая по фудбольному полю и показывая болельщикам свой отмороженный баклажан.

# %% [markdown]
# # Барри, ты жулик?
#
# Все программные коды приведены в тексте книги. Интерес вызывают 400–500 страницы. На 500 странице книга заканчивается.
# Дальше идет 3–4 приложения. В них программные коды повторяются, все те же, что есть в книге. Закономерный вопрос. Тебе платили за количество страниц?
#
# Тошно читал примеры программных кодов, посвященных долларам на банковском счёте!!! Это единственное, о чём ты думаешь? Других примеров там особо нет...
#
# Вот за что правда спасибо, так это за редкие ссылки на официальную документацию!

# %% [markdown]
# # Оглавление
# - стр. 17 [Введение](#Введение)
# - стр. 25 [Часть первая. Основы Java](#Часть-I.-Основы-Java)
# - стр. 27 [Глава 1. Знакомство с Java](#Глава-1-.-Знакомство-с-Java)
# - стр. 41 [Глава 2. Разработка программного обеспечения](#Глава-2-Разработка-программного-обеспечения)
# - стр. 59 [Глава 3 Базовые компоненты Java](#Глава-3-Базовые-компоненты-Java)
# - стр. 83 [Часть вторая Создание программы на Java](#Часть-вторая-Создание-программы-на-Java)
# - стр. 85 [Глава 4 Переменные и значения](#Глава-4-Переменные-и-значения)
# - стр. 125 [Глава 5 Управляющие инструкции](#Глава-5-Управляющие-инструкции)
# - стр. 159 [Глава 6 Циклы](#Глава-6-Циклы)

# %% [markdown]
# - стр. 179 [Часть 3 Объектно-ориентированное программирование](#Часть-3-Объектно-ориентированное-программирование)
# - стр. 181 - Глава 7 Классы и объекты -
# - стр. 221 - Глава 8. Экономия времени, нервов, слюны и денег. Повторное использование существующего кода -
# - стр. 257 - Глава 9. Конструкторы -

# %% [markdown]
# - стр. 283 - Часть IV. Продвинутые методики программирования -
# - стр. 285 - Глава 10. Размещение переменных и методов в нужных местах -
# - стр. 319 - Глава 11. Использование массивов для хранения значений -
# - стр. 349 - Глава 12. Использование коллекций и потоков -
# - стр. 383 - Глава 13. Как сохранить хорошую мину при плохой игре -
# - стр. 415 - Глава 14. Область видимости переменных -
# - стр. 443 - Глава 15. Ссылочные типы данных -
# - стр. 461 - Глава 16. Реагирование на события клавиатуры и мыши -
# - стр. 481 - Глава 17. Соединение с базой данных -

# %% [markdown]
# - 491 - Часть V. Великолепные десятки -
# - 493 - Глава 18. Десять способов избежать ошибок -
# - 501 - Глава 19. Десять полезных сайтов, посвященных Java -
# - 505 - Часть VI. Приложения -
# - 507 - Приложение А. Установка интегрированной среды разработки -
# - 517 - Приложение Б. Использование Eclipse -
# - 523 - Приложение В. Ответы к упражнениям -
# - 613 - Предметный указатель -

# %% [markdown]
# # Содержание
# - 15 [Об авторе](#Об-авторе)
# - 17 [Введение](#Введение)
# - 17 [Как работать с этой книгой](#Как-работать-с-этой-книгой)
# - 18 [Соглашения, принятые в книге](#Соглашения-принятые-в-книге)
# - 19 [Что можно не читать](#Что-можно-не-читать)
# - 19 [Исходные предположения](#Исходные-предположения)
# - 21 [Структура книги](#Структура-книги)

# %% [markdown]
# - 21 Часть I Основы Java
# - 21 - Часть II. Создание программы на Java
# - 21 - Часть III. Объектно-ориентированное программирование
# - 22 - Часть IV. Продвинутые методики программирования
# - 22 - Часть V. Великолепные десятки
# - 22 - Часть VI. Приложения
# - 22 - Пиктограммы, используемые в книге
# - 23 - Что дальше
# - 24 - Ждем ваших отзывов!

# %% [markdown]
# - стр. 25 [Часть I Основы Java](#Часть-I-Основы-Java)
# - стр. 27 [Глава 1. Знакомство с Java](#Глава-1-Знакомство-с-Java)
# - стр. 28 [Что можно делать с помощью Java](#Что-можно-делать-с-помощью-Java)
# - стр. 29 [Зачем писать программы](#Зачем-писать-программы)
# - стр. 30 [Немного истории](#Немного-истории)
# - стр. 33 [Объектно-ориентированное программирование (ООП)](#Объектно-ориентированное-программирование-(ООП))
# - стр. 33 [Объектно-ориентированные языки](#Объектно-ориентированные-языки)
# - стр. 36 [Объекты и классы](#Объекты-и-классы)
# - стр. 36 [Преимущества объектно-ориентированного подхода](#Преимущества-объектно-ориентированного-подхода)
# - стр. 39 [Наглядное представление классов и объектов](#Наглядное-представление-классов-и-объектов)
# - стр. 40 [Что дальше](#Что-дальше)

# %% [markdown]
# - стр. 41 [Глава 2. Разработка программного обеспечения](#Глава-2-Разработка-программного-обеспечения)
# - стр. 42 [Быстрый старт](#Быстрый-старт)
# - стр. 44 [Что должно быть установлено на компьютере](#Что-должно-быть-установлено-на-компьютере)
# - стр. 46 [Что такое компилятор](#Что-такое-компилятор)
# - стр. 49 [Что такое виртуальная машина Java](#Что-такое-виртуальная-машина-Java)
# - стр. 55 [Процесс разработки](#Процесс-разработки)
# - стр. 56 [Интегрированная среда разработки](#Интегрированная-среда-разработки)

# %% [markdown]
# - стр. 59 [Глава 3. Базовые компоненты Java](#Глава-3-Базовые-компоненты-Java)
# - стр. 60 [Поговорим на языке Java](#Поговорим-на-языке-Java)
# - стр. 60 [Грамматика и общие имена](#Грамматика-и-общие-имена)
# - стр. 62 [Слова в программе на Java](#Слова-в-программе-на-Java)
# - стр. 64 [Ваша первая программа на Java](#Ваша-первая-программа-на-Java)
# - стр. 65 [Как работает ваша первая программа](#Как-работает-ваша-первая-программа)
# - стр. 65 [Классы в Java](#Классы-в-Java)
# - стр. 67 [Методы в Java](#Методы-в-Java)
# - стр. 69 [Метод main](#Метод-main)
# - стр. 70 [Как приказать компьютеру выполнить нужную операцию](#Как-приказать-компьютеру-выполнить-нужную-операцию)
# - стр. 72 [Фигурные скобки](#Фигурные-скобки)
# - стр. 76 [Добавление комментариев в код](#Добавление-комментариев-в-код)
# - стр. 79 [Не будьте слишком строгими к старине Барри](#Не-будьте-слишком-строгими-к-старине-Барри)
# - стр. 80 [Использование комментариев для экспериментирования с кодом](#Использование-комментариев-для-экспериментирования-с-кодом)

# %% [markdown]
# - стр. 83 [Часть II Создание программы на Java](#-Часть-II-Создание-программы-на-Java)
# - стр. 85 [Глава 4 Переменные и значения](#Глава-4-Переменные-и-значения)
# - стр. 85 [Изменение переменной](#Изменение-переменной)
# - стр. 88 [Инструкция присваивания](#Инструкция-присваивания)
# - стр. 88 [Типы переменных](#Типы-переменных)
# - стр. 93 [Отображение текста](#Отображение-текста)
# - стр. 94 [Числа без десятичной точки](#Числа-без-десятичной-точки)
# - стр. 96 [Инициализация при объявлении](#Инициализация-при-объявлении)
# - стр. 97 [Эксперименты с JShell](#Эксперименты-с-JShell)
# - стр. 100 [А как же визуальные эффекты?](#А-как-же-визуальные-эффекты?)

# %% [markdown]
# - стр. 101 [Примитивные типы в Java](#Примитивные-типы-в-Java)
# - стр. 102 [Тип char](#Тип-char)
# - стр. 104 [Тип boolean](#Тип-boolean)
# - стр. 106 [Ссылочные типы](#Ссылочные-типы)
# - стр. 110 [Объявление импорта](#Объявление-импорта)
# - стр. 112 [Создание новых значений с помощью операторов](#Создание-новых-значений-с-помощью-операторов)
# - стр. 116 [Инициализация может быть только однократной, присваивание - многократным](#Инициализация-может-быть-только-однократной-присваивание-многократным)
# - стр. 117 Операторы инкремента и декремента
# - стр. 122 [Операторы присваивания](#Операторы-присваивания)

# %% [markdown]
# - стр. 125 [Глава 5. Управляющие инструкции](#Глава-5-Управляющие-инструкции)
# - стр. 126 [Принятие решений с помощью инструкции if](#Принятие-решений-с-помощью-инструкции-if)
# - стр. 126 [Угадайте число](#Угадайте-число)
# - стр. 127 [Ввод текста с клавиатуры](#Ввод-текста-с-клавиатуры)
# - стр. 130 [Генерация случайных чисел](#Генерация-случайных-чисел)
#
# Стр. 7
#
# -----------------------

# %% [markdown]
# - стр. 132 [Инструкция if](#Инструкция-if)
# - стр. 133 [Двойной знак равенства](#Двойной-знак-равенства)
# - стр. 133 [Блоки инструкций](#Блоки-инструкций)
# - стр. 134 [Отступы в инструкции if](#Отступы-в-инструкции-if)
# - стр. 135 [Сломанная вилка if без else](#Сломанная-вилка-if-без-else)
# - стр. 137 [Использование блоков инструкций в JShell ](#Использование-блоков-инструкций-в-JShell)
# - стр. 138 [Условия с операторами сравнения и логическими операторами](#Условия-с-операторами-сравнения-и-логическими-операторами)
# - стр. 138 [Сравнение чисел и символов](#Сравнение-чисел-и-символов)
# - стр. 139 [Сравнение объектов](#Сравнение-объектов)

# %% [markdown]
# - стр. 142 [Импортируем все за один раз](#Импортируем-все-за-один-раз)
# - стр. 143 [Логические операторы](#Логические-операторы)
# - стр. 146 [Да здравствуют нули](#Да-здравствуют-нули)
# - стр. 147 [Условия в скобках и скобки в условиях](#Условия-в-скобках-и-скобки-в-условиях)
# - стр. 150 [Вложение инструкций if](#Вложение-инструкций-if)
# - стр. 152 [Переключатель switch](#Переключатель-switch)
# - стр. 152 [Выбор варианта](#Выбор-варианта)
# - стр. 155 [Не забывайте вставлять break](#Не-забывайте-вставлять-break)
# - стр. 157 [Строковые аргументы](#Строковые-аргументы)

# %% [markdown]
# - стр. 159 [Глава 6 Циклы](#Глава-6-Циклы)
# - стр. 160 [Цикл while](#Цикл-while)
# - стр. 164 [Цикл for](#Цикл-for)
# - стр. 166 [Анатомия цикла for](#Анатомия-цикла-for)
# - стр. 168 [Премьера моего хита Эл под дождем](#Премьера-моего-хита-Эл-под-дождем)
# - стр. 171 [Цикл do](#Цикл-do)
# - стр. 174 [Чтение одиночного символа с клавиатуры](#Чтение-одиночного-символа-с-клавиатуры)
# - стр. 175 [Работа с файлами](#Работа-с-файлами)
# - стр. 176 [Объявление переменной в блоке](#Объявление-переменной-в-блоке)

# %% [markdown]
# - стр. 179 [Часть 3 Объектно ориентированное программирование](#Часть-3-Объектно-ориентированное-программирование)
# - стр. 181 [Глава 7 Классы и объекты](#Глава-7-Классы-и-объекты)
# - стр. 182 [Определение класса](#Определение-класса)
# - стр. 184 [Объявление переменных и создание объектов](#Объявление-переменных-и-создание-объектов)
# - стр. 187 [Инициализация переменной](#Инициализация-переменной)
# - стр. 188 [Использование полей объектов](#Использование-полей-объектов)
# - стр. 188 [Одна программа несколько классов](#Одна-программа-несколько-классов)
# - стр. 189 [Открытые классы](#Открытые-классы)
# - стр. 190 [Определение метода в классе](#Определение-метода-в-классе)
# - стр. 192 [Счет отображающий сам себя](#Счет-отображающий-сам-себя)
# - стр. 193 [Заголовок метода](#Заголовок-метода)
#
# Стр. 8
#
# -----------------------

# %% [markdown]
# - стр. 194 [Передача параметров методу и получениезначения возвращаемого методом](#Передача-параметров-методу-и-получение-значения-возвращаемого-методом)
# - стр. 196 [Передача значения методу](#Передача-значения-методу)
# - стр. 198 [Значение возвращаемое методом](#Значение-возвращаемое-методом)
# - стр. 201 [Что необходимо сделать чтобы числа выглядели красиво](#Что-необходимо-сделать-чтобы-числа-выглядели-красиво)
# - стр. 206 [Сокрытие деталей с помощью методов доступа](#Сокрытие-деталей-с-помощью-методов-доступа)
# - стр. 206 [Хороший стиль программирования](#Хороший-стиль-программирования)
# - стр. 210 [Публичная жизнь и личные мечты как сделать поле недоступным](#Публичная-жизнь-и-личные-мечты-как-сделать-поле-недоступным)
# - стр. 212 [Проверка соблюдения ограничений с помощью методов доступа](#Проверка-соблюдения-ограничений-с-помощью-методов-доступа)
# - стр. 213 [Собственный GUI-класс Барри](#Собственный-GUI-класс-Барри)

# %% [markdown]
# - стр. 221 [Глава 8 Экономия времени и денег повторное использование существующего кода
# ](#Глава-8-Экономия-времени-и-денег-повторное-использование-существующего-кода)
# - стр. 222 [Определение класса](#Определение-класса)
# - стр. 223 [Что означает быть служащим](#Что-означает-быть-служащим)
# - стр. 224 [Использование класса Employee](#Использование-класса-Employee)
# - стр. 228 [Создание платежного чека](#Создание-платежного-чека)
# - стр. 229 [Работа с файлами небольшое отступление](#Работа-с-файлами-небольшое-отступление)
# - стр. 230 [Хранение данных в файле](#Хранение-данных-в-файле)
# - стр. 231 [Копирование и вставка кода](#Копирование-и-вставка-кода)
# - стр. 232 [Чтение данных из файла](#Чтение-данных-из-файла)
# - стр. 235 [Куда подевался мой файл](#Куда-подевался-мой-файл)

# %% [markdown]
# - стр. 236 [Добавление имен папок к именам файлов](#Добавление-имен-папок-к-именам-файлов)
# - стр. 237 [Построчное чтение данных](#Построчное-чтение-данных)
# - стр. 239 [Закрытие соединения с дисковым файлом](#Закрытие-соединения-с-дисковым-файлом)
# - стр. 239 [Определение подклассов](#Определение-подклассов)
# - стр. 242 [Создание подкласса](#Создание-подкласса)
# - стр. 244 [Это входит в привычку](#Это-входит-в-привычку)
# - стр. 245 [Использование подклассов](#Использование-подклассов)
# - стр. 247 [Обеспечение соответствия типов](#Обеспечение-соответствия-типов)
# - стр. 248 [Вторая половина истории](#Вторая-половина-истории)
# - стр. 249 [Переопределение существующих методов](#Переопределение-существующих-методов)
# - стр. 252 [Аннотации Java](#Аннотации-Java)
# - стр. 252 [Вызов методов базовых и производных классов
# ](#Вызов-методов-базовых-и-производных-классов)

# %% [markdown]
# - стр. 257 [Глава 9 Конструкторы](#Глава-9-Конструкторы)
# - стр. 257 [Определение конструктора](#Определение-конструктора)
# - стр. 258 [Что такое температура](#Что-такое-температура)
# - стр. 258 [Что такое температурная шкала](#Что-такое-температурная-шкала)
# - стр. 260 [Так что же такое температура](#Так-что-же-такое-температура)
# - стр. 262 [Что можно сделать с температурой](#Что-можно-сделать-с-температурой)
# - стр. 264 [Поиск нужного конструктора](#Поиск-нужного-конструктора)
# - стр. 266 [Некоторые вещи никогда не меняются](#Некоторые-вещи-никогда-не-меняются)
#
# Стр. 9
#
# -----------

# %% [markdown]
# - стр. 269 [Конструктор базового класса в производном классе](#Конструктор-базового-класса-в-производном-классе)
# - стр. 269 [Усовершенствованный класс Temperature](#Усовершенствованный-класс-Temperature)
# - стр. 271 [Конструкторы подклассов](#Конструкторы-подклассов)
# - стр. 272 [Использование усовершенствованного класса TemperatureNice](#Использование-усовершенствованного-класса-TemperatureNice)
# - стр. 273 [Конструктор выполняемый по умолчанию](#Конструктор-выполняемый-по-умолчанию)
# - стр. 276 [Конструктор может не только заполнять поля](#Конструктор-может-не-только-заполнять-поля)
# - стр. 279 [Классы и методы из Java API](#Классы-и-методы-из-Java-API)
# - стр. 280 [Аннотация SuppressWarnings](#Аннотация-SuppressWarnings)

# %% [markdown]
# - стр. 283 [Часть 4 Продвинутые методики программирования](#Часть-4-Продвинутые-методикипрограммирования)
# - стр. 285 [Глава 10. Размещение переменных и методов в нужных местах](#Глава-10-Размещение-переменных-и-методов-в-нужных-местах)
# - стр. 285 [Определение класса](#Определение-класса)
# - стр. 287 [Еще один способ красивого вывода чисел](#Еще-один-способ-красивого-вывода-чисел)
# - стр. 287 [Использование класса Player](#Использование-класса-Player)
# - стр. 290 [Считаем до девяти](#Считаем-до-девяти)
# - стр. 291 [Графический интерфейс пользователя](#Графический-интерфейс-пользователя)
# - стр. 293 [Переброска исключения из одного метода в другой](#Переброска-исключения-из-одного-метода-в-другой)
# - стр. 294 [Статические поля и методы](#Статические-поля-и-методы)
# - стр. 296 [Зачем столько статики](#Зачем-столько-статики)
# - стр. 297 [Статическая инициализация](#Статическая-инициализация)

# %% [markdown]
# - стр. 298 [Отображение общей статистики команды](#Отображение-общей-статистики-команды)
# - стр. 300 [Статический импорт](#Статический-импорт)
# - стр. 301 [Осторожно статика](#Осторожно-статика)
# - стр. 304 [Поэкспериментируем с переменными](#Поэкспериментируем-с-переменными)
# - стр. 304 [Переменная на своем месте](#Переменная-на-своем-месте)
# - стр. 307 [Переменные в разных местах](#Переменные-в-разных-местах)
# - стр. 312 [Передача параметров](#Передача-параметров)
# - стр. 312 [Передача по значению](#Передача-по-значению)
# - стр. 314 [Возвращение результата](#Возвращение-результата)
# - стр. 315 [Передача по ссылке](#Передача-по-ссылке)
# - стр. 316 [Возвращение объекта из метода](#Возвращение-объекта-из-метода)
#
# - стр. 318 Эпилог

# %% [markdown]
# - стр. 319 [Глава 11. Использование массивов для хранения значений](#Глава-11-Использование-массивов-для-хранения-значений)
# - стр. 319 [По порядку рассчитайсь](#По-порядку-рассчитайсь)
# - стр. 322 [Создание массива в два этапа](#Создание-массива-в-два-этапа)
# - стр. 323 [Сохранение значений](#Сохранение-значений)
# - стр. 325 [Табуляции и другие специальные символы](#Табуляции-и-другие-специальные-символы)
# - стр. 326 [Инициализация массива](#Инициализация-массива)
# - стр. 327 [Расширенный цикл for](#Расширенный-цикл-for)
# - стр. 329 [Поиск в массиве](#Поиск-в-массиве)
#
# Стр. 10
#
# --------------------------------

# %% [markdown]
# - стр. 331 [Запись в файл](#Запись-в-файл)
# - стр. 332 [Закрытие файла](#Закрытие-файла)
# - стр. 334 [Массивы объектов](#Массивы-объектов)
# - стр. 336 [Использование класса Room](#Использование-класса-Room)
# - стр. 339 [Еще один способ форматирования чисел](#Еще-один-способ-форматирования-чисел)
# - стр. 340 [Тернарный условный оператор](#Тернарный-условный-оператор)
# - стр. 342 [Аргументы командной строки](#Аргументы-командной-строки)
# - стр. 344 [Использование аргументов командной строки в коде](#Использование-аргументов-командной-строки-в-коде)
# - стр. 346 [Проверка количества аргументов командной строки](#Проверка-количества-аргументов-командной-строки)

# %% [markdown]
# - стр. 349 [Глава 12 Использование коллекций и потоков](#Глава-12-Использование-коллекций-и-потоков)
# - стр. 349 [Ограничения массивов](#Ограничения-массивов)
# - стр. 351 [Классы коллекций](#Классы-коллекций)
# - стр. 351 [Класс ArrayList](#Класс-ArrayList)
# - стр. 354 [Использование обобщенных типов](#Использование-обобщенных-типов)
# - стр. 356 [Классы оболочки](#Классы-оболочки)
# - стр. 359 [Проверка наличия данных для чтения](#Проверка-наличия-данных-для-чтения)
# - стр. 359 [Использование итераторов](#Использованиеитераторов)

# %% [markdown]
# - стр. 361 [Другие классы коллекций Java](#Другие-классы-коллекций-Java)
# - стр. 363 [Функциональное программирование](#Функциональное-программирование)
# - стр. 365 [Решение задач программирования старым способом](#Решение-задач-программирования-старым-способом)
# - стр. 368 [Потоки](#Потоки)
# - стр. 369 [Лямбда-выражения](#Лямбда-выражения)
# - стр. 372 [Таксономия лямбда выражений](#Таксономия-лямбда-выражений)
# - стр. 372 [Использование потоков и лямбда-выражений](#Использование-потоков-и-лямбда-выражений)
# - стр. 378 [К чему все эти холопы хлопоты](#К-чему-все-эти-холопы-хлопоты)
# - стр. 381 Ссылки на методы

# %% [markdown]
# - стр. 383 [Глава 13 Как сохранить хорошую мину при плохой игре](#Глава-13-Как-сохранить-хорошую-мину-при-плохой-игре)
# - стр. 385 [Обработка исключений](#Обработка-исключений)
# - стр. 389 [Параметр блока catch](#Параметр-блока-catch)
# - стр. 390 [Типы исключений](#Типы-исключений)
# - стр. 392 [Кто должен перехватить исключение](#Кто-должен-перехватить-исключение)
# - стр. 399 [Блок catch с несколькими типами исключений](#Блок-catch-с-несколькими-типами-исключений)
# - стр. 400 [Не будем чрезмерно осторожничать](#Не-будем-чрезмерно-осторожничать)
# - стр. 400 [Восстановление работы программы после генерирования исключения](#Восстановление-работы-программы-после-генерирования-исключения)
# - стр. 401 [Наши друзья хорошие исключения](#Наши-друзья-хорошие-исключения)
# - стр. 403 [Обработайте исключение или передайте его дальше](#Обработайте-исключение-или-передайте-его-дальше)
# - стр. 410 [Блок finally](#Блок-finally)
# - стр. 412 [Использование инструкции try при работе с ресурсами](#-Использование-инструкции-try-при-работе-с-ресурсами)
#
#
# Стр. 11
#
# -----------------

# %% [markdown]
# - стр. 415 [Глава 14 Область видимости переменных](#Глава-14-Область-видимости-переменных)
# - стр. 416 [Модификаторы доступа к членам классов](#Модификаторы-доступа-к-членам-классов)
# - стр. 417 [Классы виды доступа и деление программ на части](#Классы-виды-доступа-и-деление-программ-на-части)
# - стр. 417 [Классы и члены классов](#Классы-и-члены-классов)
# - стр. 418 [Правила доступа к членам класса](#Правила-доступа-к-членам-класса)
# - стр. 421 [Помещение рисунка во фрейм](#Помещение-рисунка-во-фрейм)
# - стр. 424 [Структура папок](#Структура-папок)
# - стр. 425 [Создание фрейма](#Создание-фрейма)
# - стр. 427 [Как изменить программу не изменяя классы](#Как-изменить-программу-не-изменяя-классы)

# %% [markdown]
# - стр. 428 [Доступ применяемый по умолчанию](#Доступ-применяемый-по-умолчанию)
# - стр. 431 [Как проникнуть в пакет](#Как-проникнуть-в-пакет)
# - стр. 433 [Защищенный доступ](#Защищенныйдоступ)
# - стр. 433 [Подклассы находящиеся в разных пакетах](#Подклассы-находящиеся-в-разных-пакетах)
# - стр. 435 [Включение непроизводного класса в тот же пакет](#Включение-непроизводного-класса-в-тот-же-пакет)
# - стр. 439 [Модификаторы доступа к классам](#Модификаторы-доступа-к-классам)
# - стр. 439 [Открытые классы](#Открытые-классы)
# - стр. 440 [Классы не являющиеся открытыми](#Классы-не-являющиеся-открытыми)

# %% [markdown]
# - стр. 442 [Глава 15 Ссылочные типы данных](#Глава-15-Ссылочные-типы-данных)
# - стр. 443 [Типы данных Java](#Типы-данных-Java)
# - стр. 443 [Интерфейсы в Java](#Интерфейсы-в-Java)
# - стр. 444 [Два интерфейса](#Два-интерфейса)
# - стр. 445 [Реализация интерфейсов](#Реализация-интерфейсов)
# - стр. 447 [Объединяем все вместе](#Объединяем-все-вместе)
# - стр. 449 [Абстрактные классы](#Абстрактные-классы)
# - стр. 451 [ДВЕ РАЗНОВИДНОСТИ МЕТОДОВ](#ДВЕ-РАЗНОВИДНОСТИ-МЕТОДОВ)
# - стр. 454 [Уход за домашним любимцем](#Уход-за-домашним-любимцем)
# - стр. 456 [Использование всех ранее созданных классов](#Использование-всех-ранее-созданных-классов)
# - стр. 458  [Расслабьтесь это не галлюцинация](#Расслабьтесь-это-не-галлюцинация)

# %% [markdown]
# - стр. 461 [Глава 16. Реагирование на события клавиатуры и мыши](#Глава-16-Реагирование-на-события-клавиатуры-и-мыши)
# - стр. 462 [Реагирование на щелчок мышью](#Реагирование-на-щелчок-мышью)
# - стр. 464 [События и их обработка](#События-и-их-обработка)
# - стр. 465 [Потоки выполнения](#Потоки-выполнения)
# - стр. 467 [Ключевое слово this](#Ключевое-слово-this)
# - стр. 468 [Тело метода actionPerformed](#Тело-метода-actionPerformed)
# - стр. 469 [Идентификатор версии](#Идентификатор-версии)
# - стр. 471 [Реагирование на другие события](#Реагирование-на-другие-события)
# - стр. 477 [Внутренние классы](#Внутренние-классы)
#
# Стр. 12
#
# ----------

# %% [markdown]
# - стр. 481 [Глава 17 Соединение с базой данных](#Глава-17-Соединение-с-базой-данных)
# - стр. 482 [Создание базы данных](#Создание-базы-данных)
# - стр. 483 [Что происходит при выполнении кода](#Что-происходит-при-выполнении-кода)
# - стр. 484 [Использование команд SQL](#Использование-команд-SQL)
# - стр. 485 [Подключение и отключение базы данных](#Подключение-и-отключение-базы-данных)
# - стр. 486 [Добавление данных в таблицу](#Добавление-данных-в-таблицу)
# - стр. 487 [Извлечение данных](#Извлечение-данных)
# - стр. 489 [Удаление данных](#Удаление-данных)

# %% [markdown]
# - стр. 491 [Часть 5 Великолепные десятки](#Часть-5-Великолепные-десятки)
# - стр. 493 [Глава 18 Десять способов избежать ошибок](#Глава-18-Десять-способов-избежать-ошибок)
# - стр. 493 [Правильное использование регистра букв](#Правильное-использование-регистра-букв)
# - стр. 494 [Проход через блок switch](#Проход-через-блок-switch)
# - стр. 495 [Сравнение двух значений](#Сравнение-двух-значений)
# - стр. 495 [Добавление элемента в графический интерфейс](#Добавление-элемента-в-графический-интерфейс)
# - стр. 496 [Добавление слушателей событий](#Добавление-слушателей-событий)
# - стр. 496 [Определение обязательных конструкторов](#Определение-обязательных-конструкторов)
# - стр. 496 [Исправление нестатических ссылок](#Исправление-нестатических-ссылок)
# - стр. [497 Соблюдение границ массива](#Соблюдение-границ-массива)
# - стр. 497 [Указатели на null](#Указатели-на-null)
# - стр. 498 [Помогите виртуальной машине Java найти классы](#Помогите-виртуальной-машине-Java-найти-классы)

# %% [markdown]
# - стр. 501 [Глава 19 Десять полезных сайтов, посвященных Java](#Глава-19-Десять-полезных-сайтов-посвященных-Java)
# - стр. 501 [Веб-сайт данной книги](#Веб-сайт-данной-книги)
# - стр. 502 [Сайты Oracle](#Сайты-Oracle)
# - стр. 502 [Ответы на технические вопросы](#Ответы-на-технические-вопросы)

# %% [markdown]
# - стр. 505 - Часть VI. Приложения
# - стр. 507 - Приложение А. Установка интегрированной среды разработки
# - стр. 507 - Загрузка и установка JDK
# - стр. 508 - Java на платформе Windows, Linux и Solaris
# - стр. 510 - Java для Macintosh
# - стр. 512 - Загрузка и установка Eclipse
# - стр. 513 - Загрузка Eclipse
# - стр. 513 - Установка Eclipse
# - стр. 514 - Конфигурирование Eclipse
# - стр. 517 - Приложение Б. Использование Eclipse
# - стр. 517 - Работа с примерами книги
# - стр. 520 - Создание собственного проекта
#
# Стр. 13
#
# -----------

# %% [markdown]
# - стр. 523 - Приложение В. Ответы к упражнениям
# - стр. 523 - Глава 3
# - стр. 524 - Глава 4
# - стр. 528 - Глава 5
# - стр. 533 - Глава б
# - стр. 537 - Глава 7
# - стр. 547 - Глава 8
# - стр. 557 - Глава 9

# %% [markdown]
# - стр. 567 - Глава 10
# - стр. 574 - Глава 11
# - стр. 581 - Глава 12
# - стр. 584 - Глава 13
# - стр. 590 - Глава 14
# - стр. 599 - Глава 15
# - стр. 604 - Глава 16
# - стр. 609 - Глава 17
# - стр. 613 - Предметный указатель
#
# Стр. 14
#
# --------------

# %% [markdown]
# ----------------

# %% [markdown]
# ------------------

# %% [markdown]
# ---------------

# %% [markdown]
# --------------

# %% [markdown]
# ---------------

# %% [markdown]
# --------------

# %% [markdown]
# ------------

# %% [markdown]
# ----------------
