# %%
import os;import math;import sys;import datetime;
var='\\Untitled.ipynb'
print (var,':',os.path.getsize(os.path.abspath(os.curdir)+var)/math.pow(2, 20),' мегобайт ',datetime.datetime.now())
#http://localhost:8888/notebooks/Untitled1.ipynb
#print("http://localhost:8888/notebooks/Untitled1.ipynb")

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# public System.Delegate Get_Delegate() => this.Get_Assembly().CreateInstance(this.p_ClassName)
#     .Get(_dynamicObject => _dynamicObject
#         .SetIf(_fBool: a => a == null, _f1: a => throw new System.TypeLoadException(this.p_ClassName))
#         .GetType().GetMethod(this.p_MetodName)
#         .SetIf(_fBool: a => a == null, _f1: a => throw new System.TypeLoadException(this.p_MetodName))
#         .Get(_dynamicMethod =>
#             System. Delegate. CreateDelegate(
#                 System.Linq. Expressions. Expression. GetDelegateType(
#                     _dynamicMethod.GetParameters()
#                         .Select(p => p.ParameterType)
#                             Concat(new[] { _dynamicMethod.ReturnType })
#                             .ToArray()
#                 )
#                 , _dynamicObject
#                 , dynamicMethod
#             )
#         )
#     )
