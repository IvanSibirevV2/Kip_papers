# %%
import os;import math;import sys;import datetime;
var='\\Untitled.ipynb'
print (var,':',os.path.getsize(os.path.abspath(os.curdir)+var)/math.pow(2, 20),' мегобайт ',datetime.datetime.now())
#http://localhost:8888/notebooks/Untitled1.ipynb
#print("http://localhost:8888/notebooks/Untitled1.ipynb")

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - 01_System
#     - Diagnostics
# a C# Const.cs
# a
# T Ext Stopwatch.cs
# a c# StackTracer.cs
# a c# TestLast.cs
# VirtualConsole
# a C Ext Get ReadLine.cs
# a c# GUIVC.cs a VirtualConsole.cs
# a Ext_Cast_T.cs
# a c# Ext List_T.cs
# Da c Get T.cs
# a c# Getlf_T.cs
# a C INewEable.cs
# a Set T.cs
# a c# Setlf T.cs
