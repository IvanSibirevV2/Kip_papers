# %% [markdown]
# # [2015]_МихненкоПА_МатМодПроцРазвУпрИзмXозОрг

# %% [markdown]
# # Математическое моделирование процессов развития и управления изменениями хозяйственных организаций
#
# П. А. Михненко Математическое моделирование процессов развития и управления изменениями хозяйственных организаций ИЗДАТЕЛЬСКИЙ ДОМ Университет СИНЕРГИЯ Московский финансово-промышленный университет «Синергия» Факультет Экономики и управления.
# # Москва 2015
#
# Стр. 1
#
# --------------------

# %% [markdown]
# Рецензенты: профессор кафедры. «Экономика и организация производства» научно-учебного комплекса «Инженерный бизнес и менеджмент» МГТУ им. Н. Э. Баумана, доктор технических наук, доктор экономических наук, профессор А. И. Орлов, профессор ФГБОУ ВПО «Государственный университет управления», доктор экономических наук Л. В. Райченко
#
# Михненко П. А. Математическое моделирование процессов развития и управления изменениями хозяйственных организаций  П. А. Михненко. - М.: Московский финансово-промышленный университет «Синергия», 2015. - 214 c.

# %% [markdown]
# Монография посвящена проблемам математического моделирования процессов организационного развития и управления организационными изменениями хозяйственных организаций. Исследуются теоретические и методологические основы моделирования процессов организационного развития. Предлагается динамическая модель организационного развития, учитывающая особенности интеграции и взаимодействия подразделений в процессе организационных изменений. Обосновывается подход к оптимизации процесса адаптации организации к изменениям внешней среды. Анализируются особенности и перспективы динамического моделирования процессов организационного развития в классе систем со случайной скачкообразной структурой, а также применения в исследованиях методов нечеткой математики и нечеткого моделирования.
#
# Для научных сотрудников, преподавателей и аспирантов в сфере теории организации, общего и стратегического менеджмента и математического моделирования организационных систем и процессов. Может быть полезной студентам, обучающимся по направлению «Менеджмент».
#
# Михненко П. А., 2015 Московский финансово-промышленный университет «Синергия», 2015
#
# Стр. 2
#
# --------------------

# %% [markdown]
# # Содержание
#
# - 5 - Введенис
#     - _
# - 9 - __Глава 1__. Теоретические и методологические основы моделирования процессов организационного развития.
# - 9 - 1.1. Анализ современного состояния теории организационного развития и организационных изменений.
# - 25 - 1.2. Теория систем и системный анализ в исследовании организаций.
# - 37 - 1.3. Анализ современного состояния теории и методологии моделирования процессов организационного развития и организационных изменений.
#     - _
# - 57 - __Глава 2__. Методология математического моделирования процессов организационного развития.
# - 57 - 2.1. Феноменологическая модель организационного развития.
# - 66 - 2.2. Интеграция и взаимодействие в процессе организационных изменений .
# - 76 - 2.3. Динамическая математическая модель организационного развития.
#     - _
# - 95 - __Глава 3__. Оптимизация процесса адаптации организации к изменениям внешней среды.
# - 95 - 3.1. Постановка задачи оптимизации интенсивности организационных изменений.
# - 98 - 3.2. Одномерная модель процесса адаптации организации к изменениям внешней среды..
# - 106 - 3.3. Учет ограничений, налагаемых на управляемость организационной системы.
# - 107 - 3.4. Анализ зон адаптации.
# - 111 - 3.5. Многомерная модель процесса алаптации организации к изменениям внешней среды.
#
# Стр. 3
#
# --------------------

# %% [markdown]
# - 114 - __Глава 4__ Динамическое моделирование процессов организационного развития в классе систем со случайной скачкообразной структурой .
# - 114 -  4.1. Основные понятия и определения теории систем со случайной скачкообразной структурой
# - 121 - 4.2. Принципы математического моделирования процессов организационного развития и классе систем со случайной скачкообразной структурой ...
# %% [markdown]
# Применение методов теории систем и системного анализа к исследованию организаций заставляет прибегать к иным определениям, например, организация — свойство систем обнаруживать взаимосвязанное поведение ее частей в рамках целого. Организация системы проявляется прежде всего в ограничении разнообразия поведения ее частей и является инвариантным свойством системы. Разные наблюдатели в зависимости от целей и средств исследования могут обнаруживать в системе различные организации (Волкова и др., 2012). Данное определение весьма удачно при решении задач математического моделирования организаций и процессов организационного развития, в частности на этапах обоснования целей и задач моделирования, выбора типа модели, критериев качества и т. п. В общем случае под организационным развитием понимается регулярная целенаправленная деятельность по совершенствованию средств и способов, с помощью которых организация достигает стоящие перед ней цели.
#
# Стр. 10
#
# --------------------

# %% [markdown]
# __В общесистемном смысле__ развитие организации может рассматриваться как стремление к выбору таких форм ее существования, которые в наибольшей степени обеспечивают достижение желаемого экономического эффекта в ближайшей и долгосрочной перспективе при соблюдении баланса между состояниями стабильности и развития, отвечающего условию самосохранения. При этом следует полагать, что в аспекте закона самосохранения организационные изменения представляют собой процесс целенаправленного (управляемого) нарушения динамического равновесия организации. __В контексте проблемы__ организационного развития сущность самосохранения организации как целенаправленного управляемого процесса можно выразить следующими словами: организация как система стремится к сохранению своей целостности и качественной определенности, используя для этого весь свой потенциал. Под целостностью в данном случае понимается сохранение системы как целенаправленно упорядоченной совокупности взаимосвязанных элементов. Качественная определенность организации — это рациональное сочетание внутренних переменных организации (структуры, ресурсов, целей, функций и т. п.) и связей с внешней средой, соответствующих главной цели деятельности организации. Другими словами, качественная определенность организации — это ее способность достигать поставленную цель в условиях изменяющейся и не всегда благоприятной внешней среды.

# %% [markdown]
# __При этом важно понимать__, что стремление организации к целостности и качественной определенности (а следовательно, к самосохранению) не означает, что ее деятельность должна быть направлена на фиксацию («замораживание») какого-либо своего состояния и удержание его без изменения длительное время. Самосохранение организации возможно в том случае, когда в ней обеспечивается баланс между двумя противоположными состояниями: стабильности и развития. __Внутренние__ $S_{внутр}(t)$ и __внешние__ $S_{внешн}(t)$ факторы, обеспечивающие стабильность организации (stability), должны уравновешиваться внутренними $D_{внутр}(t)$ и внешними $D_{внешн}(t)$ факторами, способствующими ее развитию (development): $\frac{S_{внутр}(t)+S_{внешн}(t)}{D_{внутр}(t) + D_{внешн}(t)}$
#
# Стр. 11
#
# -----------

# %% [markdown]
# При отсутствии внутреннего потенциала стабильности $S_{внутр}(t)$ и стремлении организации к развитию, ее самосохранение возможно лишь в условиях максимально стабильной внешней среды, т.е. когда «вес» внешнего потенциала стабильности оказывается равным «весу» суммы внутреннего и внешнего потенциалов развития: $\frac{S_{внутр}(t)}{D_{внутр}(t) + D_{внешн}(t)}=1$. При отсутствии внутреннего петеициала развития $D_{внутр}(t)$  самосохранение организанки возможно лиши, при наличии внешних сил, побуждающих ее к развитию. Примером может служить государственное унитарное предприятие (или акционерное обшество с госудярством в роли главного акционера), развитие которого обеспечивается лишь за счет госуларственных дотаций или специально созданых льготных условий для реализании выпускаемой продукции: $\frac{S_{внутр}(t)+S_{внешн
# |Отношение к планированию изменений|Планируемые и программируемые изменения|Реакция на появляюшисся возможности|
# |Мотивация|Финансовые стимулы|Сочетание различных стимулов|
# |Участис консультантов|Экстенсивная помощь консультантов|Небольшая помощь на начальном этапе изменений|

# %% [markdown]
# Современная бизнес-практика всё чаще заставляет менеджмент крупных компаний убеждаться в том, что реактивные инкрементальные трансформации структуры и функций компании, осуществляемые перманентно в ответ на изменения внешней среды, не являются эффективным решением задачи организационного развития в целом и адаптации к изменениям среды в частности. В ряде случаев, по мнению исследователей (Ализес, 2008; Ализес, 2014; Weik и др., 1999), такие трансформации в итоге оборачиваются еще большими проблемами, порождая информационный хаос, ухудшение морально-психологического климата в коллективе, искажая систему приоритетов и ценностных установок. __В широком смысле__ под адаптацией понимается способность организационной системы приспосабливаться к изменяющимся условиям среды, помехам и т. п. Как правило, процесс управляемой адаптации организации к условиям внешней среды, характеризующейся высоким уровнем информационной неопределенности, расценивается как способность организационной системы обеспечивать эффективное достижение целей при недостатке априорной информации о факторах среды (Волкова и др., 2012). __Проблема недостатка__ априорной информации о факторах среды, на наш взгляд, является одним из центральных моментов адекватного математического моделирования процессов организационных изменений.
#
# Стр. 21
#
# ----------

# %% [markdown]
# Процесс адаптации можно описать изменением количественных и качественных характеристик организационной системы. Для развивающихся систем (в том числе систем, обладающих способностью к самоорганизации), к которым относятся организации, характерны такие уникальные способы адаптации, как настройка и самонастройка важнейших параметров, рост, обучение, самообучение, управляемая частичная дезинтеграция системы, объединение систем и т.п. Высокоорганизованные адаптивные системы, помимо прочего, обладают способностью изменять внешнюю среду для исключения или минимизации необходимости самоизменения. __Одной из наиболее заметных тенденций__ в исследовании проблемы организационных изменений становится отказ от признания эффективности реактивной адаптации и переход к изучению проактивных возможностей организационных систем, способных осуществлять упреждающие (предугадывающие) изменения. Главной отличительной особенностью методологии проактивной адаптации является то, что, формируя систему мероприятий организационных изменений, менеджмент компании опирается не на фактическую информацию о произошедших (или происходящих в настоящий момент) изменениях во внешнем окружении, а на предположениях о возможности таких изменений в будущем, выраженных в прогнозных оценках.
#
# Стр. 22
#
# --------------

# %% [markdown]
# Другим важным аспектом реализации адаптивных преобразований является аспект разрывности (или, иначе говоря, дискретности) процесса адаптации. Получивший в последние годы известность тезис о постоянстве и непрерывности организационных изменений не всегда в полной мере отражает сущность адаптации. Безусловно, анализируя деятельность успешных компаний в течение длительных периодов времени, нельзя не отметить их постоянное изменение (или как минимум стремление к изменениям). Однако постоянство процесса изменений не говорит о его непрерывности. Напротив, все успешные организационные преобразования носят дискретный (разрывный) характер, когда за этапом изменений следует этап устойчивого функционирования «обновленной» организационной системы. Этот второй этап можно условно назвать этапом «освоения» результатов осуществленных преобразований. Причем в аспекте анализа текущего состояния организации (ее результативности и эффективности) этап преобразований, а также первая фаза этапа «освоения» рассматриваются как переходный процесс, характеризующийся нелинейными (а порой — и колебательными (периодическими изменениями состояния с возможным многократным переходом через требуемое состояние равновесия.)) изменениями состояния организации.

# %% [markdown]
# %% [markdown]
# # 1.2. Теория систем и системный анализ в исследовании организаций
# Многообразие форм и типов организаций, сложность протекающих в них социально-экономических, организационных, технологических и иных процессов, а также влияние внешнего окружения заставляют подходить к исследованию организаций с точки зрения системного представления. __Системное представление__ (системный подход) — одна из основ менеджмента, заключающаяся в изучении свойств любой организации как системы — единого целого, состоящего из множества взаимосвязанных и взаимовлияющих элементов. __Слово «система» имеет греческие корни__ и означает «строй», «сочетание», «организм». Существует большое разнообразие определений понятия «система» (Садовский, 1974; Уёмов, 1978). К одному из наиболее распространенных можно отнести следующее: система представляет собой целенаправленно упорядоченную совокупность взаимосвязанных и взаимно влияющих друг на друга элементов, которая образует устойчивое единство и обладает как минимум одним новым свойством, отсутствующим у ее элементов, а именно: $S= \Biggl\langle A,R \biggr\rangle$; (1.1). где $A=\{a_i\}$, $a_i$ - элемент системы, $R=\{r_j\}$, $r_j$ - связь между  элементами.
#
# Стр. 25
#
# --------

# %% [markdown]
# Элементы, составляющие систему, часто называют компонентами или подсистемами. Подсистемой называется такая часть системы, которая сама обладает системными свойствами. Элементы системы оказывают друг на друга воздействие, подчиненное общей цели системы. Именно полезный результат (ожидаемый эффект) является основным системообразующим фактором, определяющим структуру, особенности и принципы функционирования любой системы. Причиной появления системы (или, как еще говорят, причинным системообразующим фактором) является исходная потребность существования системы. __Отсюда можно сделать важный вывод__: возникновение и развитие системы невозможно без появления потребности и определенной цели ее существования. Так, целями существования хозяйственной организации могут являться выпуск общественно полезной продукции и получение прибыли. Причинами же создания организации являются необходимость скоординированной совместной работы большого количества людей, привлечения техники, технологий и организационных механизмов, обеспечивающих эффективное достижение этих целей. __М. Месарович__ (Месарович, 1978; Месарович, 1973) в математическом определении системы выделяет множество Х входных объектов, воздействующих на систему, и множество У выходных результатов, устанавливая между ними обобщающее отношение пересечения: $S\subseteq X \times Y$,$S\subseteq X\cap Y$; (1.2)

# %% [markdown]
# Существует оригинальный взгляд (Волкова, 2001) на определение организационной системы как средство ее исследования, позволяющее рассматривать систему как совокупность укрупненных компонентов, необходимых для существования и функционирования системы, без расчленения на элементы («методологического разрушения»):
# $$S_{def}= \Biggl\langle Z, STR, TACH, COND \biggr\rangle; (1.3)$$
# где $Z=\{z\}$ - совокупность (структура) целей; $STR=\{STR_{пр},STR_{орг}, ...\}$ - совокупность структур, реализующих целей ($STR_{пр}$ - производственная структура и т.п.); $TECH =\{meth, means, alg ...\}$ - совокупность технологий, реализующих систему ( meth - методы, means - средства, alg - алгоритмы и т.п.) $COND=\{\varphi_{ex}\varphi_{in}\}$ - условия существования системы, т.е. факторы, влияющиие на ее создание и функционирование ($\varphi_{ex}$ - внешние фаторы, $\varphi_{in}$ - внутренние).
#
# Стр. 26
#
# ---------------

# %% [markdown]
# Стр. 28
#
# --------------

# %% [markdown]
# Системный подход к изучению организаций базируется на следующих принципах: __во-первых,__ исследуемая организационная система рассматривается как часть (подсистема) более общей системы; __во-вторых,__ более общая система (надсистема) по отношению к исследуемой системе рассматривается в качестве внешней среды; __в-третьих,__ исследуемая система представляется совокупностью взаимосвязанных элементов (подсистем); __в-четвертых,__ система имеет особые свойства, которые могут отсутствовать у образующих ее элементов. Как следует из первых двух принципов, __выбор границ системы__ заключается в условном разделении некоторой области материального мира на две части: собственно систему и ее внешнюю среду — набор объектов и факторов, действующих на систему извне. Определение границ между системой и ее внешней средой зависит от постановки задачи исследования и практических целей.
#
# Термин «системный анализ» трактуется неоднозначно. К особенностям системного анализа можно отнести (Садовский и др., 1969; Волкова, 1997; Волкова, 1999; Валуев и др., 1991): __во-первых__, опирается на основные понятия теории систем и философские концепции общесистемных закономерностей; __во-вторых__, применяется в тех случаях, когда задача не может быть решена с помощью формальных математических методов в силу высокой начальной неопределенности и многокритериальности; __в-третьих__, использует формальные и качественные методы (в том числе и «формализованный здравый смысл») (Волкова и др., 2012); __в-четвертых__, предлагает подходы к расчленению высокой неопределенности на более обозримые и поддающиеся анализу при сохранении целостного (системного) представления об объекте исследования.
#
# Одним из основных свойств любой системы, характеризующим ее внутреннее строение, является структура — отражение определенных взаимосвязей, взаиморасположения составных частей системы, ее устройства (строения) (рис. 1.3). __В соответствии с определением__ (моделью) системы (1.1) на схеме обозначено: $А_1$, $А_2$, ..., $А_i$, ... , $А_n$ - элементы системы (где n - обшее число элементов в системе); $S_{12}$, $S_{21}$, ... , $S_{mn}$ и т.д. - взаимовлияние элементов (например, $S_{12}$ — влияние элемента $А_1$, на элемент $А_2$,); $x_1$, $x_2$, ... , $x_i$ , ... , $x_n$ - состояния элементов; Х — состояние системы; $V_{BC}$ - воздействие внешней среды на систему; $V_{CB}$ — воздействие системы на внешнюю среду.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Рис. 1.3. Структура системы
#
# Элементом $A_i$ системы называется ее неделимая часть, обладающая самостоятельностью по отношению к другим элементам. Под неделимостью элемента понимается нецелесообразность учета в данной модели системы внутреннего строения этого элемента. Элемент характеризуется только своими внешними проявлениями в виде связей и взаимодействия с другими элементами. __Каждый элемент системы__ характеризуется набором свойств, которые однозначно определяют его роль и место в данной системе. Мгновенное значение свойств элемента называется его состоянием $х_i$, оно может описываться различными параметрами. __Например__, состояние отдела фирмы как элемента системы можно описать укомплектованностью персоналом, производительностью труда, количеством обслуживаемых за день клиентов и т.п. С течением времени состояние каждого элемента может изменяться, такое последовательное изменение состояния элемента называется его движением. __Влияние одного элемента на другой $S_{ij}$__, — это зависимость состояний одного элемента от состояния другого элемента системы. Например, влияние отдела кадров (HR-отдела) организации на все ее подразделения проявляется в том, что от степени компетентности набираемых работников и их деловых качеств напрямую зависит производительность труда, текучесть кадров и социально-психологический климат в этих подразделениях. Обратное влияние может заключаться в формировании руководителями отделов и служб специальных требований, предъявляемых к кандидатам на вакантные должности. Влияние такого элемента системы, как «Руководитель отдела», на элемент «Отдел» проявляется в реализации властных полномочий, формулировании требований, принятии решений о поощрениях и взысканиях. Обратное влияние может заключаться, например, в высказывании сотрудниками отдела своего мнения и использовании коллегиальных методов формирования решений.
#
# Стр. 29
#
# -------------

# %% [markdown]
# Организационные системы помимо общесистемных свойств, как правило, обладают свойством иерархичности построения. Совокупность состояний элементов, а также характер связей между ними определяют состояние всей системы (state of the system) — характеристика системы на данный момент се функционирования, описываемая комплексом существенных переменных и параметров. Формально состояние организационной системы может быть представлено в виде элемента $X(t)$ множества $\Omega_n$, возможных состояний, где аргумент t обозначает время, множество $\Omega_n$, - пространство состояний организационной системы. Состояние системы в каждый момент времени t задаётся и величинами. $х_i(t)$, называемыми координатами состояния системы: $ X(t)=[x_1(t), x_1(t), ... , x_i(t), ... , x_n(t)]$ . В теории систем множество X(t) называется вектором состояния системы. С течением времени позиция организационной системы в выбранном пространстве состояний может изменяться, что называется движением системы.
#
# Стр. 30
#
# ------------

# %% [markdown]
# Теория систем допускает несколько подходов к описанию систем. Наиболее часто используются следующие описания: функциональное, информационное, коммуникационное, морфологическое (структурное). Функциональное описание системы указывает на особенности процессов, протекающих внутри системы, и значение параметров, описывающих ее состав и работу. Такой подход к анализу реальных систем даст ответ на вопрос, для чего предназначена данная система, какие цели она преследует. Кроме того, функциональное описание позволяет оценить характер воздействия системы на ее внешнее окружение (т. е. на другие системы). Например, функциональное описание коммерческой организации с указанием типов и особенностей бизнес-процессов позволяет проанализировать характер взаимодействия этой организации с партнерами, поставщиками, потребителями, конкурентами, государством и т. п. __Информационное описание__ системы даст представление о типах и направлениях информационных потоков, протекающих внутри системы, между системой и ее внешней средой. Такое описание позволяет делать выводы об информационной упорядоченности системы и степени информационной энтропии. __Коммуникационное описание системы__ отражает взаимосвязь данной системы с другими системами в рамках их иерархического построения. Такое описание указывает на состав, сложность и необходимость каналов, связывающих организационную систему с элементами внешней среды, а также — на внутреннюю коммуникационную структуру организации.

# %% [markdown]
# Морфологическое описание системы указывает на состав и взаимные связи между элементами системы. При описании организационных систем морфологический подход позволяет выделить иерархическую структуру. __Все системы__, в том числе и организационные, обладают рядом особых свойств, называемых системными свойствами: неаддитивность, эмерджентность, мультипликативность, устойчивость, управляемость, адаптивность, обособленность и совместимость. __Неаддитивность__ заключается в том, что эффект от действия системы нельзя определять как алгебраическую сумму эффектов ее элементов. Кроме того, эффект от деятельности больших систем непостоянен во времени. В организациях это объясняется, например, разной квалификацией и опытом персонала, работающего в организации, стилями руководства, групповым взаимодействием, организационной культурой, характером внутриорганизационных коммуникаций и т. п. __Эмерджентность__ (эмергентность) (от англ. emergence — возникновение, появление нового) в теории систем — наличие у какой-либо системы особых свойств, не присущих ее подсистемам и блокам, а также сумме элементов, не связанных системообразующими связями.
#
# Стр. 31
#
# ---------

# %% [markdown]
# Как указывалось выше, теория систем помимо понятия «состояние системы - рассматривает также понятие «движение системы», под которым понимается процесс последовательного изменения ее состояния. Для удобства описания движения систем вводятся понятия вынужденного и собственного движения системы. Вынужденное движение системы - это изменение ее состояния под воздействием внешних (а иногда и внутренних) факторов, как правило, не согласующееся с целями системы. Собственное движение системы - это целенаправленное изменение ее состояния под воздействием системы управления. __Управляемость системы__ — это ее способность адекватно, без запаздываний и искажений реагировать на управленческое воздействие. Реакция системы на управленческое воздействие описывается понятием переходный процесс - изменением состояния системы с течением времени после начала воздействия на нее (рис. 1.5). __Другими словами, переходный процесс__ - это переход системы от начального состояния к конечному (требуемому) состоянию. Управляемость системы в общем случае можно охарактеризовать несколькими параметрами: видом переходного процесса, временем (7) реакции системы на управляющее воздействие (временем переходного процесса) и установившейся (систематической) ошибкой реакции системы ($\Delta$).

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Рис. 1.5. Переходный процесс системы
#
# Переходные процессы, возникающие в реальных организациях, могут быть различных видов (рис. 1.6). Так, например, в хорошо работающей организации переход на производство нового вида продукции может носить плавный характер во всех функциональных зонах: последовательное изменение маркетинговой политики, запланированное изменение технологий, своевременное переобучение персонала, внедрение новой системы мотивации и т.п. В другом же случае такой переход может носить колебательный характер с постепенным приближением к установившемуся (требуемому) значению.
#
# Колебания могут проявляться, например, в следующем. Сначала персонал организации отрицательно оценивает нововведение руководства, в результате чего ухудшается моральный климат в коллективе, падает производительность. Затем эффективная работа менеджмента (например, новые подходы к стимулированию работников) создает предпосылки для улучшения ситуации. Через некоторое время моральный климат и производительность даже превышают запланированные значения. Далее фазы спада-роста могут повторяться несколько раз, пока анализируемый параметр не установится на требуемом уровне или близком к нему.
#
# Стр. 34
#
# ---------------------

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# $$(a)$$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# $$(б)$$

# %% [markdown]
# Рис. 1.6. Виды переходных процессов и параметры управляемости: а — переходный процесс с малым временем реакции (7) и нулевой ошибкой — хорошая управляемость; б — колебательный переходный процесс с большим временем реакции (Т) и ненулевой установившейся ошибкой ($\Delta\neq0$) — плохая управляемость. __Исходя из определения управляемости__, можно сделать поспешный вывод, что увеличение значения этого свойства всегда приводит к положительному результату — высокой результативности и эффективности функционирования организационной системы. Однако это не всегда так. Дело в том, что в ряде случаев избыточная, т. е. необоснованно высокая степень управляемости системы может привести к снижению ее устойчивости. Так, высокая управляемость (быстрая реакция на указания менеджеров) может привести к ухудшению морального климата в коллективе и увеличению текучести кадров в условиях необоснованно жесткой требовательности менеджмента при осуществлении контрольных мероприятий и нарушении масштаба допустимых отклонений. __Возможен и обратный эффект__: приобретение системой избыточной устойчивости может повлечь за собой ухудшение ее управляемости. Избыточная устойчивость организационной системы может проявляться в следовании менеджмента «раз и навсегда» установленным правилам и нормам независимо от изменения требований внешнего окружения, что снижает способность организации к целенаправленным изменениям.
#
# Стр. 35
#
# --------------

# %% [markdown]
# __Адаптивность__ — способность приспосабливаться к новым внешним условиям. Уровень адаптивности различен для разных систем и зависит от степени соответствия структуры и внутренних связей организации внешним условиям. Например, в условиях сложного и динамично изменяющего рынка высокая адаптивность присуща организациям с гибкой органической структурой, свободной от бюрократических механизмов управления. __Обособленность частей системы__ — стремление некоторых подсистем большой системы к автономности и изолированности. В хозяйственных организациях это свойство проявляется при решении вопросов распределения ресурсов и властных полномочий. Пример проявления данного свойства — выделение в структуре компании дивизионов (бизнес-единиц). При этом свойство обособленности находится в определенном балансе с противоположным ему свойством — совместимостью. __Совместимость__ — свойство взаимной приспособляемости и взаимной адаптивности элементов системы. В зависимости от общесистемных свойств различают линейные и нелинейные системы. __Система называется линейной__, если она обладает следующими свойствами: __во-первых__, реакция системы на сумму произвольных входных воздействий равна сумме ее реакций на каждое из этих воздействий в отдельности; __во-вторых__, любое усиление входного воздействия по величине без изменения его формы приводит к такому же усилению выходного результата системы.

# %% [markdown]
# Системы, для которых данные свойства несправедливы, являются нелинейными. Организационные системы являются нелинейными. Как линейные, так и нелинейные системы могут быть стационарными и нестационарными. Система называется стационарной, если при сдвиге во времени входного воздействия без изменения его вида, выходной результат также сдвигается во времени на ту же величину без изменения своего вида. Если выходной результат помимо сдвига во времени изменяет свою форму, то система является нестационарной (рис. 1.7). Например, организацию можно считать стационарной системой, если одно и то же управленческое решение, принятое руководством в разное время, повлечет за собой однотипные реакции: действия и мнения персонала, результат, последствия и т. п. В том случае, если повтор решения приведет к существенно иной реакции, можно говорить о наличии в системе нестационарности. Следовательно, прогноз последствий принятия того или иного управленческого решения в такой системе нельзя строить на основе анализа прошлых тенденций.
#
# Стр. 36
#
# ---------------

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# $$(a)$$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# $$(б)$$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# $$(в)$$

# %% [markdown]
# Рис. 1.7. Иллюстрация реакции стационарной и нестационарной систем: а — управляющее воздействие: требование увеличить значение какого-либо показателя; б — результат работы стационарной системы: вид переходного процесса не изменился; в — результат работы нестационарной системы: вид переходного процесса изменился.
#
# Системный анализ находит широкое применение во многих сферах деятельности: при моделировании процессов принятия решений в условиях неопределенности, при исследовании и проектировании сложных организационно-технических систем, при исследовании проблем организации и управления на уровне компаний, корпораций, регионов, государств, при разработке автоматизированных систем различного рода (Алексеева и др., 2013; Дик, 2001; Семенов, 2003), при исследованиях эффективности логистики (Хабаров, 2013) и др.

# %% [markdown]
# # 1.3. Анализ современного состояния теории и методологии моделирования процессов организационного развития и организационных изменений
#
# Как отмечается разными авторами (Воронин и др., 2008; Новиков и др., 2007; Новиков, 2007; Емельянов и др., 2002; Волкова и др., 2012), одним из эффективных методов изучения организационных систем является их моделирование - процесс построения и анализа модели организации. Модель (от лат. modulus - мера, аналог, образец) — копия или аналог изучаемого процесса, предмета или явления, отображающая существенные свойства моделируемого объекта, с точки зрения цели исследования (Малый экономический словарь, 2000). В общем случае модель представляет собой образ какого-либо объекта, процесса или явления (Ильичев и др., 1983). В системном анализе и теории моделирования систем под этим термином понимается образ некоторой системы, аналог (схема, структура и т.п.) фрагмента природной или социальной реальности. Целенаправленность исследования - один из важнейших аспектов моделирования, определяющий выбор метода моделирования, типа (класса) модели, формального представления, ожилаемой степени полноты и достоверности результатов и др. В этой связи представляется интересной следующая образная трактовка целенаправленности моделирования: лучшая модель круга — квадрат, если задачей исследования является определение площади фигуры; задача определения длины окружности предполагает, что лучшей моделью круга является отрезок прямой соответствующей длины.
#
# Стр. 39
#
# -----------

# %% [markdown]
# По мнению ряда исследователей, начавшийся с первой половины ХХ в. процесс формализации экономической науки привел к формированию развернутой экономико-математической методологии, которая, однако, почти не рассматривает закономерности внутренней организации экономических субъектов. Особенно отчетливо этот недостаток экономической теории проявляется при решении задач, связанных не столько с экономическими, сколько с организационными, организационно-техническими, социально-психологическими и иными аспектами функционирования и развития организаций как сложных систем. __Бурный прогресс__ теории математического управления и теории управления техническими системами, обусловленный стремительным развитием таких направлений, как авиация, космические технологии, вооружение, робототехника и т. п., внес колоссальный вклад в развитие методов моделирования сложных технических систем.

# %% [markdown]
# # Подходы к классификации моделей систем.
# Созданные к настоящему времени модели организаций в основном можно разделить на «экономические» и «инженерные». По мнению авторов (Воронин и др., 2008; Губко, 2006), в настоящее время наблюдается сближение позиций экономического и инженерного направлений в моделировании организаций, что позволяет говорить о появлении синтетических теорий, объединяющих достоинства инженерного и экономического подходов. __Большое разнообразие__ подходов к классификации моделей систем (и организационных систем, в частности), предлагаемых разными авторами, не позволяет остановиться на каком-либо одном из них. Тем не менее различные подходы к выделению классификационных признаков оказываются удобными для определения роли и места тех или иных моделей или основанных на них методах исследования организационных систем. __Часто выделяются__ две группы моделей: материальные (физические, реальные, вещественные, натурные) и мысленные (умозрительные, абстрактные, идеальные). Представляется, что ни один из использующихся в данной классификации терминов не является вполне удачным. __К материальным__, как правило, относятся модели, представляющие собой упрощенные копии реальных природных, технических, организационных объектов или процессов. Для таких моделей характерно то, что их некоторые (интересующие исследователя) свойства отражают аналогичные свойства моделируемых объектов. Так, уменьшенная трехмерная (демонстрационная) копия цеха завода отражает такие свойства реального цеха, как композиционность размещения и количественную пропорциональность входящих в него объектов (внешние, визуальные признаки), не претендуя на адекватность отображения абсолютных размеров и тем более технических процессов.
#
# Стр. 40
#
# -------

# %% [markdown]
# Другим примером материальной модели может служить нагревательный элемент в модели технического устройства, отражающий тепловые свойства (физический, не визуальный признак), не обязательно с точной передачей температуры, спектра и других параметров излучения, создаваемого реальным объектом (например, электрическая лампа как модель теплоизлучения двигателя самолета). __Материальность__, или «физичность», таких моделей состоит в способах передачи существенных свойств и отношений, доступных человеческому восприятию на основе аналогий. В связи с этим представляется не вполне удачным выделение в особый класс так называемых аналоговых моделей, которые определяются некоторыми авторами как аналоги, которые ведут себя как реальный объект, но по внешним признакам существенно отличаются от него... (например, схема бизнес-процесса как модель реального бизнес-процесса) (Звонников и др., 2013; Шишкин и др., 2009). __Тем не менее термин__ «аналоговое моделирование» применяется для обозначения подхода к имитационному моделированию технических устройств и процессов на основе включения в модель реальных (аналоговых) технических элементов, что предполагает непосредственную обработку непрерывных (аналоговых) сигналов без применения цифровых (дискретных) технологий обработки. В ряде случаев синонимом термина «аналоговое моделирование» в технической сфере является термин «полунатурное» моделирование. __По поводу сигналов__. Аналоговый сигнал — сигнал данных, у которого каждый из представляющих параметров описывается функцией времени и непрерывным множеством возможных значений (ГОСТ 17.6.5.7-79 «Передача данных. Термины и определения»). __Мысленные (абстрактные)__ модели представляют собой идеальные языковые конструкции, построенные средствами мышления. Помимо естественных языков в абстрактном моделировании широко используются формализованные языки.

# %% [markdown]
# __Важным основанием классификации моделей__ является использование в ходе моделирования количественных мер. По этому основанию выделяют качественные и количественные (математические) методы моделирования. __Качественные__, или содержательные (построенные на основе эмпирических данных), модели получили широкое распространение в теории менеджмента. Такие модели позволяют осуществлять качественный анализ эффективности деятельности организаций. Одним из видов качественных содержательных моделей являются модели жизненного цикла организации (Greiner, 1967; Greiner, 1972; Lippitt и др., 1967; Ализес, 2014; Филонович и др., 1996) или модели организационной культуры (Камерон, Куинн, 2001). __Применение математики__ в качестве формализованного языка моделирования позволяет говорить о математическом моделировании. __На взаимосвязь__ содержательного и формализованного количественного моделирования указывает, например, Мышкис А. Д. (Мышкис, 2007): «Очевидный, но важнейший начальный этап построения или выбора математической модели — это получение по возможности более четкого представления о моделируемом объекте и уточнение его содержательной модели, основанное на неформальных обсуждениях. Нельзя жалеть времени и усилий на этот этап, от него в значительной мере зависит успех всего исследования. Не раз бывало, что значительный труд, затраченный на решение математической задачи, оказывался малоэффективным или даже потраченным впустую из-за недостаточного внимания к этой стороне дела».
#
# Стр. 41
#
# -----------

# %% [markdown]
# Под аналитическим моделированием понимается такой подход к моделированию, для которого характерно то, что все системные связи и процессы записываются в виде некоторых функциональных соотношений (например, алгебраических, дифференциальных и других уравнений) или логических условий (Воронин и др., 2008). __Аналитическая модель__ может быть исследована следующими методами (Арнольд, 1998): __во-первых__, аналитическим (получение явных зависимостей для искомых характеристик в виде формул); __во-вторых__, численным (получение числовых результатов при выбранных начальных условиях при невозможности аналитического решения); __в-третьих__, качественным (определение некоторых свойств решения). __Имитационное моделирование__ в широком смысле представляет собой целенаправленные серии многовариантных исследований, выполняемых на компьютере с применением математических моделей (Волкова и др., 2012). __Имитационной моделью__ называется специальный программный комплекс, позволяющий имитировать функционирование какого-либо сложного объекта. Как правило, имитационная модель отражает большое число переменных, параметров, закономерности и логику поведения исследуемого объекта.

# %% [markdown]
# Формальная классификация математических моделей часто основывается на выделении признаков применяемых математических средств. Наиболее распространенным подходом к классификации математических моделей является выделение следующих дихотомий: линейные или нелинейные; статические или динамические; детерминированные или стохастические; дискретные или непрерывные. Более или менее развитый теоретический аппарат математического моделирования существует сегодня только для физического или технического уровня сложности системного описания (Воронин и др., 2008). В сфере математического описания технических систем и процессов имеется богатейший теоретический и практический научный материал. Социальные, в частности, экономические науки пока не могут продемонстрировать столь же глубокое и широкое применение методов математического моделирования для решения практических задач в силу высокой сложности исследуемых объектов (экономические системы, организации) и протекающих в них процессов.
#
# Cтр. 42
#
# -----------

# %% [markdown]
# Выбор метода моделирования зависит от большого количества факторов, наиболее значимым из которых является представление о моделируемой системе. Наряду с общим определением системы как комплекса взаимосвязанных элементов (см. (I.1)), существует ряд конструктивных определений, обращающих внимание на типичные свойства системы-модели, среди которых выделяются такие, как признаки внутреннего строения, функционирования, поведения, развития и т. п. (см. (1.2), (1.4)). __В соответствии с__ подходом К. Боулдинга (Боулдинг, 1969) базовая метамодель любой системы $М_s$ может быть представлена в виде открытого (для дополнения и фрактального углубления (Воронин и др., 2008)) кортежа ее базовых признаков и свойств, упорядоченных в соответствии с эмпирически обоснованным нарастанием системной сложности (Воронин и др., 2008). (Здесь предлагается упрощенный вариант кортежа базовой модели): $M_s=\{A:\{a_i\};S:\{s_j\};F:\{f_k\};D:\{d_i\};V:\{v_q\};U:\{u_o\};Z:\{z_m\};G:\{g_p\};N:\{n_c\};\}$, где $А:\{а_i\}$ — элементы; $S:\{s_j\}$ — структура; $F:\{f_k\}$ — функции; $D:\{d_i\}$ — динамические свойства; $V:\{v_q\}$ — взаимодействие с внешней средой; $U:\{u_o\}$ — управление; $Z:\{z_m\}$ — целеполагание; $G:\{g_p\}$ — гомеостазис; $R:\{r_b\}$ — развитие; $N:\{n_c\}$ — наблюдатель (исследователь).

# %% [markdown]
# Степень учета тех или иных базовых признаков в кортеже зависит от задачи исследования. Так, в задачах исследования процессов организационных изменений и развития возрастает значение моделирования признаков $D:\{d_i\}$ , $Z:\{z_m\}$ и $R:\{r_b\}$. __На сегодняшний день__ накоплен значительный опыт обоснования, разработки, анализа и использования разнообразных методов моделирования организационных (организационно-экономических) систем. К наиболее проработанным и теоретически развитым классам таких математических моделей можно отнести (табл. 1.3) (Губко и др., 2004; Воронин и др., 2008; Новиков, 2012; Орлов, 2011; Шишкин и др., 2009; Новиков и др., 2006; Новиков, 2008; Орлов и др., 2007; Орлов, 2014). __К одному из наиболее проработанных__ в наше время классов математических моделей организаций, допускающих их использование при исследовании проблем организационного развития, можно отнести модели формирования организационных структур (Губко и др., 2004; Губко, 2006; Воронин и др., 2002; Воронин и др., 2008; Новиков, 2012).
#
# Стр. 43
#
# ----------

# %% [markdown]
# Тоблица 1.3. Основные вилы моделей организационных систем
#
# |Виды моделей|Математический аппарат,<br/> теории и истодология|
# |---|---|
# |Модели принятия <br/> решения|Теория полезности. Теория вибора. <br/> Теория графов. Методы оптимизации. <br/> Кооперативные и некооперативные игры. <br/> Иерархические игры. <br/> Ограниченная рациональность. <br/> Нечеткие множества. <br/> Молели коллективного повеления. <br/> Отношения предпочтения.|
# |Модели стимулирования <br/> в организационных <br/> системах| Институциональное управление. <br/> Модели поведения участников. <br/> Управление проектами. <br/> Разработка и оптимизация <br/> организационных структур. <br/> Теория игр. <br/> Теория активных систем. <br/> Сетевые структуры. <br/> |
# | Модели <br/> иерархических <br/> структур <br/> | Теория графов. <br/> Оптимальные деревья. <br/> Кусочно-однородные <br/> и аддитивные функции затрат. <br/> Иерархии и теория команд. <br/> Теория контрактов. <br/> Иерархии знаний. <br/> Теория принятия решений. |

# %% [markdown]
# |Виды моделей|Математический аппарат,<br/> теории и истодология|
# |---|---|
# |Модели нерархии <br/> управления | Управленческие затраты. Иерархия управления <br/> производетвенными (технологическими) линиими. <br/> Теория менеджмента. Методы оптимизашии. <br/> Оптимальные деровыя.|
# |Модели <br/>распределения <br/>ресурсов|Стохастические методы. Теория полезности. <br/> Матрины. Линейное программирование. |
# | Молели управления <br/> запасами | Теория принятия решений. <br/> Методы оптимизации |
# | Модели финансирования <br/> инновационного <br/> развития фирмы |Статическое и динамическое <br/> моделирование. Неопределенности. <br/> Механизмы: самостоятельного <br/> финансирования, распределения <br/> инвестиший, возврата инвестиций, <br/> смешанного финансирования, <br/> распределения затрат и <br/> распределения дохода|

# %% [markdown]
# |Виды моделей|Математический аппарат,<br/> теории и истодология|
# |---|---|
# |Модели управления <br/> организационными <br/> проектами | Игры с переменным составом. <br/> Теория менеджмента. <br/> Матричные структуры управления.|
# |Молели управления <br/> развитием персонала|Иерархия потребностей. <br/> Теория менеджмента. <br/> Мотивания.|
# |Экспертные технологии <br/> принятия решений | Экспертное прогнозирование. <br/> Теории измерений и экепертные оценки. <br/> Методы средних рангов. <br/> Математические методы анализа <br/> экспертных оценок |
# | Принятие решений <br/> на основе моделей <br/> обеспечения качества |Основы статистического <br/> контроля качества. <br/> Асимптотическая теория <br/> одноступенчатых планов. |
#
# Стр. 44
#
# ------------

# %% [markdown]
# Разработана достаточно подробная система классификации таких моделей, основанная на их формальных характеристиках (Губко и др., 2004). Основные признаки (основания) классификации приведены в табл. 1.4.

# %% [markdown]
# Таблица 1.4. Классификация математических моделей формирова организационных структур (по Губко и др., 2004)

# %% [markdown]
# |№<br/>п/п|Основание (признак)<br/>классифика|Возможные значения признаков для <br/> рассматриваемого класса систем|
# |---|---|---|
# |1|Цель исследован|Анализ и синтез|
# |2|Природа элементов системы|Активные ассивные|
# |3|Природа системы в целом|Целенаправленная <br/> и нецеленаправленная|
# |4|Количество элементов системы|Конечное или бесконечное <br/> (Как допушение, позволяющее <br/>упростить залачу исследования <br/>(см., например $[$Губко, 2002$]$)).|
# |5|Однородность элементов <br/>  структуры|Иденти или индивидуальные|

# %% [markdown]
# |№<br/>п/п|Основание (признак)<br/>классифика|Возможные значения признаков для <br/> рассматриваемого класса систем|
# |---|---|---|
# |6|Динамика модели|Динамическая или статическая|
# |7|Неопределенность| Детерминирован или с неопределенностью <br/> (Рассматриваются  неопределенности <br/> разной природы)|
# |8|Типы организационных структур|Иерархическая или сетевая|
# |9|Типы связей|Направленные или ненаправленные|
# |10|Наличие исходной структуры|«С нуля» или реорганизация|

# %% [markdown]
# |№<br/>п/п|Основание (признак)<br/>классифика|Возможные значения признаков для <br/> рассматриваемого класса систем|
# |---|---|---|
# |10|Наличие исходной структуры|«С нуля» или реорганизация|
# |11|Количество уровней <br/> организационной структуры|Фиксированное или <br/> нефиксированное|
# |12|Распределение ролей <br/> («руководители-подчиненные»)|Фиксированное или <br/> нефиксированое|
# |13|Направление формирова <br/> структуры|Снизу вверх или сверху вниз|
#
# Эта классификация позволяет выделять разнообразные типы моделей в задачах исследования организационных структур и процессов. Вместе с тем ряд задач исследования процессов организационных изменений требует использования дополнительных оснований для классификации систем и их моделей. Признак «постоянство структуры» в отдельных специфических задачах позволяет выделять организационные системы с постоянной структурой; с переменной структурой; со случайной скачкообразной структурой (Бухалев, 1996). Признак «стационарность» системы позволяет рассматривать нестационарные и стационарные (допущение) организационные системы.

# %% [markdown]
# Для анализа различий между содержательными и процессными эффектами организационных изменений У. Барнетт и Г. Кэрролл предлагают использовать модель Эмбюрги и др. (Amburgey T.L. и др., 1993): $r_j(t)=exp[\gamma t_j + \Theta X_j(t)+a(\Delta Z_j)+B \tau_j]$, где $r_j(t)$ — текущий показатель риска гибели организации j, t — возраст организации j; Х — текущие переменные пространства состояний организации j, $\Delta Z_j$ — индикаторное значение, приравниваемое к нулю в момент основания организации j до момента осуществления в ней значительных изменений; $\Theta_j$ — время «возвращения» с момента последних значительных изменений (приравнивается к нулю, если в организации не происходило изменений); у и в — нормирующие коэффициенты.
#
# Стр. 47
#
#  ---------

# %% [markdown]
# Модель (1.5) позволяет фиксировать содержательные изменения совместно с изменениями значений независимых переменных $Х_j$. Процессные эффекты изменений представлены здесь в виде $a(\Delta Z_j)$ и $b\tau_j$. __В основе модели__ Эмбюрги и др. лежит теория структурной инерции Ханнана и Фримана (Hannan М. Т. и др., 1984), согласно которой организации становятся всё более инертными по мере того, как в них закрепляются определенные процедуры, роли и структуры. Это означает, что с увеличением возраста организации вероятность организационных изменений снижается.
#
# Данное утверждение было подтверждено эмпирическими исследованиями, результаты которых опубликованы рядом западных ученых. Однако, по нашему мнению, прямая линейная зависимость, характеризующая рост и закрепление бюрократических методов организации и управления с течением времени существования организации, не всегда имеет место. В частности, в модели жизненного цикла организации И.А. Адизеса (Адизес, 2008; Адизес, 2014) возрастание с течением жизни организации негативных тенденций, связанных с бюрократизацией организации и управления, рассматривается лишь как вариант недостаточного понимания менеджментом текущей ситуации и, как следствие, низкого внимания к организационным изменениям. Тем не менее статистически обоснованные эмпирические исследования (во всяком случае, проводимые в 1990-е гг. в США и странах Западной Европы) подтверждают предположения Ханнана и Фримена о снижении вероятности организационных изменений с увеличением возраста организации.
#
# При этом теория структурной инерции утверждает, что вероятность изменений возрастает после того, как какое-либо изменение уже произошло и «часы» инерции начали новый отсчет с того момента времени, когда в результате изменений были сформированы новые структуры, процедуры и стандарты (Широкова, 2010; Amburgey T. L. и др., 1993). В соответствии с теорией структурной инерции в модели (1.5) должно наблюдаться следующее: а > 0 и b < 0 (рис. 1.9). Максимальное значение $r_j(t_{км})$ кривой $r_j(t)$ означает скачкообразный рост риска гибели организации и определяется значением коэффициента а > 0. Скорость убывания риска определяется значением коэффициента b < 0.
#
# Стр. 48
#
# ---------

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Рис. 1.9. Зависимость риска гибели организации от ее возраста с учетом изменений (Широкова, 2010, адаптировано)
#
# Структурная инерция определяется в относительных и динамических терминах в контексте сопоставления скоростей изменения внешней среды и осуществляемых организационных изменений. В частности, структура организации обладает значительной инерцией в случаях, когда скорость реорганизации ниже скорости изменения внешних условий. Ниже эта проблема будет подробно обсуждаться в контексте построения динамической модели организационных изменений. __Одной из проблем__, связанных с моделированием организационных изменений, часто называется адекватная оценка результатов организационных изменений («организационных последствий изменений») (Широкова, 2010). Наиболее часто в качестве показателей результативности организационных изменений называются такие финансовые показатели, как прибыль от инвестиций (ROI), доходность активов (ROA) и т. п. В (Barnett и др., 1995) со ссылкой на Мейера и Гупта указывается, что любая переменная результативности, основанная на показателях деятельности организации, имеет тенденцию к потере вариативности по мере использования, что снижает достоверность определения позитивных и негативных результатов.

# %% [markdown]
# С учетом предположения, что организационная система в процессе изменений не находится в стабильном состоянии (состоянии равновесия), и при наличии свойства непрерывности переменных результата, достаточную динамическую базу моделирования может обеспечить линейная модель частичной корректировки (linear partial adjustment) (Широкова, 2010): $\frac{dY_j}{dt} = r(Y_j'-Y_j)$, где $Y_j$ — наблюдаемая непрерывная переменная (показатель результативности деятельности организации j в данный момент времени); $Y_j'$ — ненаблюдаемая переменная (конечный уровень Y при установившемся равновесии); r — скорость организационной корректировки в направлении достижения равновесия. Ненаблюдаемая переменная $Y_j$ может быть установлена в качестве функции от наблюдаемых величин для проверки гипотезы о конечных результатах изменений.
#
# Стр. 49
#
# ---------

# %% [markdown]
# # Теория команд в исследованиях организационных изменений.
# Проблемы математического моделирования и исследования процессов организационных изменений и организационного развития заставляют исследователей обращаться к теории команд (teams theory) и построенным на ее основе моделям организационных систем (Marschak и др., 1972; Маргерисон, 2004; Новиков, 2007; Новиков, 2008; Губко, 2006; Миниберг, 2004). __Под командой__ понимается коллектив (объединение людей, осуществляющих совместную деятельность и обладающих общими интересами), способный достигать цели автономно и согласованно при минимальных управляющих воздействиях (Новиков, 2007). __Выделены следующие характеристики команды__, в совокупности отличающие ее от группы, коллектива и/или организации (Новиков, 2008): единство цели; совместная деятельность; непротиворечивость интересов; автономность деятельности; коллективная и взаимная ответственность за результаты совместной деятельности; специализация и взаимодополняемость ролей (включая оптимальное распределение функций и объемов работ, а также синергетичность взаимодействия членов команды); устойчивость команды (оправдываемость взаимных ожиданий ее членов). __Основным предметом__ исследования теории команд являются проблемы координации деятельности групп индивидуумов (членов команд), преследующих общие цели. __Процесс распределения задач__ между исполнителями (декомпозиция общей цели деятельности) предполагает, что своевременное и правильное выполнение каждым членом команды своей части работ в итоге приведет к достижению общей цели. Однако правильное разделение сложной задачи на составные части в соответствии с компетенциями и обязанностями сотрудников еще не означает эффективную организационную деятельность. Для продуктивной работы необходимо обеспечить координацию работы исполнителей. В общем случае формирование организационной структуры (команды) предполагает, во-первых, правильное распределение задач. А во-вторых, осуществление координации, обеспечивающей интеграцию совместной работы исполнителей. Г. Минцберг (Миниберг, 2010) выделяет пять координационных механизмов — способов, посредством которых организации координируют свою деятельность и обеспечивают интеграцию всех своих частей: взаимное согласование, прямой контроль, стандартизация рабочих процессов, стандартизация выпуска, стандартизация навыков и знаний (квалификации).
#
# Стр. 50
#
# ---------

# %% [markdown]
# __При взаимном согласовании__ контроль процессов и результатов труда, условно говоря, осуществляют сами сотрудники. Для этого они используют неформальные, но направленные на конкретные профессиональные вопросы коммуникации. Этот простейший координационный механизм зачастую оказывается весьма эффективным способом обеспечить бесперебойность трудового процесса. Он не требует значительного отвлечения исполнителей от решения их непосредственных задач. В основе механизма взаимного согласования лежит предположение о достаточной квалификации (компетентности) работников в рамках оперативно решаемой ими задачи, что позволяет им отказаться от прив
#
# ------

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Рис. 1.10. Графическое представление координационного профиля (пример)
#
# Базовая модель команды предполагает, что имеется команда из $n$ агентов, каждый из которых выбором своего действия $x_i\in X_i$, $i=i,...,n$, стремится максимизировать общий критерий эффективности $К(*)=К(x_1, ..., x_n, \Theta)$, где $\Theta$ — состояние природы. Причем у каждого агента имеется свое представление о состоянии природы. Задача состоит в том, чтобы скоординировать решения, принимаемые агентами, т. е. найти рациональные правила выбора действий с учетом частной информации, имеющейся у агентов (Губко, 2006). __Одним из наиболее ранних подходов__ к решению поставленной задачи является модель Б. Л. Овсиевича (Овсиевич, 1979), в которой рассматривается система из и элементов, каждый из которых описывается некоторым числом возможных состояний. Работа системы описывается вероятностной мерой $\mu(s)$ на множестве ее состояний, где состояние $s$ всей системы определяется вектором состояний ее элементов. В качестве основной количественной характеристики системы в модели рассматривается ее информационная энтропия: $\sum_{s}\mu(s) \lg(\mu(s))$.
# Стр. 53
#
# ------

# %% [markdown]
# В силу системных свойств энтропия системы не равна сумме энтропией ее элементов. Согласно Б. Овсиевичу, разница энтропий системы и суммарной энтропии элементов определяет объем работы по координации элементов системы, которую должна выполнить система управления (менеджер). Задача оптимизации управления в данной постановке сводится к разбиению множества элементов (исполнителей) на подсистемы, управляемые элементами (менеджерами), объемы работ которых ограничены сверху. __Целью разбиения является__ минимизация разницы между суммарной энтропией подсистем и системы в целом. В результате разбиения формируются уровни иерархии вплоть до высшего уровня. Данный подход в целом соответствует выводам, которые можно сделать исходя из применения закона необходимого разнообразия У. Р. Эшби к иерархическим организационным системам (Эшби, 1959). __Обширный класс__ математических моделей команд составляют задачи стимулирования агентов — вознаграждения членов команды по результатам совместной деятельности в условиях, когда управляющий орган (менеджер) не обладает информацией об индивидуальных вкладах членов команды в общий результат, предоставляя им самим выбрать способ достижения цели. __При решении задачи__ моделирования процессов организационных изменений проблема коллективного стимулирования командной работы может оказаться весьма актуальной. Причем допущение об отсутствии у руководителя своевременной и достоверной информации об индивидуальных вкладах агентов в рассматриваемых условиях является достаточно адекватным.

# %% [markdown]
# Приведем следующую общую постановку задачи коллективного стимулирования (Новиков, 2008). Под командой понимается множество агентов $N = \{1, 2, ..., n\}$, в которой i-й агент принимает решение $х_i \in X_i$, $i \in N$. Результат деятельности команды определяется как $z = Q(x)$, где $x = [x_1, x_2, ..., x_n] \in X' = \prod_{i \in N} X_i$ — функция агрегирования, зависящая от вектора х действий всех членов команды и наблюдаемая управляющим центром.
#
# Система стимулирования $\sigma (z) = [\sigma_1(z), \sigma_2(z), ..., \sigma_n(z)]$ ставит в соответствие результату деятельности команды систему индивидуальных вознаграждений ее членов $(\sigma_i(z) ≥ 0)$ с бюджетным ограничением. В некоторых задачах бюджетное ограничение может отсутствовать. $\sum_{i \in N} \sigma_i(z) = z$.
#
# Целевая функция $f_1(*)$ i-го агента представляет собой разность между полезностью $u_i(*)$ от вознаграждения и затратами $с_i(*)$, зависящими от вектора действий агентов х и типа i-го агента: $f_i(x, \sigma (*), r_i) = u_i(\sigma_i(z)) - c_i(x, r_i)$, $i \in N$, где типом $r_i > 0$ i-го агента называется параметр, отражающий все существенные его характеристики: эффективность деятельности, производительность труда и т. п.
# Стр. 54
#
# ------------

# %% [markdown]
# Целевая функция центра описывается разностью между доходом $Н(*)$ от результата $z$ деятельности команды и суммарным стимулированием (вознаграждением), выплаченным агентам:
#
# $$\Phi(z, \sigma(*)) = H(z) - \sum_{i \in N} \sigma_i(z)$$
#
# В результате задача коллективного стимулирования заключается в выборе системы стимулирования, которая максимизировала бы гарантированный выигрыш управляющего центра на множестве равновесий игры членов команды:
# $$min_{x^* \in E_N(\sigma(*))} [H(Q(x^*)) - \sum_{i \in N} \sigma_i(Q(x^*))] -> max_{\sigma(*)} $$
# где $E_N(\sigma(*)) = {x^* \in X'}$ — множество равновесных стратегий (по Дж. Нэшу) игры агентов при заданной системе стимулирования $\sigma(*)$.

# %% [markdown]
# В соответствии с классификацией моделей коллективного стимулирования (Новиков, 2008), затраты агентов (третье основание классификации) могут быть сепарабельными или несепарабельными. Сепарабельность функций затрат агентов означает, что затраты каждого агента зависят только от его собственных действий, в то время как в общем случае (при несепарабельных затратах) затраты каждого агента могут зависеть от действий всех агентов. Анализ условий и особенностей осуществления организационных изменений демонстрирует на содержательном уровне крайне высокий уровень несепарабельности действий членов команд, участвующих в изменениях, что может служить основанием для выбора соответствующего типа модели.
#
# Стр. 55
#
# --------------

# %% [markdown]
# Анализируя особенности применения моделей коллективного стимулирования для исследования организационных изменений, также следует обратить внимание на такое основание классификации, как типы агентов (шестое основание (Новиков, 2008)): типы известны всем агентам / каждому агенту известен свой тип (adverse selection). __Представляется__, что помимо факта информированности агентов о типах, в условиях решения ими новых задач неочевидным становится сам факт однозначного (детерминированного) определения типа агента. Задание той или иной формы неопределенности типа агента применительно к решаемой задаче может являться особым признаком модели стимулирования команды в условиях организационных изменений. __Как подчеркивает Новиков Д. А.__, первое основание классификации — наблюдаемость / ненаблюдаемость действий агентов управляющим центром — в наибольшей степени подчеркивает специфику команд (Новиков, 2008). Если индивидуальные действия агентов наблюдаются центром, то последний может использовать системы персонифицированного стимулирования (в которых вознаграждение каждого агента зависит только от его собственных действий или от действий всех агентов). В том случае, когда центр наблюдает только агрегированный результат деятельности команды, он вынужден стимулировать каждого члена команды за результат совместной деятельности. __Ключевым вопросом__, возникающим при рассмотрении такого коллективного стимулирования, по мнению автора (Новиков, 2008), является вопрос о существовании «идеального агрегирования», т. е. при каких условиях существует система стимулирования, которая в условиях ненаблюдаемых центром действий агентов дает центру тот же выигрыш, что и в условиях наблюдаемых действий?

# %% [markdown]
# Нам представляется, что в условиях организационных изменений важность данного вопроса возрастает многократно, поскольку персонифицированный вклад отдельного члена команды в достижение общего результата преобразований может значительно превосходить вклады других агентов, в том числе — агрегированный вклад «остальных» членов команды. Такая трактовка особенностей команд, осуществляющих организационные изменения, в ряде случаев может привести к отказу от модели коллективного стимулирования в рассмотренной постановке. __Таким образом__, анализ современного состояния теории и методологии моделирования процессов организационного развития и организационных изменений продемонстрировал наличие разнообразных теоретико-методологических подходов и развитого экономико-математического и организационно-экономического аппарата математического моделирования организационных систем, в том числе и в контексте их развития. __Тем не менее__ приходится констатировать, что в настоящее время не существует единого теоретико-методологического подхода к обоснованию облика математических моделей динамических процессов организационных изменений, и задача адекватного математического моделирования этих процессов, обеспечивающих развитие организации, окончательно не решена.
#
# Стр. 56
#
# ------

# %% [markdown]
# # Глава 2. Методология математического моделирования процессов организационного развития
# ### 2.1. Феноменологическая модель организационного развития
# Как указывалось выше, под организационным развитием мы будем понимать регулярную, целенаправленную деятельность менеджмента по совершенствованию средств и способов, с помощью которых организация достигает стоящие перед ней цели. В контексте реализации организационное развитие будет рассматриваться как система мероприятий в сфере менеджмента, направленных на осуществление в организации целенаправленных изменений. При этом под целями организационных изменений мы будем понимать формирование такой структурно-функциональной упорядоченности организационной системы, которая обеспечивала бы развитие компании в долгосрочной перспективе, а в краткосрочной — восстановление ее системной устойчивости как баланса между стабильностью и развитием. Процесс организационных изменений, направленных на создание условий для развития организации, может быть представлен следующей обобщенной функциональной схемой (рис. 2.1):

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Рис. 2.1. Обобщенная функциональная схема процесса управления организационным развитием. (Для упрощения схема показана без учета обратных связей между этапами.)
#
# На рис. 2.1 приняты следующие обозначения:
# - Т — стратегические цели развития и повышения конкурентоспособности организации;
# - Р — параметры (планы, рекомендуемые процедуры, требования, нормы и т. п.) организационных изменений;
# - R — зафиксированные результаты организационных изменений;
# - Е — зафиксированные экономические результаты развития организации;
# - М — предпочтения менеджмента относительно выбора модели и методов организационных изменений;
#
# Стр. 57
#
# ------

# %% [markdown]
# - $\gamma_k$ — незапланированные факторы, влияющие на процесс и результаты организационных изменений;
# - $\gamma_K$ — незапланированные факторы, влияющие на процесс и результаты развития организации;
# - $f_1$ — функция обоснования и выбора параметров организационных изменений;
# - $f_2$ — функция осуществления организационных изменений в соответствии с выбранными параметрами;
# - $f_3$ — функция формирования ожидаемых экономических результатов развития организации в условиях завершенных или текущих организационных изменений;
# - F — процесс реализации комплекса организационно-экономических мероприятий, направленных на развитие организации.
#
# Как видно, базовая модель организационного развития может быть представлена следующими выражениями:
# $$P=f_1(T,M);$$ $$R=f_2(P,\gamma_R);$$ $$E=f_3(R,\gamma_E);$$ $$откуда:$$ $$E=F(T,M,P,R,\gamma_R,\gamma_E)$$.

# %% [markdown]
# В данной постановке процесс управления организационным развитием включает в себя два этапа: __во-первых__, этап планирования организационных изменений, т. е. этап формирования требуемых параметров организационных изменений, направленных на развитие организации; __во-вторых__, этап реализации организационных изменений в соответствии с выбранными параметрами. В общем случае этап планирования организационных изменений включает в себя: __во-первых__, выбор базовой модели организационных изменений; __во-вторых__, оценку временного периода осуществления организационных изменений; __в-третьих__, проектирование в соответствии с выбранной моделью организационных изменений таких организационных параметров, как функции, процессы, информационная структура, организационная структура, организационная культура (с учетом предполагаемой динамики, глубины и специфики сопротивления организационным изменениям) и др. __По мнению Райченко Л. В.__, наиболее ярко и разнообразно организационные изменения проявляются в организационных структурах управления, иерархии, распределении полномочий, построении коммуникаций, формировании процедур и осуществлении взаимодействия органов и субъектов управления (Райченко, 2003). Причем, как отмечает автор, реальные организационные изменения неизбежно происходят на уровне конкретного индивидуума, содержательно участвующего в процессе управления организацией. __Детальнее роль__ и место этапа управления организационными изменениями в процессе управления развитием организации могут быть представлены следующей схемой (рис. 2.2) (Михненко, 2010)..
#
# Стр. 58
#
# ----------

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Рис. 2.2. Процесс запланированных организационных изменений, осуществляемых в интересах развития организации
#
# На рис. 2.2 приняты следующие обозначения:
# - Y — факторы внешней среды организации;
# - Х — ситуационные переменные внешней среды, определяющие условия функционирования организации;
# - Т — цели развития и повышения конкурентоспособности организации;
# - Р — параметры (планы, требования, нормы и т. п.) организационных изменений;
# - U — управленческие решения — система задач, норм и требований, формируемых для каждого подразделения (функциональной области, бизнес-единицы и т. п.) организации в соответствии с планом и параметрами организационных изменений;
# - $\zeta$ и $\xi$ — ошибки оперативного оценивания (количественного измерения и содержательной интерпретации менеджментом) текущих экономических результатов развития организации и результатов организационных изменений соответственно;
# - М — предпочтения менеджмента компании относительно выбора модели и методов организационных изменений;
#
# Стр. 59
#
# ---------------------------

# %% [markdown]
# - $\delta R$ — элементарные текущие изменения функций, процессов, организационной структуры и организационной культуры организации, осуществленные в единицу времени;
# - R – сконцентрированные (накопленные до эффективных уровней) и устойчиво проявляющиеся системные результаты организационных изменений;
# - $\delta E$ — элементарные количественные и качественные изменения экономической эффективности организации, позволяющие алекватно оценивать оперативную эффективность осушествляемых организационных изменений и процессов организационного развития в целом, однако не оказывающие заметного (желасмого) влияния на внешнюю среду
# - Е — экономические результаты развития организации — вектор количественных и качественных изменений экономической эффективности компании, оказывающих социально-экономическое, научно-техническое, инфраструктурное и иное влияние на внешнюю среду;
# - $f_1$ — функция обоснования и выбора параметров организационных изменений;
# - $f_2$ — функция осуществления организационных изменений в соответствии с выбранными параметрами;
# - $f_3$ — функция формирования ожидаемых экономических результатов развития организации в условиях завершенных или текущих организационных изменений.
#
# Стр. 60
#
# -----------

# %% [markdown]
# __Например__, если под экономическим результатом развития организации $Е$, оказывающим заметное влияние на внешнюю среду и обеспечивающим укрепление ее конкурентной позиции, понимать существенное увеличение доли рынка, то в качестве оперативного экономического результата $\delta E$ будет выступать выход организации на заданный уровень объемов производства и качества продукции, обеспечивающий в перспективе увеличение доли рынка до желаемого значения. __В рамках рассматриваемой модели__ предполагается, что в отличие от сконцентрированных (накопленных до эффективных уровней) и устойчиво проявляющихся комплексных результатов организационных изменений $R$, элементарные изменения $\delta R$ не оказывают заметного влияния на процессы изменения экономических характеристик организации. __Строго говоря__, большинство текущих (элементарных) организационных изменений могут оказывать достаточно заметное оперативное влияние, в том числе негативное, на различные аспекты деятельности организации, вызывая изменения ее значимых экономических, социальных и других характеристик. __Однако в рассматриваемой модели__ под «элементарными» понимаются такие организационные изменения, учет текущего влияния которых на основные экономические характеристики признается нецелесообразным до завершения переходных процессов или в силу необходимости учета их влияния только в комплексе с другими изменениями. __Предположим__, что под комплексным организационным изменением $R$ понимается смена типа организационной структуры управления (ОСУ), тогда примерами составляющих его элементарных изменений $\delta R$ могут служить: __во-первых__, текущее перераспределение полномочий и ответственности между менеджерами среднего звена; __во-вторых__, прием на работу новых сотрудников; __в-третьих__, изменение территориального расположения подразделений; __в-четвертых__, появление новых департаментов и информационных систем и т. п.

# %% [markdown]
# Очевидно, что для адекватной оценки экономической эффективности $Е$ смены ОСУ потребуется время от нескольких месяцев до года или более. При этом т.н. «элементарные» $\delta Е$ изменения (в том числе негативные, например, падение объемов продаж из-за внедрения новых, недостаточно освоенных процессов или смены персонала) могут последовать в течение двух-трех недель. __Как видно__, рассматриваемые процессы представляют собой совокупность трех контуров управления (см. рис. 2.2):
#
# - $К_1$ — контур управления организационными изменениями;
# - $К_2$ — контур управления развитием организации;
# - $К_3$ — контур управления взаимодействием организации с ее внешней средой.
#
# Управление организационными изменениями (контур $К_1$) представляет собой динамический элемент процесса управления развитием организации (контур $К_2$), который, в свою очередь, является элементом внешнего контура — контура управления взаимодействием организации с ее внешней средой (контур $К_3$).
#
# Стр. 61
#
# ---------

# %% [markdown]
# Таким образом, прослеживается взаимная связь трех циклических процессов: __во первых__, концентрация результатов текущих организационных изменений R приводит к целенаправленному изменению параметров и характеристик функционирования организации (контур $К_1$); __во вторых__, информация о текущих изменениях экономической эффективности $\delta E$ организации может использоваться менеджментом для оперативной корректировки (уточнения) целей организационного развития (контур $К_1$). Говоря о возможности оперативной корректировки менеджментом целей и параметров организационного развития, необходимо принимать во внимание риск ошибочных корректировочных действий, обусловленных недостаточной точностью измерения и интерпретации текуших результатов экономического развития компании, что в рассматриваемой модели описывается случайной переменной $\zeta$ - погрешностью (ошибкой) оценки. __в третьих__, концентрация (накопление и стабилизация) результатов изменений экономической эффективности организации Е оказывает воздействие на ее внешнюю среду, вызывая изменение ее ситуационных переменных Х (т.е. условий функционирования организации). __Такая трактовка__ развития организации представляется наиболее удобной для выявления роли и места процесса организационных изменений как системы мероприятий, призванных создать условия для развития организации в краткосрочной и долгосрочной перспективе с сохранением требуемого уровня экономической стабильности в аспекте закона самосохранения.

# %% [markdown]
# Для описания процессов взаимодействия организации с ее внешней средой примем следующие обозначения: __во-первых__, под факторами ($Y$) внешней среды организации будем понимать элементы ее внешнего окружения: потребители, конкуренты, поставщики, государственные органы и т.п.; __во-вторых__, под условиями ($Х$) функционирования организации во внешней среде будем понимать ситуационные переменные, формируемые и изменяемые факторами внешней среды. __К основным условиям__ (ситуационным переменным) относятся рынки сбыта, научно-технический прогресс, рынок труда, потребительские предпочтения и т.п. Изменение условий оказывает прямое и непосредственное влияние на организацию, обусловливая ее операционную деятельность, конкурентоспособность и стратегическое развитие. __Процесс формирования__ и изменения каждой ситуационной переменной внешней среды, как правило, зависит от действия не одного, а нескольких факторов. Так, формирование и изменение ситуационной переменной «рынок сбыта» обусловлено действием таких факторов, как потребители (их территориальное размещение, потребности, покупательная способность и т.п.); законы, государственные органы и органы местного самоуправления (определяющие условия торговли теми или иными видами товара на той или иной территории); конкуренты и др.
#
# Стр. 62
#
# ----------

# %% [markdown]
# Формирование переменной «развитие науки и техники в сфере деятельности организации» зависит от таких факторов, как научно-исследовательские организации; состояние мировой экономики; законы государства, регулирующие и стимулирующие научные исследования и опытно-конструкторские разработки; инновационная и опытно-конструкторская деятельность организаций-конкурентов и т. п. __Влияние каждого фактора__ внешней среды на формирование (изменение) условий существования организации можно описать так называемыми весовыми коэффициентами $w_{ij}$, указывающими степень и характер влияния $j$-го фактора внешней среды на формирование $і$-го условия (ситуационной переменной). Совокупность весовых коэффициентов __образует матрицу внешней среды $W$__. Таким образом, процесс трансформации факторов внешней среды ($Y$) в ситуационные переменные ($X$) можно условно представить матричным преобразованием $Х = W \times Y$:

# %% [markdown]
# $\begin{pmatrix}x_1 \\ \vdots  \\  x_j \\ \vdots \\ x_n \end{pmatrix}= \begin{pmatrix} w_{11} & \dots & w_{1j} & \dots & w_{1m} \\ \vdots & \vdots & \vdots & \vdots & \vdots \\ w_{i1} & \dots & w_{ij} & \dots & w_{im} \\ \vdots & \vdots & \vdots & \vdots & \vdots \\ w_{n1} & \dots & w_{nj} & \dots & w_{1m} \end{pmatrix} \times \begin{pmatrix}y_1 \\ \vdots \\ y_j \\ \vdots \\ y_m \end{pmatrix} = \begin{pmatrix} w_{11}y_1+\dots+w_{1j}y_j+\dots+w_{1m}y_m \\ \vdots \\ w_{i1}y_1+\dots+w_{ij}y_j+\dots+w_{im}y_m \\ \vdots \\ w_{n1}y_1+\dots+w{nj}y_j+\dots+w_{1m}y_m \end{pmatrix} $; где $w_{ij}\geq0$, $\sum_jw_{ij}=1$

# %% [markdown]
# Каждая ситуационная переменная $х_i$, представляющая собой условие функционирования организации, формируется под влиянием комплекса разнообразных факторов внешней среды с учетом их весовых коэффициентов. Недостаточно полный учет влияния какого-либо из факторов ведет к неадекватной оценке текущей ситуации в анализируемой сфере и динамики изменения внешней среды в целом, что, в свою очередь, влечет за собой ошибки при формировании стратегии развития организации. __В табл. 2.1__ приведены некоторые факторы внешней среды и условия, влияние которых на функционирование и развитие организации традиционно является наиболее заметным. __Матрица $W$ показывает__, что разные факторы внешней среды по-разному действуют на формирование и изменение условий существования организации. Так, основное влияние на характеристики рынков сбыта оказывают компании-конкуренты, потребители, законы государства и состояние мировой экономики, кроме того, заметна роль поставщиков и учредителей компании. Потребительские предпочтения зависят от мнений, образования и особенностей самих потребителей (покупателей), а также от деятельности компаний-конкурентов, состояния мировой экономики и т. п.
#
# Стр. 63
#
# --------

# %% [markdown]
# Таблица 2.1. Матрица $W$ формирования ситуационных переменных внешней среды (условный пример)
#
# |---|---|---|---|---|---|---|---|---|---|---|
# |---|:--|:--|:--|:--|:--|:--|:--|:--|:--|---|
# |---|+++|---|---|---|---|---|---|---|---|$y_1$ Конкуренты|
# |---|---|+++|---|---|---|---|---|---|---|$y_2$ Поставщики и партнеры|
# |---|---|---|+++|---|---|---|---|---|---|$y_3$ Потребители|
# |---|---|---|---|+++|---|---|---|---|---|$y_4$ Законы и государственные органы|
# |---|---|---|---|---|+++|---|---|---|---|$y_5$ Акционеры (учредители)|
# |---|---|---|---|---|---|+++|---|---|---|$y_6$ Трудовые ресурсы общества|
# |---|---|---|---|---|---|---|+++|---|---|$y_7$ Политические изменения|
ономики (10%) и разработками научно-исследовательских организаций (40%). __Очевидно__, что комплекс факторов, формирующих и изменяющих условия существования и развития исследуемой организации (матрицу $W$), следует дополнить еще одним фактором — воздействием самой организации (рис. 2.3). Функционирование организации и изменение ее экономических и иных характеристик в конечном счете могут способствовать созданию как благоприятных, так и неблагоприятных конкурентных условий ее существования и развития. __Таким образом__, динамика, эффективность и результаты процессов в контуре управления взаимодействием организации с ее внешней средой ($К_3$) влияют на соответствующие параметры контура управления развитием организации ($К_2$) и, как следствие, на параметры контура управления организационными изменениями ($К_1$). В свою очередь, параметры контура $К_1$ определяют параметры «внешних» контуров.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Рис. 2.3. Организация как фактор изменения внешней среды
#
# В рамках рассматриваемой модели контур $К_1$ обладает наибольшей динамикой по сравнению с другими контурами управления. От интенсивности целенаправленных организационных трансформаций зависит скорость концентрации результатов изменения экономической эффективности организации, а следовательно, скорость изменения условий ее функционирования во внешней среде. Представление менеджмента о характере воздействий организации на ее внешнюю среду должно лежать в основе выбора моделей и параметров организационных изменений.
#
# Стр. 65
#
# -----

# %% [markdown]
# # 2.2. Интеграция и взаимодействие в процессе организационных изменений
# __Принцип распределенной ответственности__. Первый элемент контура управления организационными изменениями — постановка задач подразделениям (см. рис. 2.2) — представляет собой процесс декомпозиции целей развития компании ($T$) в систему задач, норм и требований, формируемых для каждого подразделения компании ($U$). Строго говоря, учет в данном контуре ошибки оценивания результатов элементарных организационных преобразований не позволяет называть его идеальным. Под «идеальностью» в данном случае понимается строгое следование запланированным параметрам изменений. Причем в идеальном случае этот процесс протекает следующим образом: __во-первых__, в соответствии с выбранными на этапе планирования параметрами организационных изменений ($Р$); __во-вторых__, при наличии у менеджмента оперативной информации о текущем состоянии организационной системы и текущих результатах ее преобразования ($R$); __в-третьих__, в условиях недостаточно достоверной информации, т. е. при наличии ошибок оценивания результатов ($\xi$); __в-четвертых__, при наличии ограниченных ресурсов, выделяемых на осуществление преобразований. __Принцип распределения задач и ресурсов__ между подразделениями организации, назовем его принципом распределенной ответственности, предполагает, что в общем случае каждое подразделение компании должно включать в план своих организационных преобразований каждую из задач, стоящих перед компанией в целом. Под ресурсами будем понимать весь комплекс средств, способных обеспечить процесс организационных преобразований в соответствии с целями организации: материальные, финансовые, человеческие (трудовые), информационные (интеллектуальные, включая технологии производства, оказания услуг и управления), административные (включая возможности делегирования и перераспределения полномочий и ответственности).

# %% [markdown]
# Матричное описание состояний и процессов, имеющих место в ходе организационных изменений, по нашему мнению, наиболее наглядно и полно иллюстрирует их многомерный характер, что позволяет учитывать взаимосвязь задач всех подразделений компании. Математически принцип распределенной ответственности демонстрируется матрицей $D$:
# $$ D = \begin{pmatrix} d_{11} & \dots & d_{1n}  \\ \vdots & \ddots & \vdots  \\ d_{m1} & \dots & d_{mn} \end{pmatrix} = (d_{ji})_{m \times n}; (2.1) $$
# где $d_{ji}$ — требуемая интенсивность решения $i$-й задачи $j$-м подразделением организации, зависящая от целей, а также ресурсной и методологической обеспеченности; $n$ — общее количество целей (задач), стоящих перед организацией на данном этапе; $m$ — общее количество подразделений компании (основных, функциональных и вспомогательных), задействованных в осуществлении организационных изменений.
#
# Стр. 66
#
# -------------

# %% [markdown]
# Например, $d_{11}$ — интенсивность решения первым подразделением первой задачи развития ($с_1$), стоящей перед компанией; $d_{12}$ — интенсивность решения первым подразделением второй задачи развития ($с_2$), стоящей перед компанией; $d_{21}$ — интенсивность решения вторым подразделением первой задачи ($с_1$) и т. д. __Результатом динамического планирования__ организационных изменений, осуществляемых в соответствии с принципом распределенной ответственности, будет система мероприятий $U = (u_j)_{m1}$, состоявшая из $m$ задач $(u_1,u_2,\dots,u_j,\dots,u_m)^T$ — по числу подразделений компании:
# $$U=\begin{pmatrix}u_1 \\ \vdots \\ u_j \\ \vdots \\ u_m \end{pmatrix}=\begin{pmatrix}d_{11}c_1+\dots +d_{1i}c_i+\dots+d_{1n}c_n \\ \vdots \\ d_{j1}+\dots + d_{ji}c_i+\dots+d_{jn}c_n \\ \vdots \\ d_{m1}c_1+ \dots +d_{mi}c_i+\dots+d_{mn}c_n \end{pmatrix}. (2.2)$$
#
# Например, запись задачи первого подразделения: $u_1=d_{11}c_1+\dots+d_{1i}c_i+\dots+d_{1n}c_n$ — указывает на то, что план организационных изменений этого подразделения должен включать в себя все $n$ задач $(c_1,\dots,c_i,\dots,c_n)$, стоящих перед компанией, при этом интенсивности $(d_{11},\dots,d_{1i},\dots,d_{1n})$ решения каждой из задач этим подразделением будут различны и будут определяться принятыми параметрами организационных изменений $Р$ с учетом обратных связей по результатам $R$ преобразований.

# %% [markdown]
# Предположим, что перед компанией стоят следующие взаимосвязанные задачи развития, обеспечивающие ее адаптацию к изменяющимся условиям и переход на новую стратегическую позицию:
#
# - $с_1$ - диверсификация производимой продукции;
# - $с_2$ - применение в производстве новейших достижений НТП;
# - $с_3$ - создание собственной сбытовой сети;
# - $с_4$ - формирование корпоративной культуры, способствующей эффективному внедрению инноваций в производстве и управлении.
#
# Обозначим планы организационных изменений подразделений (функциональных областей) компании:
#
# - $u_1$ - производства;
# - $u_2$ - $HR$ - департамента;
# - $u_3$ - отдела продаж (сбыта);
# - $u_4$ - НИОКР;
# - $u_5$ - финансового отдела;
# - $u_6$ - департамента маркетинга и рекламы.
#
# Структурно матрица $D$ в этом случае будет иметь вид $(d_{ji})_{6\times4}$, где $m = 6$ — количество подразделений, вовлеченных в процесс преобразований; $n = 4$ — количество стратегических задач (частей стратегического плана развития компании).
#
# Стр. 67
#
# ------

# %% [markdown]
# Рассмотрим план организационных изменений производственной функции компании: $u_1=d_{11}c_1+d_{12}c_2+d_{13}c_3+d_{14}c_4$. __Слагаемые__ в правой части выражения представляют собой четыре части плана $u_1$ организационных изменений, осуществляемых производственным отделом компании. Как видно, в соответствии с принципом распределенной ответственности для процесса организационных изменений производственной функции компании должны быть характерны следующие интенсивности: $d_{11}$ — диверсификации продукции; $d_{12}$ — применения в производстве новейших достижений НТП; $d_{13}$ — создания сбытовой сети; $d_{14}$ — формирования корпоративной культуры, способствующей эффективному внедрению инноваций в производстве и управлении. __Первая__ $d_{11}с_{1}$ и __вторая__
ексте их соответствия целям развития компании. Например, если $c_i$ — цель, заключающаяся в формировании корпоративной культуры, которая будет способствовать эффективному внедрению инноваций в производстве и управлении, то $р_i(*)$ будет задавать следующую систему требований: рост профессиональных компетенций сотрудников; доминирование в коллективе экспертной модели лидерства; снижение бюрократизации управления; формирование адхократических ОСУ в подразделениях, отвечающих за инновации и технологии, и т. п. Тогда вектор рассогласования $(d_i)_{n\times 1}$ будет представлять собой комплекс сведений, показывающих в контрольные промежутки времени, насколько полно и качественно реализуются эти требования.

# %% [markdown]
# С учетом рассмотренного замечания система динамически формируемых задач $U(t)$ формально может быть представлена в виде.
#
# $$U=\begin{pmatrix} u_1(t) \\ \vdots \\ u_j(t) \\ \vdots \\ u_m(t) \end{pmatrix}= \begin{pmatrix} d_{11}\delta_1(t)+\dots+d_{1i}\delta_i(t)+\dots+d_{1n}\delta_n(t) \\ \vdots \\ d_{j1}\delta_1(t)+\dots+d_{ji}\delta_i(t)+\dots+d_{jn}\delta_n(t) \\ \vdots \\ d_{m1}\delta_1(t)+\dots+d_{mi}\delta_i(t)+\dots+d_{mn}\delta_n(t)  \end{pmatrix}; (2.3)$$
#
# Где аргумент времени $t$ указывает на то, что сам процесс формирования задач подразделениям в ходе организационных преобразований имеет динамический, изменяющийся характер. __Динамический характер__ формирования задач подразделениям показывает, насколько сложен и ответственен данный этап управления изменениями. Тем не менее именно такой замкнутый контур управления даст возможность вовремя вносить коррективы в процесс управления изменениями. Эффективность управления контуром $К_1$ определяет в конечном счете эффективность управления развитием компании с учетом ее влияния на внешнюю среду.
#
# Стр. 70
#
# ----------

# %% [markdown]
# Как видно, матрица задач (2.2) демонстрирует директивный характер распределения оперативных задач между подразделениями на основе целей развития ($С$), формулируемых и декларируемых топ-менеджментом компании. Матрица задач (2.3), построенная на основе контура $U → \delta R → R → U$, отражает тот факт, что в процессе осуществления организационных изменений менеджменту подразделений делегируется право принятия самостоятельных решений по корректировке этого процесса. Подробнее о способах распределения оперативных задач между подразделениями см. в п. 2.3.

# %% [markdown]
# __Оперативная интеграция подразделений__. Очевидно, что чем больше аспектов деятельности компании вовлекается в организационные преобразования, тем более активной будет реакция организационной системы на изменения внешней среды. Однако, помимо числа вовлеченных элементов, большое значение имеет степень их взаимодействия. Иными словами, содержание и эффективность преобразований в организации, помимо всего прочего, определяются типом и особенностями ее структуры. __С какой же целью и каким образом__ подразделения компании должны решать поставленные перед ними «неявные» задачи? Решение подразделениями «неявной» задачи позволяет компании консолидировать усилия всех функциональных и вспомогательных подразделений при решении общих задач, достигая организационной конвергенции. Конвергенция оказывается возможной посредством рациональной интеграции подразделений. __Под текущей__ (оперативной) интеграцией подразделений будем понимать обоснованный выбор возможных координационных механизмов их взаимодействия в интересах эффективного осуществления запланированных организационных изменений. В рассматриваемой модели (см. рис. 2.2) интеграция представляет собой второй элемент (этап) контура $К_1$, отвечающий за решение взаимосвязанных задач, стоящих перед подразделениями, и получение текущих элементарных результатов организационных преобразований ($\delta R$). __Математически систему интеграции__, заключающуюся в совместной координации усилий подразделений по решению общих задач, можно представить матрицей:
#
# $$I=\begin{pmatrix} i_{11} & \dots & i_{1m} \\ \vdots & \ddots & \vdots \\  i_{m1} & \dots & i_{mm} \end{pmatrix} =(i_{jj})_{m \times m}$$

# %% [markdown]
# Как видно, матрица интеграции является квадратной $m \times m$, где $m$ — количество подразделений компании. Рассмотрим содержательный смысл элементов этой матрицы: __во-первых__, $i_{11}$ — внутренние интеграционные (координационные) усилия первого подразделения, направленные на обеспечение высокой эффективности собственной («очевидной») части организационных преобразований; __во-вторых__, $i_{12}$ — интеграция (координация деятельности) первого и второго подразделений, осуществляемая в интересах организационных преобразований первого подразделения; __в-третьих__, $i_{21}$ — интеграция (координация деятельности) второго и первого подразделений, осуществляемая в интересах организационных преобразований второго подразделения и т. п. __В рамках__ рассмотренного выше примера: __во-первых__, $i_{11}$ — внутренние интеграционные (координационные) усилия производственного отдела, направленные на обеспечение высокой эффективности процесса обновления производственного оборудования или технологий; __во-вторых__, $i_{12}$ — интеграция (координация деятельности) производственного отдела и HR-департамента, направленная на согласование и совместную формулировку требований, предъявляемых к производственному персоналу (рабочим, технологам, инженерам и т. п.). Скоординированная работа этих двух подразделений, например, может позволить производственному отделу избежать необходимости привлекать к работе недостаточно квалифицированных специалистов; __в-третьих__, $i_{21}$ — также представляет собой координацию деятельности производственного отдела и HR-департамента, направленную на согласование и совместную формулировку требований, предъявляемых к производственному персоналу. Однако в этом случае интеграция этих двух подразделений позволяет HR-департаменту избежать затрат времени и иных ресурсов на поиск и наем персонала, не вполне удовлетворяющего требованиям производственного отдела.
#
# Стр. 71
#
# -----------------

# %% [markdown]
# Другими словами, матрица интеграции — это система горизонтальной координации процесса решения общих задач компании. В общем случае принцип распределенной ответственности предполагает, что необходимость в интеграции не ограничивается лишь горизонтальной координацией подразделений, более сложные модели могут учитывать вертикальные и диагональные связи. __Содержательно матрица__ интеграции представляет собой таблицу, количественно описывающую степень взаимодействия подразделений при решении задач организационных изменений (табл. 2.2). Степень взаимодействия подразделений может оцениваться условными единицами в диапазоне от 0 (полное отсутствие взаимодействия) до 1 (максимально возможное взаимодействие). __Как указывается__ (Волкова и др., 2012), «коренным образом должно быть улучшено сотрудничество персонала (например, в рабочих группах). По мере надобности сотрудник должен иметь средства коммуникации с любым коллегой». __Данный пример__ демонстрирует вариант оперативного состояния организационной структуры компании, при котором ее производственные подразделения практически не взаимодействуют с HR-подразделениями ($i_{14} = i_{41} = 0$). Степень взаимодействия финансового и производственного отделов можно назвать средней ($i_{12} = i_{21} = 0,5$), а наиболее «плотным» взаимодействием характеризуется совместная работа финансовой и маркетинговой функциональных областей ($i_{23} = i_{32} = 0,7$).
#
# Стр. 72
#
# --------

# %% [markdown]
# Таблица 2.2. Взаимодействие подразделений организации (условный пример)
# ||Производство|Финансы|Маркетинг|Персонал|
# |---|---|---|---|---|
# |Производство|1,0|0,5|0,2|0,0|
# |Финансы|0,5|1,0|0,7|0,1|
# |Маркетинг|0,2|0,7|1,0|0,2|
# |Персонал|0,0|0,1|0,2|1,0|
#
# Степень внутренней интеграции (координации деятельности) каждого подразделения оценивается единицей (диагональные ячейки матрицы). В более сложных моделях возможен учет особенностей внутреннего взаимодействия каждого подразделения. При этом диагональные ячейки могут принимать значения меньше единицы, указывая тем самым на более низкий уровень внутреннего взаимодействия персонала и структурных образований подразделения (функциональной области).

# %% [markdown]
# Какие же типы координационных механизмов и способы интеграции подразделений следует считать наиболее эффективными для осуществления организационных изменений? Что понимается под оптимальностью интеграции? В соответствии с методологией Г. Минцберга (Минцберг, 2010) можно выделить пять степеней интеграции для различных форм (масштабов) организационного взаимодействия (табл. 2.3). __Принцип распределенной ответственности__ в сочетании с принципом интеграции подразделений представляет собой наиболее общую модель распределения задач в ходе осуществления организационных изменений. Однако такой подход вряд ли можно назвать широко распространенным в бизнес-практике. __Большинство современных компаний__ имеет функциональную или линейно-функциональную структуру с количеством уровней иерархии от 2 до 6 (Широкова и др., 2006). Одним из основных недостатков таких структур является недостаточное понимание менеджментом функциональных подразделений общих целей развития компании. Тезис «недостаточное понимание» указывает здесь не столько на отсутствие у менеджмента среднего звена информации о генеральном направлении развития компании, сколько на наличие условий, побуждающих руководителей концентрировать свое внимание на решении лишь "очевидных" задач своих подразделений без учета необходимого уровня интеграции с другими подразделениями.
#
# Стр. 73
#
# ------

# %% [markdown]
# Таблица 2.3. Формы организационного взаимодействия, предполагающие различные степени коорлинации
#
# |---|(Формы организационного взаимодействия)| (Формы организационного взаимодействия)|(Формы организационного взаимодействия)|---|
# |:--|:--|:--|:--|:--|
# |Степень интеграции (условный коэффициент)|В масштабе подразделений, групп и отдельных сотрудников|В масштабе функциональных областей и бизнес-единиц организации|В масштабе групповых организационных форм|Основной координационный механизм по Г. Мининбергу (Минцберг, 2010).|
# |1) Максимальная интеграция (0,8-1,0)|Рабочие команды| Адхократия (матричные и проектные структуры, значительный поток неформальных коммуникаций) | Комбинаты, вертикально интегрированные структуры и т.п. | Взаимное согласование |
# |2) Высокий уровень интеграции (0,6-0,8)|Постоянные интеграторы, связующие должностные позиции|Простая структура (централизация, значительный поток неформальных коммуникаций)|Концерны, финансово-промышленные группы и т.п.|Прямой контроль|
# |3) Средний уровень интеграции (0,4-0,6)|Временные рабочие группы, постоянные комитеты|Профессиональная организация (значительный поток неформальных коммуникаций на уровне основного ядра)|Холдинги|Стандартизация квалификации|

# %% [markdown]
# |---|(Формы организационного взаимодействия)| (Формы организационного взаимодействия)|(Формы организационного взаимодействия)|---|
# |:--|:--|:--|:--|:--|
# |Степень интеграции (условный коэффициент)|В масштабе подразделений, групп и отдельных сотрудников|В масштабе функциональных областей и бизнес-единиц организации|В масштабе групповых организационных форм|Основной координационный механизм по Г. Мининбергу (Минцберг, 2010).|
# |4. Низкий уровень интеграции (0,2-0,4)|Временные прямые контакты|Механистическая бюрократия (функциональная структура, слабые неформальные коммуникации)||Стандартизация труда|
# |||Дивизиональные структуры|Конгломераты, консорциумы, картели и т.п.| Стандартизация выпуска|
# |5. Крайне низкий уровень (0,0-0,2)|Информационные системы, удаленные сотрудники (freelancers)|Аутсорсинг|Франчайзинг|Стандартизация выпуска|

# %% [markdown]
# Большое количество уровней иерархии при высокой степени централизации управления приводит к снижению интеграционной активности менеджеров функциональных и вспомогательных подразделений по причине отсутствия у них полномочий по принятию самостоятельных решений. Частично устранить этот недостаток позволяет децентрализация и наличие неформальных горизонтальных связей. Высокая степень взаимодействия характерна для матричных и многомерных структур. __В этой связи__ заслуживает внимание мнение И. Адизеса: «Я всегда утверждал, что организация начинает стареть, когда лишается предпринимательского духа. Сейчас я считаю иначе. Прежде чем уходит предпринимательство, у компании начинаются проблемы с интеграцией» (Адизес, 2008).

# %% [markdown]
# В большинстве случаев слабая интеграция подразделений приводит к проявлению эмерджентности — расхождению целей подразделений с общими целями организации. Наличие же взаимодействия приводит к позитивному результату — проявлению мультипликативности и синергетического эффекта. Однако неоправданная интенсификация информационного обмена между частями организации или необоснованная концентрация полномочий в одной из частей компании зачастую не только не устраняет противоречия, но и усугубляет их. В ряде случаев именно упрощение внутренних отношений приводит к повышению организационной устойчивости. Так, Р. Акофф делает вывод, что интенсификация информационного обмена вопреки традиционной мудрости не устраняет, а лишь углубляет конфликт (Акофф, 2002). На этот же аспект обращал внимание и А.А. Богданов, утверждая, что на основе упрощения внутренних отношений системы происходит повышение ее организационной прочности и устойчивости (Богданов, 1989).

# %% [markdown]
# Такое понимание роли интеграции между частями (сферами деятельности) организации позволяет сформулировать предположение об оптимальном взаимодействии при осуществлении организационных изменений. Таким образом, в процессе осуществления организационных изменений возможно создание условий для оптимального взаимодействия подразделений. __Поскольку оперативная интеграция__ имеет динамический характер, это обстоятельство позволяет рассматривать контур К как процесс формирования оперативных (временных) организационных структур, состав и характер связей внутри которых является оптимальным именно для данного (текущего) этапа управления организационными изменениями. В рассматриваемой постановке критерием оптимальности таких временных структур является минимум рассогласования $\Delta = (\delta_i)_{n \times i}$, хр. Очевидно, что динамика и характер интеграционных процессов в компании зависят от целого ряда условий, наиболее значимым из которых является тип процесса организационных изменений.
#
# Стр. 75
#
# ------

# %% [markdown]
# В самом общем случае любое элементарное организационное изменение $\delta r_j$, реализованное в $j$-м подразделении, является результатом работы всех подразделений организации, благодаря координации их деятельности в интересах $j$-го подразделения. Очевидно, что тип и глубина интеграции каждого подразделения с каждым из других подразделений компании должны зависеть от характера, сложности и срочности совместно решаемых задач. Таким образом: __во первых__, эффективность каждого элементарного организационного изменения, реализованного в подразделении, зависит от согласованности действий всех подразделений компании; __во вторых__, согласованность действий возможна в условиях наиболее благоприятной интеграции подразделений в интересах решения данной залачи и при наличии у менеджмента подразделений права принятия решений на тех уровнях, где сконцентрированы необходимые квалификация и информация; __в третьих__, реализация принципа «распределенной ответственности» в сочетании с оптимальной оперативной интеграцией подразделений является условием осуществления эффективных организационных изменений в интересах развития компании и повышения ее конкурентоспособности; __в четвертых__, формирование методологического аппарата оптимизации оперативной интеграции является актуальной задачей современной теории организации и менеджмента.

# %% [markdown]
# # 2.3. Динамическая математическая модель организационного развития
# Предлагаемый подход к математическому моделированию процессов организационного развития и связанных с ними процессов организационных изменений базируется на следующих гипотезах: __во первых__, организационное развитие представляет собой процесс адаптации экономических характеристик предприятия к изменениям внешней среды; __во вторых__, организационные изменения являются необходимым элементом (внутренним контуром) процесса организационного развития; __в третьих__, под управлением организационными изменениями понимается обеспечение минимума текущих рассогласований между оперативными результатами изменений и их запланированными значениями (характеристиками); __в четвертых__, эффективность организационных изменений обусловлена эффективностью распределения задач между подразлелениями и их координации (интеграции); __в пятых__, для процесса эффективных изменений характерно соблюдение "принципа распределенной ответственности".
#
# Стр. 76
#
# --------

# %% [markdown]
# В качестве основного тезиса, определяющего понятие «организационная структура» в контексте организационных изменений, рассматривается определение Г. Минцберга: «Структуру организации можно определить как простую совокупность способов, посредством которых процесс труда сначала разделяется на отдельные рабочие залачи, а затем достигается координация действий по решению этих задаче. __Приведем следующую классификацию__ типов организационных систем и их моделей (Ackoff и др., 1996): __во первых__, детерминированные - системы и модели, которые ни сами в целом, ни их части не являются целенаправленными; __во вторых__, анимационные (одушевленные, организматические) - системы и модели, которые в целом преследуют некие цели, а их части являются нецеленаправленными; __в третьих__, социальные (общественные) - системы и модели, в которых как их части, так и они в целом являются целенаправленными.

# %% [markdown]
# Рассматривая применимость каждой из трех моделей к анализу организаций, Р. Акофф делает вывод о том, что плохая работа организаций обусловлена либо недостатком информации, либо помехами в каналах связи. Следовательно, необходимым было предоставление все больших объемов информации и всемерное совершенствование связи. К сожалению, когда мы сталкиваемся со сложностями усиления социальных взаимодействий и взаимозависимостей, такой образ мышления оказывается неэффективным. Система не желает признать, что члены организации в отличие от частей организма имеют возможность выбора и отнюдь не пассивно реагируют на получаемую информацию. __Использование моделей анимационных__ систем для анализа современных организаций, по мнению Р. Акоффа, так же не адекватно, как и применение детерминированных моделей. Модель организации как социальной системы в максимальной степени свободна от недостатков астерминированных и анимационных (организматических) подходов.

# %% [markdown]
# К основным принципам адаптивных организаций, по мнению Р. Акоффа, относятся следующие: __во первых__, демократичность организации, заключающаяся в том, что каждый ее элемент заинтересован в достижении общеорганизационных целей, а индивидуальная власть подчиняется коллективной; __во вторых__, принципы внутреннего рынка, характеризующие «проецирование» рыночных отношений на внутреннюю среду организации, что даст каждому подразделению значительную степень "рыночной" автономии и самостоятельности; __в третьих__, многомерность организационной структуры, предполагающая создание (на основе первых двух принципов) структурных единиц трех разных видов: 1) по функциям - единицы, продукция которых потребляется «внутренним рынком» организации, 2) по продукции - сдиницы, продукция которых потребляется внешним рынком; 3) по потребителям - единицы, деятельность которых ориентируется на рынки, определяемые группами потребителей и их территориальным размещением; __в четвертых__, интерактивное планирование, включающее в себя «определение наиболее реализуемого приближения к проекту». Под интерактивным планированием в общем случае понимается формирование динамических процедур определения степени соответствия внутренней среды организации тем требованиям, которые предъявляет к ней изменяющаяся внешняя среда. Планирование предполагает выбор и рациональное распределение ресурсов, обеспечивающих заданное «приближение», а также определение периодов адаптационных преобразований, исполнителей и системы контроля; __в пятых__, система реализации решений, включающая в себя фиксацию ожиданий, обработку информации, на которой основываются ожидания, рационализацию процесса принятия решения, выполняет непрерывное слежение за окружающей средой для обнаружения произошедших изменений или изменений, которые могут произойти и потребовать адаптации организации.
#
# Стр. 77
#
# ----------

# %% [markdown]
# Анализируя достоинства многомерных организационных структур, в наибольшей степени отвечающих требованиям адаптивности, Р. Акофф делает вывод о том, что такой тип организации устраняет необходимость постоянных реструктуризаций, которые заменяются перераспределением ресурсов. Замена (в общем случае частичная) постоянной рестуктуризации процедурой рационального распределения ресурсов позволяет значительно повысить эффективность процесса адаптации организации. __Однако говоря__ о необходимости «следящих» свойств организационной системы, под «следящим механизмом» Р. Акофф понимает систему, модель которой не предполагает стохастического подхода к обоснованию критериев оптимальности: «эффективность следящих механизмов основана на том, что они не имеют права выбора и могут только реагировать заранее определенным образом на события в окружающей их среде». __Такая трактовка__ следящих свойств, по существу, возвращает модель адаптации к детерминированным основам. Поэтому приведенный выше перечень свойств, характеризующих принципы моделирования адаптивных организационных структур, следует дополнить принципом стохастического (вероятностного) моделирования, который заключается в необходимости формулировки критерия оптимальности (эффективности) таких систем в виле функционала, зависящего от верояткостных характеристик процееса адаптации. __Как указывалось выше__, управление организационными изменениями представляет собой внутренний контур процесса управления развитием (ем. рис. 2.2). В динамическом аспекте взаимосвязанные процессы (организации с внешней средой, организационного развития и управления организационными изменениями) можно представить в виле схемы, приведенной на рис. 2.4.
#
# Стр. 78
#
# -------------

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Рис. 2.4. Взаимосвязанные процессы организационного развития
#
# В соответствии с моделью (см. рис 2.2) и с учетом рис. 2.4 функциональная схема модели организационного развития может быть представлена в виде рис. 2.5.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Рис. 2.5. Функциональная схема модели организационного развития
#
# На рис. 2.5 приняты следующие обозначения:
# - $W$ — матрица, формирующая вектор Х условий внешней среды, оказывахних влияние на организацию (См. п. 2.1.):
# $$X= \begin{pmatrix} x_1 \\ \vdots \\ x_l \\ \vdots \\ x_L \end{pmatrix}=(x_l)_{L \times 1} $$
#
# - G - матрица развития, формирующая вектор Р планов и параметров организационных изменений как функция целей развития $T$ и компетенций (предпочтений) менеджмента М: $P=G(T,M)=G(X,\zeta,M);$
#
# - $\zeta$ - многокомпонентная информационная погрешность оценивания результатов мониторинга процесса организационных изменений - центрированная случайная величина с известной интенсивмостью $insv[\zeta]$:
#
# Стр. 79
#
# ------

# %% [markdown]
# Интегральная зависимость $R(t)=\int_{t_0}^t U(t)dt$ ; $R(t_0)=R_0$ ;
#
# - $А$ - матрица адаптации предприятия, определяющая интенсивность организационных изменений в соответствии с задачами развития. Здесь под интенсивностью изменений понимается требуемая скорость осуществления организационных преобразований, а также степень залействования сотрудников, рабочего времени, финансовых и иных ресурсов;
#
# - $С_{ij}$ , — матрица конвертации результатов $R$ организационных изменений в соответствующие вектора с согласованием их размерностей;
#
# - $С_R=(с_{r_i})_{n \times m}$ - - матрица интерактивного планирования организационных изменений, т.с. матрица конвертации вектора $R = (r_j)_{m \times 1}$ -к, в вехтор $R^* = (r^*_i)_{n \times 1}$ для согласования с размерностью вектора $Р = (p_i)_{n \times 1}$;
#
# - $С_K =(c_{r_i})_{L \times m} $ еха - матрица интерактивного планирования развития организации, т.с. матрица конвертации вектора $R = (r_j)_{m \times 1}$, в вектор $Е = (е_i)_{L \times 1}$ , оперативной экономической эффективности осуществлясмых организационных изменений и процессов организационного развития в целом описывает процесс накопления результатов организационных изменений в ответ на управленческое воздействие, где $U(t)$ - вектор управлення процессом преобразований. Таким образом, на интервале преобразований $[t_0;t]$: $U(t)=\frac{dR}{dt}$
#
# Стр. 80
#
# ------------

# %% [markdown]
# Содержательно производная $\frac{dR}{dt}$ представляет собой элементарный результат организационных изменений $\delta R$, полученный в единицу времени. Остальные обозначения соответствуют обозначениям, принятым на (рис. 2.1, 2.2). Для удобства дальнейшего математического описания процессов организационных изменений функциональная схема математической молели может быть приведена к следующему виду (рис. 2.6).

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Рис. 2.6. Функциональная схема математической модели организационных изменений
#
# Тогда вектор результатов мониторинга процесса организационных изменений $\Delta = (\delta _i)_{n \times 1} $ - многокомпонентное рассогласование между плановыми $Р = (p_i)_{n \times 1}$ и текущими фактическими результатами изменений $R = (r_j)_{m \times 1})$ будет определяться выражением: $\Delta = P-C_RR$ (2.4). __На схеме__ (рис. 2.6) матрица А адаптации предприятия, определяющая интенсивность организационных изменений в соответствии с задачами развития, представляет собой произведение $A=(a_{ji})_{m \times n} = IS = (i_{jj})_{m \times m} \times (s_{ji})_{m \times n}; (2.5) $  где $I = (i_{jj})_{m \times m}$ — матрица оперативной интеграции (координации деятельности) подразделений; $S =(s_{ji})_{m \times n}$ — матрица компетентности сотрудников, интерпретируемая как способ распределения задач между подразделениями. Матрица А имеет вид
#
# $$A=\begin{pmatrix} a_{11} & \dots & a_{1n} \\ \vdots & \ddots & \vdots \\ a_{m1} & \dots & a_{mn} \end{pmatrix}; (2.6) $$
#
# где $a_{11}=i_{11}s_{11}+i_{12}s_{21}+\dots +i_{1i}s_{j1}+\dots+i_{1m}s_{m1}$ - интенсивность организационных изменений, осушествлясмых 1-м подразаслением при решении 1-й задачи развития; i_{11} - внутренняя интеграция сотруников 1-го подразделения; $s_{11}$ - компетенции сотрудников 1-го подразеления в отношении 1-й залачи развития; $i_{1j}$ — интеграция 1-го и j-го подразаслений в интересах решения 1-м подразелением 1-й задачи; $s_{j1}$ — компетенции j-го полразлеления в отношении 1-й залачи и т.п.
#
# Стр. 81
#
# ---------

# %% [markdown]
# Выбор стохастической модели следящей системы (рис. 2.6) для исследования адаптивных возможностей хозяйственных организаций обусловлен достаточно высокой адекватностью этой модели при описании процессов, протекающих в компаниях органического типа, работающих в условиях высокоподвижной и сопределенной внешней среды. Именно возможность гибкого реагирования на внешкие изменения отличает такие организации от механистических структур, для которых характерна высокая инерционность и отсутствие необходимой гибкости. __Важно подчеркнуть__, что наличие замкнутого («следяшего») контура в модели организационных изменений ни в коей мере не указывает на исключительно реактивный характер адаптивных организационных преобразований и организационного развития в целом. Контур с обратной связью $Р → \Delta → U → R → R^* → Р$ отражает лишь стремление менеджмента к осуществлению программы организационных изменений в максимально точном соответствии с ее параметрами. При этом содержание и параметры самой программы преобразований могут быть обусловлены представлениями менеджмента о характере как текущих, так и перспективных изменений внешней среды и целей организации. __Формирование построенной__ на основе прогнозов развития внешней среды программы внутриорганизационных изменений и вытекающих из этого прогноза стратегических целей может говорить о проактивном подходе к управлению организационным развитием, что нисколько не противоречит задаче минимизации отклонений текущих результатов организационных изменений от заданных значений, построенных на основе программы проактивного управления развитием организации.
#
# Стр. 82
#
# --------------

# %% [markdown]
# Как следует из (2.4), $lim_{C_RR\to P}\Delta=0$, откуда $С^{opt}_R=arg(P-C_RR=0)$, где $С^{opt}_{1i}$ — оптимальное значение матрицы интерактивного планирования по критерию минимума рассогласования $\Delta$. __В ряде задач__ матрица $С_R= (с_{r_{ij}})_{n \times m}»$ может рассматриваться в качестве матрицы ресурсного обеспечения процесса организационного развития. В этом случае оптимальное значение этой матрицы по вышеуказанному критерию будет иметь вид
#
# $$C^{opt}_R=\frac{1}{m}\begin{pmatrix} \frac{p_1}{r_1} & \dots & \frac{p_1}{r_m} \\ \vdots & \ddots & \vdots \\ \frac{p_n}{r_1} & \dots & \frac{p_n}{r_m} \end{pmatrix}$$
#
# Откуда следует весьма важный вывод в контексте методологии организационных изменений: $\lim\limits_{R(t)\to 0} С_R^{opt}=\infty$ т. с. снижение результативности $R(f)$ организационных изменений, направленных на оперативную оптимизацию внутренней среды орга-низашии в ходе реализации программы организационного развития, приводит к неограниченному росту необходимого ресурсного обеспечения программы развития.

# %% [markdown]
# Математическая модель демонстрирует, что развитие организации оказывается практически невозможным без управления процессом целенаправленных организационных изменений внутренней среды. Рост результативности R внутриорганизационных изменений, обеспечивающих эффективность процесса развития организации, приводит к уменьшению необходимого значения матрицы С, ресурсного обеспечения процесса адаптации. При этом результаты организационных изменений зависят от значения динамически формируемой матрицы адаптации (А). __Управление компетенциями персонала__ в процессе организационных изменений. Статическая («административная») модель управления изменениями предполагает, что в соответствии с принципом распределенной ответственности матрица $S=(s_{ji})_{m \times n}$ , эквивалентна матрице $D=(d_{ji})_{m \times n}$ (2.1) и содержательно представляет собой систему адми стративного распределения задач и ресурсов между подразлелениями, участвующими в осуществлении изменений, где $s_{ji}$, — требуемая интенсивность решения $i$-й залачи $j$-м подразделением, зависящая от целей, административных решений, а также ресурсной и методологической обеспеченности процесса организационных изменений. В этом случае задачи организационного развития распределяются между подразделениями в соответствии с имеющейся организационной структурой. Основной тезис: структура формирует компетенции и ответственность.
#
# Стр. 83
#
# ---------------

# %% [markdown]
# Как подчеркивает Райченко (Райченко, 2003), административно устанавливаемый порядок не допускает своего изменения без причин, просто так. Он сосредоточивает максимум регламентирующих и контролирующих усилий на возврашение живой, развиваюшейся коммуникации в прокрустово ложе- запланированных связей. При этом основной ущерб наносится не излишними затратами на администрирование, а реальной потерей возможностей естественных и уже поэтому во многом более перспективных организационных изменений. __Обшеизвестна эффективность специализации__, концентрации отдельного сотрудника на решении лишь определенного класса проблем (Воронин и др., 2008). В то же время специализация порождает проблемы координации, поиска специалиста, который может решить конкретную проблему. Как оказывается, организация сотрудников в форме иерархии представляет собой весьма эффективный способ координации. Главной проблемой при построении иерархии является поиск компромисса между эффективностью использования знаний и затратами на координацию.

# %% [markdown]
# Динамическая («компетентностная») модель в соответствии с принципом распределенной ответственности позволяет трактовать $S = (s_{ji})_{m \times n}$ как матрицу компетенций сотрудников, а в динамическом аспекте - обучения и приобретения ими навыков. Основной тезис: компетенции и ответственность формируют структуру. В этом случае матрица компетентности зависит от времени (этапа) организационных изменений. В модели с непрерывным временем эта матрица будет иметь вид
#
# $$S(t)=(s_{ji}(t))_{m \times n}=\begin{pmatrix} s_{11}(t) & \dots & s_{1n}(t) \\ \vdots & \ddots & \vdots \\ s_{m1}(t) & \dots & s_{mn}(t) \end{pmatrix}$$
#
# где $t=[t_0;t_3]$ - текущее время; $t_0$ — момент начала изменений; $t_3$ - момент завершения изменений. В модели с дискретным временем $S[k]=(s_{ji})_{m \times n}$  где $k = \overline{1,К} $ - номер этапа организационных изменений.
#
# Стр. 84
#
# ---------

# %% [markdown]
# Изменение компетенций персонала, принимающего участие в организационных изменениях, признается не только как явление, сопровождающее процесс запланированных адаптационных преобразований, но и как обязательный элемент, обеспечивающий их эффективность (Волкова и др., 2012). Например, концепция хозяйственного реинжиниринга оперирует понятиями «профессионал процесса» и «уполномоченный сотрудник», отражающими значение прироста компетентности сотрудников в процессе изменений. __Исходя из предположения__, что организация, подразделение, менеджер и сотрудники на каждом новом этапе реализации запланированных организационных изменений приобретают определенный опыт и навыки, изменение затрат ресурсов (например, трудозатрат) на осуществление изменений можно описать следующим выражением (Просветов, 2008): $s_{ji}[k+1]=s_{ji}[k][k+1]^q$ , где q - показатель степени, характеризующий скорость снижения затрат ресурсов, q < 0.

# %% [markdown]
# Представляется важным дополнить это выражение показателем минимально возможных трудозатрат (МВТ) на выполнение базовых операций $s^o_{ji}$, тогда $s_{ji}[k+1]=s^o_{ji}+s_{ji}[k][k+1]^q$ причем в частном случае показатель МВТ может быть единым для всех подразделений: $s^o_{ji} =s^o$. Оценка $L$ уровня обучения (приобретения опыта) подразделения базируется на предположении об удвоении производительности труда (Просветов, 2008), что в нашем случае имеет вид
#
# $$l_{ji}=\frac{s_{ji}[k+1]}{s_{ji}[k]}=\frac{q^qs_{ji}[k]}{s_{ji}[k]}=2^q ;$$
#
# $$lg(l_{ji})=lg(2^q) ; q=\frac{lg(l_{ji})}{lg(2)} .$$
#
# Откуда $s_{ji}[k+1]=s^o_{ji}+s_{ji}[k][k+1]^{\frac{lg(l_{ji})}{lg(2)}}=s^o_{ji}+s_{ji}[k][k+1]^{3,32 lg(l_{ji})}$ Оценка $l$ уровня обучения (приобретения опыта) подразделения,
# выраженная в процентах или в долях единицы, означает, что на каждом последующем этапе изменений подразделение затрачивает $l%$ ресурсов (времени) от затрат предыдущего периода.

# %% [markdown]
# Предположим, что уровень обучения $j$-го подразделения в процессе решения $і$-й задачи организационных изменений $l_{ji} = 80%$, а в качестве затрат ресурсов рассматривается время (в часах), затрачиваемое на одну типовую операцию. Тогда при $s_{ji}[l]=10 ч $ и $s_{ji}^o = 2 ч $, - кривая обучения будет иметь вид, показанный на рис. 2.7. __Выражение (2.7)__ описывает процесс снижения затрат времени на основные операции за счет накопления опыта персоналом и выхода затрат на уровень максимальных возможностей подразделения. Однако применительно к процессу осуществления организационных изменений это выражение имеет существенный недостаток - отсутствует возможность учета новизны каждой операции, что как раз и отличает организационные изменения от привычных производственных процессов.
#
# Стр. 85
#
# ---------

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# На рисунке возможна опечатка $S_k$ или $S_{ji}$ - разберайтесь сами
#
# Рис. 2.7. Кривая обучения
#
# Дополним выражение (2.7) коэффициентом новизны $q_{new}[k]$, полагая его случайной величиной, равномерно распределенной на интервале $[1,q^{max}_{min}]$:
#
# $$s_{ji}[k+1]=s^o_{ji}+q_{new}[k]s_{ji}[k][k+1]^{\frac{lg(l_{ji})}{lg(2)}}$$
#
# В условиях предыдущего примера будем полагать, что величина $q_{new}[k]$ распределена в диапазоне $
# [\overline {1,2}]$ с математическим ожиданием $\overline{q_{new}}=1,48$ и СКО $\sigma_{q_{new}} = 0,34 $ (рис. 2.8).
#
# Равномерное распределение коэффициента новизны не всегда является достаточно адекватным характеру исследуемых процессов. В модели Л. Гарикано (Garicano, 2000), описывающей успешность реализации производственного процесса, множество всех поступающих залач моделируется точками отрезка $[0, Z]$ действительной оси.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# На рисунке возможна опечатка $S_k$ или $S_{ji}$ - разберайтесь сами
#
# Рис. 2.8. Кривая обучения с учетом случайного коэффициента новизны
#
# $Q_{new}[k](\overline{q_{new}}=1,48 и СКО \sigma_{q_{new}}=0,34)$
#
# Квалификация сотрудника определяется подмножеством задач, которые он способен квалифицированно решить. При этом Гарикано предлагает два подхода к описанию модели. В рамках первой интерпретации считается, что вероятность $р(z)$ появления задачи $z \in [0, Z)$ убывает с ростом $z$. Второй подход предполагает, что переменная $z$ описывает сложность проблемы и большие значения действительной оси соответствуют более сложным задачам. __На наш взгляд__, оба подхода в известном смысле схожи между собой и их объединение позволяет говорить об убывании вероятности появления задачи с ростом ее сложности. В соответствии с этими рассуждениями в модели компетентности сотрудников, решающих задачи организационных изменений, сложность задач может быть описана случайной величиной с дискретной функцией вероятности, распределенной по закону Пуассона $p(z)=\frac{\lambda^z}{z!}e^{-\lambda}; \lambda > 0$ .
#
# Стр. 86
#
# ----------

# %% [markdown]
# Важно отметить, что каждый элемент матрицы компетентности $(s_{ji}[k])_{m \times n}$ представляет собой не обобщенный уровень компетентности подразделения, а уровень компетентности сотрудников конкретного $j$-го подразделения при решении конкретной $і$-й залачи организационных изменений. Поэтому в целях повышения адекватности представляется целесообразным использовать в моделях таких процессов различные оценки $L$ уровней обучения (приобретения опыта) сотрудников в зависимости от уровней «характерности/нехарактерности» $і$-й задачи для $j$-го подразделения на каждом конкретном этапе преобразований. Так уровень обучения при решении характерных задач может оцениваться малыми значениями L, например, $L = 60 - 40%$, в то время как решение нехарактерных задач осуществляется в условиях высоких значений уровня обучения, например, $L = 95 - 80%$. __Проблема обоснования значений__ $L$ в задачах моделирования процессов организационных изменений может решаться применением метода экспертных оценок в сочетании с аппаратом нечетких множеств (см. ниже). Процессы решения подразделениями инновационных залач организационных изменений, обусловленных реакцией организации на плохо наблюдаемые случайные изменения внешней среды, требуют принципиально иного подхода к моделированию уровня накопления опыта сотрудников.
#
# Стр. 87
#
# -----------

# %% [markdown]
# Одним из таких подходов может быть применение логико-математического аппарата теории систем со случайной скачкообразной структурой (Бухалев, 1996) в сочетании с методологией оценки типов структур в зависимости от уровня зрелости подразделения в отношении конкретной задачи Херси П. и Бланшара К., а также других аналогичных моделей. __Весьма интересный подход__ к моделированию процесса управления обучением предлагает проф. Орлов А. И. (Орлов, 2011). Применительно к проблеме моделирования организационных изменений, требующих управления компетенциями сотрудников, эту модель можно интерпретировать следующим образом. __Здесь в описании модели__ Орлова А. И. сохранены авторские обозначения в математических выражениях и текстовые метафоры, представляющиеся нам удачными. __Пусть__ $x(f)$ - объем профессиональных знаний, накопленных сотрудником, задействованным в организационных изменсниях, к моменту времени $t$, $у(t)$ - объем накопленных профессиональных навыков; $u(f)$ - доля времени, отведенного на накопление знаний в промежутке времени $(t; t + dt)$. __Предположим__, что увеличение $х(f + dt) - x(f)$ объема знаний сотрудника пропорционально потраченному на это времени $u(t)dt$ и накопленным навыкам $у(f)$. Следовательно, $\frac{dx(t)}{dt}=k_1 u(t) y(t)$ , (2.8) - где коэффициент $k_1 > 0$ зависит от индивидуальных особенностей сотрудника.

# %% [markdown]
# Увеличение знаний за то же время пропорционально потраченному на это времени $(1 - u(t))dt$ имеющимся навыкам $у(t)$ и знаниям $x(t)$. Следовательно, $\frac{dy(t)}{dt}=k_2(1-u(t)) * x(t)y(t)$ (2.9) . __Коэффициент__ $k_2 > 0$ также зависит от индивидуальных особенностей сотрудника. При этом скорость приобретения работником новых знаний (обязанностей, технологий, процедур и т.п.) зависит от объема накопленных к данному моменту времени знаний и навыков (опыта). Однако скорость усвоения новых профессиональных знаний не зависит напрямую от объема полученных ранее новых сведений. Поэтому на правую часть уравнения (2.8), по мнению Орлова А. И., влияют только приобретенные в прошлом активные знания, примененные при решении новых задач и перешедшие в навыки. __В условиях организационных изменений__ управление процессом обучения сотрудника может заключаться в выборе при каждом $t$ значения функции $u(t)$ из отрезка $[0;1]$.
#
# Стр. 88
#
# --------------

# %% [markdown]
# Рассматриваются две задачи (Орлов, 2011): __во первых__, максимально быстрое приобретение сотрудником новых знаний $х_1$ и навыков $у_1$: $(x_0,y_0)_{t_{min}} \to(х_1,y_1)$; __во вторых__, максимально быстрое приобретение сотрудником заданного объема знаний. Двойственная задача: за заданное время достигнуть как можно большего объема знаний. Здесь двойственность понимается в обычном для линейного программирования смысле. __По мнению автора модели__, линейная замена переменных эквивалентна переходу к другим единицам измерения знаний и умений, своим для каждого обучаемого... Оптимальные траектории движения для второй задачи и двойственной к ней совпадают. С помощью замены переменных $z = k_2х$ , $w= k_1k_2у$ осуществляется переход от системы (2.8), (2.9) к более простой системе дифференциальных уравнений, не содержащей неизвестных коэффициентов: $\frac{dz}{dt}=uw$ , $\frac{dw}{dt}=(1-u)zw$ . (2.10) __Решения первой и второй задач__ (оптимальное управление u(t)), находят с помощью принципа максимума Л. С. Понтрягина. В первой задаче для системы (2.10) из этого принципа следует, что быстрейшее движение может происходить либо по горизонтали ($u = 1, z^2_0 < w_0$) и вертикали ($ u=0,x^2_0 > w_0$), либо по особому решению — параболе $w = z^2$; ($u=1/3, z^2_0=w_0$) .

# %% [markdown]
# Во второй задаче из семейства оптимальных траекторий, ведущих из начальной точки $(z_0; w_0)$ в точки луча $(z_1; w_1)$, $w_0\leq w_1 \leq +\infty$, выбирается траектория, требующая минимального времени. При $z_1 ≤ 2z_0$, оптимально $w_1 = z_0(z_1 - z_0)$, траектория состоит из вертикального и горизонтального отрезков. При $z_1 > 2z_0$, оптимально $w_1=z_1^2/4$, траектория проходит по магистрали $w = z^2$ от точки $(z_0; z_0^2)$ до точки $(z_1/2; z_1^2/4)$. __Таким образом__, чем большим объемом новых знаний $z_1$, должен овладеть сотрудник, тем больше времени (2/3) он должен потратить на приобретение навыков, соответственно на накопление знаний остается 1/3 общего времени. __В течение основного периода__ организационных изменений, требующих приобретения сотрудниками новых компетенций, оптимальное распределение времени между приобретением знаний (инструктажи, изучение источников, совещания и т.п.) и решением практических задач будет одним и тем же для всех сотрудников, независимо от индивидуальных коэффициентов $k_1$, $k_2$. Этот факт устойчивости оптимального решения показывает возможность организации обучения, оптимального одновременно для всех сотрудников. Однако время приобретения новых навыков будет зависеть от начального положения $(x_0; y_0)$ и индивидуальных коэффициентов $k_1$, $k_2$.
#
# Стр. 89
#
# ---------

# %% [markdown]
# # Интеграннонные активности и интеграционные полномочия подразлелений.
# Как уже отмечалось, одним из основополагающих факторов, определяющим эффективность алаптационных преобразований организации, является степень взаимолействия ее подразделений. По мнению Р. Акоффа, организационные молели, не учитывающие несовпадение интересов частей системы (зачастую приводящее к конфликтам), не позволяют адекватно описывать процессы адаптации организации к высокотурбулентной постоянно усложняющейся внешней среде. Значительная часть энергии большинства современных организационных систем «тратится впустую в тщетных попытках разрешения конфликта» (Акофф, 2002). __Рассмотрим матрицу интеграции__:
#
# $$I=\begin{pmatrix} i_{11} & \dots & i_{1m} \\ \vdots & \ddots & \vdots \\ i_{m1} & \dots & i_{mm} \end{pmatrix} =(i_{ij})_{m \times m} ;$$
#
# где $i_{j1}(t)$ — оперативная интеграция $j$-го и 1-го подразделений, инициируемая $j$-м подразделением в интересах решения закрепленных за ним задач развития; $i_{1j}(t)$ — оперативная интеграция $j$-го и 1-го подразделений, инициируемая 1-м подразделением в интересах решения закрепленных за ним задач развития.

# %% [markdown]
# Под интеграционной активностью подразделения будем понимать его стремление к объединению собственных ресурсов с ресурсами (прежде всего - интеллектуальными и информационными) других подразделений. При этом стремление к привлечению ресурсов других подразделений для решения «собственных» (прежде всего — «неявных» задач) будем называть «внутренней интеграционной активностью» подразделения, а стремление к участию в решении залач других подразделений - «внешней интеграционной активностью» (Михненко, 2011; Михненко, 2011а; Михненко, 2012).
#
# Обозначим
#
# $$\overline{I}_{int}(t)=\frac{1}{m}\sum^m_{j=1}i_{j1}(t); \overline{I}_{ext}(t)=\frac{1}{m}\sum^m_{j=1}i_{1j}(t) ;$$
#
# где $\overline{i}_{int}(t)$ — средняя внутренняя интеграционная активность 1-го подразделения - показатель востребованности компетенций 1-го подразделения другими подразделениями, для решения закрепленными за ними задач развития; $\overline{i}_{ext}(t)$ — средняя внешняя интеграционная активность 1-го подразделения - показатель интенсивности запросов 1-го подразделения на использование компетенций других подразделений для решения задач развития, закрепленных за 1-м подразделением.
#
# Стр. 90
#
# ----------------

# %% [markdown]
# Рассматриваемая математическая модель предполагает, что в пронессе организационных изменений подразделения могут демонстрировать разные типы интеграционной активности. __Под интеграционными полномочиями__ подразделения будем понимать степень и характер его взаимодействия с другими подразделениями организации, обоснованные исходя из формализованного представления об эффективности организационных изменений и директивно установленные для этого подразделения. Одной из первостепенных залач подготовки и осуществления организационных изменений является обоснование и оптимизация интеграционных полномочий всех подразделений компании. __Оперативное обоснование и оптимизация__, а также динамическое изменение интеграционных полномочий подразделений компании по существу представляют собой процесс динамической оптимизации организационной структуры компании. При этом под критерием динамической оптимизации организационной структуры понимастся максимально полное соответствие структуры целям и задачам изменений. __Различные интеграционные полномочия__ и соответствующие им интеграционные активности подразделений порождают временные центры управления изменениями, а организационная структура компании временно уподобляется сетевой структуре. По мнению Д. Новикова, сетевая структура — набор априори равноправных агентов, в котором могут возникать временные иерархические и другие структуры, определяемые решаемыми системой задачами (Новиков, 2002).

# %% [markdown]
# Пример (табл. 2.4) демонстрирует один из возможных вариантов распределения активностей и формирования временных центров управления изменениями. Средние внешняя и нутренняя интеграционные активности рассчитаны без учета диагональных ячеек матрицы. __Данное распределение указывает на то__, что подразделение 3, являясь максимально востребованным («донором»), вынуждено делегировать собственные ресурсы в интересах решения задач других подразделений $\overline{I_{ext}}(t)=0,78$. Подразделение 1 («акцептор») привлекает для решения собственных задач ресурсы всех остальных подразделений в форме создания объединенных рабочих команд и привлечения интеграторов $\overline{I_{int}}(t)=0,78$. Подразделение 2, демонстрируя поведение как «донора» $\overline{I_{ext}}=0,85$, так и «акцептора» $\overline{I_{int}}(t)= 0,88$, становится временным центром управления изменениями, концентрирующим вокруг себя все остальные подразделения организации для эффективного решения общих задач (рис. 2.9). Пример реального распределения интеграционных активностей подразделений компании приведен в приложении 1.
#
# Стр. 91
#
# --------

# %% [markdown]
# Таблица 2.4. Оперативное распределение интеграционных полномотий
#
# ||Подразделение 1 |Подразделение 2 |Подразделение 3 |Подразделение 4 |Подразделение 5 |$\overline{I_{int}}(t)$|
# |:--|:--|:--|:--|:--|:--|:--|
# |Подразделение 1|| 0,80| 0,90| 0,85| 0,70| 0,82|
# |Подразделение 2|0,80||0,85|0,95|0,90|0,88|
# |Подразделение 3|0,30|0,95||0,25|0,10|0,40|
# |Подразделение 4|0,00|0,80|0,75||0,30|0,46|
# |Подразделение 5|0,10|0,85|0,60|0,00||0,39|
# |$\overline{I_{int}}(t)$|0,30|0,85|0,78|0,51|0,50||

# %% [markdown]
# Представляется важным следующее замечание: интеграционные полномочия, определяемые аналитически и распределяемые менеджментом директивным способом, сами по себе являются лишь требованиями или рекомендациями. Однако в процессе осуществленияо рганизационных изменений, по-видимому, следует ожидать стремления подразделений к увеличению внутренней и уменьшению внешней интеграционных активностей, что приведет к снижению общеорганизационной конвергенции. __Установившийся баланс__ интеграционных активностей может быть интерпретирован ситуацией игрового равновесия, где в роли "максимизирующего игрока" выступает стремление подразделений к внутренней интеграционной активности, а «минимизирующим игроком» - стремление к внешней интеграционной активности. В состоянии реально сформировавшегося игрового равновесия распределение интеграционных активностей, возможно, будет значительно отличаться от директивного. __Таким образом__, под запланированными организационными изменениями будем понимать процесс целенаправленного управляемого перевода организационной системы из текущего состояния в некоторое заданное (желаемое). Принцип распределенной ответственности как механизм распределения задач и ресурсов между подразделениями организации предполагает, что в общем случае каждое подразделение компании должно включать в план своих организационных преобразований каждую из задач, стоящих перед компанией и целом. __Решение подразделениями__ так называемых неявных задач позволяет компании консолилировать усилия всех функциональных и вспомогательных подразделений при решении общих задач. Такая консолидация становится возможной вследствие рациональной интеграции подразделений.
#
# Стр. 92
#
# -------

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Рис. 2.9. Поле интеграционных активностей подразделений
#
# Под текущей (оперативной) интеграцией подразделений будем понимать обоснованный выбор одного из возможных координационных механизмов их взаимодействия в интересах эффективного осуществления запланированных организационных изменений. __Эффективность каждого__ элементарного организационного изменения, реализованного в подразделении компании, зависит от эффективности решения этой задачи всеми подразделениями компании в условиях наиболее благоприятной интеграции всех подразделений в интересах решения данной задачи. __Под интеграционной__ активностью подразделения будем понимать его стремление к объединению собственных ресурсов с ресурсами (прежде всего - интеллектуальными и информационными) других подразделений. При этом стремление к привлечению ресурсов других подразделений для решения собственных (прежде всего - неявных задач) будем называть «внутренней интеграционной активностью» подразделения, а стремление к участию в решении задач других подразделений — «внешней интеграционной активностью».

# %% [markdown]
# __Одной из первостепенных__ задач подготовки и осуществления организационных изменений является обоснование и оптимизация интеграционных полномочий всех подразделений компании (см. приложение 1). __В ходе организационных__ изменений залача динамической (оперативной) оптимизации интеграционных полномочий подразделений (в сочетании с принципом распределенной ответственности) представляет собой процесс формирования «оперативно-оптимальных» организационных структур, наиболее благоприятствующих осуществлению изменений в иных (не структурных) аспектах. В состоянии реально сформировавшегося игрового равновесия распределение интеграционных активностей, возможно, будет значительно отличаться от директивного. Представляется актуальным поиск моделей оценки
# «установившейся» (паритетной) ситуации в аспекте интеграционной активности подразделений, приводящей к отклонению от условий реализации изменений.
#
# Стр. 93
#
# ----------

# %% [markdown]
# # Глава 3. Оптимизация процесса адаптации организации к изменениям внешней среды
#
# ### 3.1. Постановка задачи оптимизации интенсивности организационных изменений
#
# Как подчеркивалось выше, стохастический подход к моделированию процесса организационного развития помимо прочего предполагаст формулировку критерия оптимальности алаптивных динамических организационных систем в виде функционала, зависящего от вероятностных характеристик процесса адаптации. __В большинстве__ практических залач критерий оптимальности может представлять собой минимум некоторого функционала, зависящего от математического ожидания и дисперсии (СКО) величины, характеризующей степень несоответствия (рассогласования) параметров организации требованиям внешней среды в установившемся режиме. __Под установившимся__ режимом преобразований понимается процесс, характеризующийся бессрывностью и необратимостью процесса адаптивных преобразований на основе постоянно поступающей информации об изменениях отслеживаемых факторов внешней среды. Содержательно такой критерий означает стремление к управлению изменениями, обеспечивающему минимум систематической и случайной составляющих рассогласования. __В математической модели__ организационного развития (См. п. 2.3.) матрица $А$ адаптации предприятия определяст интенсивность организационных изменений, т. с. требуемую скорость осушествления организационных преобразований, а также степень залействования сотрудников, рабочего времени, финансовых и иных ресурсов. Интенсивность организационных изменений может быть рассмотрена в контексте теоремы Р. Эшби, интерпретированной для процессов управления хозяйственными организациями «для того, чтобы успешно противостоять среде, сложность и быстрота принятия решений в фирме должны соответствовать сложности и быстроте изменений, происходящих в среде» (Эшби, 1959).
#
# Стр. 95
#
# ------------

# %% [markdown]
# Адаптация здесь проявляется во внутриорганизационной гибкости предприятия, позволяюшей ему быстро и качественно переходить к новым видам продукции, выходить на новые рынки, эффективно оценивать поступающую информацию, обеспечивать психологическую устойчивость коллектива, эффективно использовать интеллектуальный потенциал менеджмента и сотрудников и т. п. __Поставим задачу__ оптимизации матрицы А (2.5), (2.6) при следующих допущениях: __во первых__, о стационарности матрицы $C_R=(c_{r_k})_{n \times m}$ интерактивного планирования на интервале $[t_0;t]$ цикла организационных изменений: $C_R = const;$ (3.1); __во вторых__, о центрированности случайной величины $\xi(t)$, т.е. об отсутствии систематической ошибки анализа внешней среды и измерений результатов преобразований: $m_\xi=M(\xi)=0$ , (3.2) где $m$, $М(*)$ - символы математического ожидания.

# %% [markdown]
# Однократно продифференцируем по времени уравнение (2.4) для вектора рассогласования (результатов мониторинга процесса организационных изменений): $\frac{d \Delta}{dt}=\frac{dP}{dt}-C_R\frac{dR}{dt}$, где, как следует из схемы (см. рис. 2.6), $\frac{dR}{dt}=U=A(\Delta+\xi)=A(P-C_RR+\xi)$, откуда $\frac{d\Delta}{dt}=\frac{dP}{dt}-C_RA(P-C_RR+\xi)=\frac{dP}{dt} - С_RA(\Delta+\xi)$. Как указывалось выше, вектор Р планов и параметров организационных изменений является функцией вектора Х условий внешней среды, оказывающих влияние на организацию: $Р = G(X,\zeta, М)$. __Примем допущение__ $\frac{dp}{dt}=\frac{dX}{dt}$, указывающее на способность высшего руководства организации обеспечивать темпы планирования организационных изменений в соответствии с темпами знаковых для организации изменений ситуационных переменных Х внешней среды. Обозначим $\frac{dX}{dt}=V$, тогда $\frac{d\Delta}{dt}=V-C_RA(\Delta+\xi)$.
#
# Стр. 96
#
# --------

# %% [markdown]
# Используя метод вероятностных моментов и учитывая допущения (3.1) и (3.2), получим дифференциальные уравнения для математического ожидания $m_{\Delta}$ и ковариации $\Theta_{\Delta}$, вектора $\Delta$: $\frac{dm_{\Delta}}{dt}=m_V-C_RAM_{\Delta}$, (3.3); $\frac{d\Theta_{\Delta}}{dt} = C_RA \Theta_{\Delta} +\Theta_{\Delta}A^TC_R^T + A^TC_R^TQC_RA$ , (3.4) где $m_{\Delta}$ - математическое ожилание вектора рассогласований $\Delta$; $m_v$ - математическое ожидание вектора скорости изменения ситуационных переменных внешней среды; $Q = (q_{i \times 1})_{n \times 1}$ — вектор информационной неопределенности - дисперсия информационно погрешности $\xi$; индекс $Т$ - знак транспонирования.

# %% [markdown]
# Тогда постановка задачи оптимизации матрицы А будет иметь следующий вид.
#
# __Во первых__. Решение уравнений (3.3) и (3.4) в установившемся режиме процесса организационных изменений: $m^*_{\Delta} = arg(\frac{dm_{\Delta}}{dt}=0)$; (3.5) ; $\Theta^*_{\Delta}=arg(\frac{d\Theta_{\Delta}}{dt}=0)$. (3.6)
#
# __Во вторых__. Обоснование критерия оптимальности, построенного на функционале от векторов математического ожидания и ковариации рассогласования $\Delta$: $J = \min\limits_{A \in  \Omega_A}\varphi \{m^*_{\Delta}(A),\Theta^*_{\Delta}(A)\} $; (3.7);
# где $\Omega_A$, - область значений А.
#
# __В третьих__. Получение выражения для $A^*$ (аргумент функционала $J$), где $A^*$ - оптимальная интенсивность изменений по критерию минимума статистических характеристик $m_{\Delta}$, и $\Theta^*_{\Delta}(A)$ , рассогласования $\Delta$. Откуда в соответствии с (2.5) определится матрица оперативнооптимальной интеграции подразделений, участвующих в осушестилении организационных изменений: $I^*=A^*S^{-1}$; (3.8);
#
# Стр. 97
#
# -------------

# %% [markdown]
# Таким образом, оптимизация матрицы А по критерию минимума статистических характеристик рассогласования позволяет обосновать оптимальное значение интенсивности органи мционных изменений, направленных на адаптацию организации к изменениям ситуационных переменных внешней среды. __В ряде задач__ ковариация рассогласования $\Theta^*_{\Delta}(A)$, - интенсивность несистематических ошибок менеджмента - может рассматриаться в качестве аргумента функиии $f_{сопротивления организационных изменений}(\Theta_{\Delta})$  сопротивления организационных изменений. Возрастание $\Theta^*_{\Delta}$, приводит к росту сопротивления изменениям в силу очевилности ошибочных решений менеламента. __Важная роль__ точности оценивания приролных случайностей и нео пределенностей подчеркивается в (Гермейер, 1976) применительно к моделям игр с несовпадающими интересами. Трудности принятих решения состоят в недостаточной информированности принимаюших решения игроков о значениях вектора приролих случайностей и неопрелеленностей, критериях и решениях партнеров и о выборе своих действий. Недостаточная информированность игрока ставит его перед хаосом будуших значений критерия эффективности при данном решении, и этот хаос больше, чем меньше информированность. Поэтому только четкая фиксация ожилающейся информации и путей ее увеличения создает правильное представление о трудностях и способах принятия решений. __Ю. Гермейер указывает__, что даже само понятие решения (предмета выбора) меняется в глазах исследователя с изменением уровня информированности. Это связано с динамикой получения информации по мере развертывания исследуемого процесса. __Нам представляется__, что эти рассужления вполне характеризуют аспект информационной неопределенности и в рассматриваемом неигровом подходе к описанию поведения организационной системы.

# %% [markdown]
# # 3.2. Одномерная модель процесса адаптации организации к изменениям внешней среды
#
# Получим аналитическое выражение для оптимального значения $a^*$ скалярной величины а - коэффициента адаптации в одномерном случае, где $а = (а_{ij})_{m \times n} $ , при $n = 1$, $m = 1$. В соответствии с (3.5) и (36)
# и с учетом допушений (З.1) и (3.2) выражения для $m^*_{\Delta}$, $\Theta^*_{\Delta}$ и $\alpha^*_{2\Delta}$, в уста
# новившемся режиме соответственно будут иметь вид
#
# $$m^*_{\Delta} = \frac{m_V}{c_ra}; (3.9);$$
#
# $$\Theta^*_{\Delta} = \frac{1}{2}c_raq; (3.10);$$
#
# $$\alpha^*_{2\Delta} = m^*_{\Delta} + \Theta^*_{\Delta} = (\frac{m_V}{c_ra})^2 + \frac{1}{2}c_raq ; (3.11);$$
#
# где $c_r = (c^{(n)}_{i\neq j})_{n \times m}$; $q=(q_{i \times 1})_{n \times 1}$. - дисперсии информационной погрешности $\xi$ при n = 1, m = 1.
#
# Стр. 98
#
# ------

# %% [markdown]
# На рис. 3.1 приведены графики зависимости статистических моментов величины рассогласования от интенсивности изменений $\alpha$, указанной в процентах от максимально возможного значения. __Как видно__, увеличение интенсивности преобразований а вызывает резкое снижение математического ожидания $m^*_{\Delta}$; и линейный рост дисперсии $\Theta^*_{\Delta}$ рассогласования. Величина $\alpha^*_{2\Delta}$, имеет характерный минимум при определенном значении $\alpha$. Следовательно, для каждой группы значений $(m_V,c_r,q)$ , определяющих условия осушесткления алаптивных организационных изменений, может быть найдено оптимальное значение интенсивности изменений а по критерию (3.7).

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Рис. 3.1. Зависимость статистических моментов рассогласования от интенсивности организационных изменений при $m_V=50$, $ с_r = 1$, $q = 1$. Условные обозначения: жирная линия — $m^*_{\Delta}$, обычная линия - $\Theta^*_{\Delta}$ , пунктирная линия - $\alpha^*_{2\Delta}$ .
#
# На рис. 3.2 изображено семейство кривых $\alpha^*_{2\Delta}(a)$ при $m_V = 0, 10, 20, 30, 40, 50, 75, 100$ и $с_r$ = 1, $q = 1$. При m, = 0 (отсутствие изменений ситуационных переменных внешней среды) график $\alpha^*_{2\Delta}(a)$ представляет собой прямую линию, где $\alpha^*_{2\Delta min}(a=0)$. Увеличение $m_V $, (при неизменних прочих условиях) приводит к росту минимального значения статистической характеристики $\alpha^*_{2\Delta}(a)$ и смешению его вправо по оси $а$. Что свидетельствует об увеличении требуемой (оптимальной) интенсивности организационных преобразований при одновременном ухудшении статистического показателя качества адаптации.
#
# Стр. 99
#
# -----------

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Рис. 3.2. Семейство кривых $\alpha^*_{2\Delta}(a)$ при $m_\forall= 0; 10; 20; 30; 40; 50; 75; 100 $ и $c_r = 1$, $q = 1$
#
# На рис. 3.3 изображено семейство кривых $\alpha^*_{2\Delta}(a)$ при $q = 0; 0,1; 0,5; 1;2; 5; 10;$
# и $m_V = 50$ и $с_r = 1$. Как видно, увеличение уровня информационной неопределенности у представлений о состоянии внешней среды и текущих результатах организационных изменений приводит к существенному увеличению минимального значения $\alpha^*_{2\Delta}(a)$ без заметного смещения по оси $а$. Это свидетельствует о значительном ухудшении качества адаптивных организационных изменений в связи с ростом информационной неопределенности. _Получим выражение_ для оптимального значения $а^*$ в установившемся режиме по критерию равенства математического ожидания и дисперсии рассогласования:
#
# $$a^*=arg_{a \in \Omega}\{m^*_{\Delta}(a)=\Theta^*_{\Delta}(a)\}$$.
#
# Иными словами, оптимизация осуществляется по критерию
#
# $$J= \min\limits_{A \in  \Omega_A} \varphi \{|m^*_{\Delta}(A) - \Omega^*_{\Delta}(A)|\}; (3.12)$$
#
# Данное условие характеризует такое соотношение величин $m^*_{\Delta}(a)$, $\Theta^*_{\Delta}(а)$, при котором лальнейшее увеличение интенсивности изменений в целях снижения систематической ошибки $m^*_{\Delta}(a)$ становится нецелесообразным из-за роста дисперсии $\Theta^*_{\Delta}(а)$ (см. рис. 3.1).
#
# Стр. 100
#
# -----------
