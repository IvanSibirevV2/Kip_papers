# %%
import os;import math;import sys;import datetime;
var='\\MacOs_Sequoia.ipynb'
print (var,':',os.path.getsize(os.path.abspath(os.curdir)+var)/math.pow(2, 20),' мегобайт ',datetime.datetime.now())
# Out:
# \MacOs_Sequoia.ipynb : 10.123122215270996  мегобайт  2025-03-05 17:01:25.795079

# %% [markdown]
# http://localhost:8888/files/Kip_papers/Untitled_1121/_OceanofPDF.com_macOS_Sequoia_For_Dummies_-_Guy_Hart-Davis.pdf

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# FIGURE 13-1: Click Wi-Fi in Control Center (left), and then click the network in the Wi-Fi
# pane (right).

# %% [markdown]
# If the Wi-Fi network you want to join doesn’t appear in the Other
# Networks list, but you know the network exists, it’s probably set to hide
# its name (in technical terms, its Service Set Identifier, or SSID). Click
# Other to open the Find and Join a Wi-Fi Network dialog (see Figure 13-
# 2). Fill in the Network Name field and the Password field, and then click
# the Join button.

# %% [markdown]
# Стр. 351
#
# ---------

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# FIGURE 13-2: Use the Find and Join a Wi-Fi Network dialog to join a Wi-Fi network that
# hides its name.

# %% [markdown]
# # Технические подробности
#
# Most home Internet routers are set to use a technology called
# Dynamic Host Configuration Protocol (DHCP), which
# automatically provides connection information to computers on the
# network. This connection information includes the Internet Protocol
# address (IP address), a number that identifies the computer; the
# subnet mask, a number used to organize the network; and the IP
# address or name of the Internet router, which tells the computer
# where to find the on-ramp to the Internet.

# %% [markdown]
# To connect your Mac to a Wi-Fi network via the Wi-Fi pane in the
# System Settings app, follow these steps:

# %% [markdown]
# 1. Open System Settings — for example, click the System Settings
# icon on the Dock or on the Launchpad screen.

# %% [markdown]
# Стр. 352
#
# --------

# %% [markdown]
# 2. Click Wi-Fi in the sidebar to display the Wi-Fi pane.

# %% [markdown]
# Make sure the Wi-Fi switch at the top is set to On (blue).

# %% [markdown]
# 3. In the Other Networks list, move the pointer over the Wi-Fi
# network you want to join, and then click the Connect button that
# appears on the right (see Figure 13-3).

# %% [markdown]
# A dialog opens to prompt you for the Wi-Fi network’s password.

# %% [markdown]
# 4. Type the password in the Password box.

# %% [markdown]
# To see the characters you’re typing, set the Show Password switch to
# On (blue).

# %% [markdown]
# 5. Click the Join button.

# %% [markdown]
# Once macOS has established the connection, the network’s name
# appears near the top of the Wi-Fi pane, just under the Wi-Fi switch.

# %% [markdown]
# # Managing your Wi-Fi networks

# %% [markdown]
# If your Mac connects to only a single Wi-Fi network, you may not need
# to perform any management — you can just let it connect with default
# settings. But if your Mac connects to multiple Wi-Fi networks, take a
# minute to make yourself familiar with the controls for managing Wi-Fi
# networks. This is especially important if your Mac connects to two or
# more Wi-Fi networks in the same location — for example, if you have
# multiple Wi-Fi networks in your home, in your workplace, or in your
# favorite espresso emporium.

# %% [markdown]
# Стр. 353
#
# ----------

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# FIGURE 13-3: From the Wi-Fi pane in System Settings, you can set up and configure Wi-Fi
# network connections.

# %% [markdown]
# Here’s how to manage your Wi-Fi networks:

# %% [markdown]
# 1. Open System Settings — for example, choose ⇒ System Settings.

# %% [markdown]
# 2. Click Wi-Fi in the sidebar to display the Wi-Fi pane (see Figure
# 13-4).

# %% [markdown]
# The current Wi-Fi network appears at the top, with a green circle and
# a Connected readout. Below that, the Networks section shows three
# lists:

# %% [markdown]
# - Personal Hotspots: These are hotspot Wi-Fi networks
# provided by devices such as your iPhone or cellular iPad.

# %% [markdown]
# - Known Networks: These are the available Wi-Fi networks
# your Mac has previously connected to and for which it knows
# the password (if the network is secured, indicated by the lock
# icon). A check mark appears next to a known network to
# which your Mac is already connected.

# %% [markdown]
# # Запомни
#
# Your Mac will automatically connect to networks in
# the Known Networks list when they are available. If you don’t
# want your Mac to connect to a particular known network, you
# need to tell macOS (we’ll get to this in a moment).

# %% [markdown]
# - Other Networks: These are Wi-Fi networks your Mac hasn’t
# previously connected to, or that it has connected to but that
# you’ve made it forget.

# %% [markdown]
# 3. Set the Ask to Join Networks switch to On (blue) if you want
# your Mac to prompt you to join an available Wi-Fi network
# when none of its known networks are available.

# %% [markdown]
# These prompts may be helpful, so try turning on Ask to Join
# Networks and see how it suits you.

# %% [markdown]
# 4. Set the Ask to Join Hotspots switch to On (blue) if you want your
# Mac to prompt you to join an available Wi-Fi hotspot.

# %% [markdown]
# These prompts also may be helpful. But keep in mind that some
# hotspots are run by malefactors keen to slurp up unwary users’
# credentials, bank information, and cookie recipes, so connecting to
# hotspots whose provenance you don’t know may prove costly.

# %% [markdown]
# 5. Click the Advanced button at the bottom of the Wi-Fi pane to
# display the Advanced dialog (see Figure 13-5).

# %% [markdown]
# Стр. 355
#
# --------

# %% [markdown]
# 6. In the Require Administrator Authorization To section, set the
# Change Networks switch, the Turn Wi-Fi On or Off switch, and
# the Show Legacy Networks and Options switch to On (blue) or
# Off (white), as needed.

# %% [markdown]
# Requiring administrator authentication for all three actions might be
# a good idea.

# %% [markdown]
# # Лампочка
#
# Legacies are generally a positive thing, but a legacy network
# usually means one that has poor network speeds and worse security.
# The Wi-Fi MAC Address readout shows the hexadecimal Media
# Access Control (MAC) address for your Mac’s wireless network
# interface. You might need the MAC address to whitelist your Mac
# with your Internet router.

# %% [markdown]
# 7. Configure Auto-Join and prune the Known Networks list as
# needed:

# %% [markdown]
# - Toggle Auto-Join for the network. Click the ellipsis (…)
# button, and then click Auto-Join to place or remove the check
# mark.

# %% [markdown]
# - Remove a network. Click the ellipsis (…) button, click
# Remove from List, and then click the Remove button in the
# confirmation dialog.

# %% [markdown]
# # Лампочка
#
# The ellipsis (…) pop-up menu for a network in the Advanced
# dialog also usually contains the Copy Password command, which
# lets you copy a known network’s password.

# %% [markdown]
# 8. Click Done to close the Advanced dialog.

# %% [markdown]
# Стр. 356
#
# ------

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# FIGURE 13-4: In the Wi-Fi pane, choose whether to automatically join known networks and hotspots.

# %% [markdown]
# Стр. 357
#
# -----

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# FIGURE 13-5: In the Advanced dialog, you can control automatic joining and remove Wi-Fi
# networks you no longer want to use.

# %% [markdown]
# Стр. 358
#
# -----

# %% [markdown]
# From the Wi-Fi pane in System Settings, you can click the Details button
# for the connected Wi-Fi network to display the Details dialog, which
# provides options for configuring that network. In this dialog, you can set
# these four settings:

# %% [markdown]
# - Automatically Join This Network: This switch gives you another
# way to control whether your Mac automatically joins this particular
# network when it’s available.

# %% [markdown]
# - Private Wi-Fi Address: In this pop-up menu, choose whether to
# obfuscate your Mac’s Wi-Fi interface’s hardware address instead of
# providing its real address (which might enable malefactors to track
# your connections). Choose Off to provide the real address. Choose
# Fixed to use a single fake address for each connection. Choose
# Rotating to use a different fake address each time your Mac connects
# to a Wi-Fi network.

# %% [markdown]
# - Low Data Mode: Set this switch to On (blue) to reduce your Mac’s
# data usage as far as is practical. You’d use Low Data Mode when
# connecting your Mac to a metered network, such as the extortionate
# Internet connections some hotels provide. (If the Wi-Fi network is
# connected to an all-you-can-eat Internet connection, you probably
# won’t want to use Low Data Mode.)

# %% [markdown]
# - Limit IPAddress Tracking: Set this switch to On (blue) to have
# macOS hide your IP address from known address trackers in Safari
# and Mail. Limiting tracking is usually a good idea.

# %% [markdown]
# # Лампочка
#
# The Details dialog also contains readouts showing the IP address
# your Mac’s wireless connection is using. Lastly, there’s a Forget
# This Network button that you can click to command your Mac to
# forget this network.

# %% [markdown]
# # Запомни
#
# Use only wireless networks that you know and trust, especially
# in public places such as hotels and airports. If you must connect
# your Mac to a network that might be untrustworthy, use a virtual
# private network (VPN) to encrypt the data your Mac sends and
# receives.

# %% [markdown]
# Finally, if you have any reservations about using public Wi-Fi, use your
# mobile phone’s hotspot feature (if it has one) instead of a public Wi-Fi
# network. Cellular networks encrypt all traffic, making them more secure
# than Wi-Fi networks.

# %% [markdown]
# Also look for https (not http) at the beginning of URLs to ensure that
# your wireless connection to that website is encrypted (more secure).

# %% [markdown]
# Стр. 359
#
# -------

# %% [markdown]
# # Connecting your Mac to a network via Ethernet

# %% [markdown]
# If your Mac has an Ethernet port, you can connect the Mac to a network
# in seconds by plugging one end of an Ethernet cable into that port and
# the other end into your Internet router. Take a few more seconds to
# arrange the cable so that nobody will trip over it and your cats can’t use
# it as a slackline.

# %% [markdown]
# # Лампочка
#
# If your Mac doesn’t have an Ethernet port, you can add one by
# getting a USB-to-Ethernet adapter or a Thunderbolt-to-Ethernet
# adapter.

# %% [markdown]
# Once you’ve made the physical connection, macOS normally configures
# it automatically within a few seconds. To see the details of the
# connection, open the System Settings app, click Network in the sidebar,
# and then click Ethernet in the Network pane. The Ethernet pane appears
# (see Figure 13-6), showing the connection’s details, including the IP
# address and the router address.

# %% [markdown]
# Стр. 360
#
# ------

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# FIGURE 13-6: Use the Ethernet pane to learn the IP address and other details of an
# Ethernet connection.

# %% [markdown]
# From here, you can click the Details button to open the Details dialog,
# which enables you to perform heavy-duty configuration of the
# connection. With the Ethernet category selected at the top of the sidebar,
# make sure the Limit IP Address Tracking switch is set to On (blue).
# Beyond this, it’s best not to change the settings in the Details dialog
# unless a) you know what you’re doing, or b) you’re following directions
# from a network administrator to solve a particular problem.

# %% [markdown]
# # Browsing the Web with Safari

# %% [markdown]
# With your Internet connection set up, you’re ready to browse the web.
# The following sections use Safari because it’s the web browser installed
# with macOS Sequoia.

# %% [markdown]
# Стр. 361
#
# -----

# %% [markdown]
# # Лампочка
#
# If you don’t care for Safari, check out Firefox or Chrome, which
# are both free browsers and have features you won’t find in Safari. It
# never hurts to have a spare in case Safari has issues with a
# particular website.

# %% [markdown]
# To begin, open Safari in any of these ways:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Click the Safari icon (shown in the margin) on the Dock or
# Launchpad.

# %% [markdown]
# - Double-click the Safari icon in your Applications folder.

# %% [markdown]
# - Click a URL link in an email, an iMessage, or a document.

# %% [markdown]
# - Double-click a URL link document (a .webloc file) in Finder.

# %% [markdown]
# The first time you launch Safari, you see a generic start page, as shown
# in Figure 13-7. (If you've upgraded to Sequoia from an earlier version of
# macOS, Safari will open to the same page it opened to before you
# upgraded.)

# %% [markdown]
# Стр. 362
#
# --------

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# FIGURE 13-7: Safari first displays a generic start page.

# %% [markdown]
# You can customize your start page by clicking the Edit button in the
# lower-right corner of the start page (shown in Figure 13-7). Enable or
# disable an item by selecting or deselecting its check box, respectively.

# %% [markdown]
# # Лампочка
#
# The Recently Closed Tabs section lists webpages that were open
# in tabs you’ve recently closed on this Mac, while the iCloud Tabs
# section of the start page shows webpages you’ve recently accessed
# on your other computers and devices that log into the same iCloud
# account.

# %% [markdown]
# # Лампочка
#
# You can choose what appears in new Safari windows and tabs by
# choosing Safari ⇒ Settings and clicking the General tab at the top
# of the Settings window.

# %% [markdown]
# Стр. 363
#
# --------------

# %% [markdown]
# # Using and customizing the toolbar

# %% [markdown]
# The Safari toolbar, at the top of every Safari window, consists of a
# narrow row of icons and the Search or Enter Website Name field. The
# icons do pretty much what their names imply. From left to right, they are

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Show/Hide Sidebar: Click this icon (shown in the margin) to
# see your favorites or Reading List in the sidebar; click it again to
# hide the sidebar.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - New Tab Group: Click this icon (shown in the margin) to
# create a new empty tab group. And if you don’t already know what a
# tab group is, you will shortly. This icon appears when the sidebar is
# displayed.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Tab Group Picker: Click this icon (shown in the margin) to
# display a pop-up menu containing the list of tab groups, together
# with the New Empty Tab Group command and the New Tab Group
# with This Tab command. This icon appears when the sidebar is
# hidden.

# %% [markdown]
# - Back/Forward: When you open a page and move to a second page
# (or third or fourth), Back takes you to previously visited pages.
# Remember that you need to go back before the Forward icon will
# work.

# %% [markdown]
# - Search or Enter Website Name (aka address box): This field, to
# the right of the Show Sidebar button, is where you enter web
# addresses, or URLs (Uniform Resource Locators) that you want to
# visit. Just type one — or paste if you prefer — and press Return to
# surf to that site.

# %% [markdown]
# To the right of the Search or Enter Website Name field are three
# more icons:

# %% [markdown]
# - Share pop-up menu: When you find a page of interest or a page you
# know you’ll want to remember, click this icon (which displays a
# drop-down menu) to tell Safari to remember it for you in its cool
# Reading List or as a bookmark — two topics covered later in this
# chapter. Or send a link to it via Mail or Messages, both covered in
# Chapter 15, or post it on Facebook or tweet it on Twitter.

# %% [markdown]
# Стр. 364
#
# ----------

# %% [markdown]
# - New Tab (+): Click to open a new tab; press and hold down to see a
# drop-down menu of recently closed tabs, and then click the one you
# want to return to.

# %% [markdown]
# - Show/Hide Tab Overview: Click the Show/Hide Tab Overview icon
# to see previews of all your open tabs (which you learn about shortly)
# or all tabs in the selected tab group. If you have other Macs or Apple
# devices, you’ll also see the open tabs in Safari on other devices that
# have Safari enabled in iCloud. This feature is so handy you can also
# access it on the View menu (View ⇒ Show Tab Overview) or by
# pressing ⌘ +Shift+\.

# %% [markdown]
# # Лампочка
#
# You can add other useful icons to your toolbar by choosing
# View ⇒ Customize Toolbar and then dragging icons such as Home
# Page, History, Bookmarks, AutoFill, and Print from the Customize
# Toolbar dialog to the toolbar.

# %% [markdown]
# # Using the Safari sidebar

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#  Click the Show/Hide Sidebar icon on the toolbar, choose View ⇒
# Show Sidebar, or press ⌘ +Shift+L to display the sidebar, where you’ll
# find links to your start page, tab groups, received links, and collected
# links (where you’ll find Bookmarks and Reading List).

# %% [markdown]
# Click the first sidebar item, Start Page, to see your start page (as
# discussed previously).

# %% [markdown]
# # Working with tab groups

# %% [markdown]
# Tab groups give you an easy and effective way to manage multiple tabs.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# To create a new tab group, click the New Tab Group icon on the
# right above the sidebar (shown in the margin) and choose New Empty
# Tab Group. If the sidebar is not displayed, click the Tab Group Picker
# icon and choose New Empty Tab Group. Or, if you currently have more
# than one tab open, and you want to create a group containing those tabs,
# choose New Tab Group with x Tabs (for example, New Tab Group with
# 5 Tabs).

# %% [markdown]
# Стр. 365
#
# ----------

# %% [markdown]
# Another way to create a new empty tab group is by choosing File ⇒
# New Empty Tab Group or pressing ⌘ +Control+N.

# %% [markdown]
# You can add a webpage to a tab group in these ways:

# %% [markdown]
# - If the sidebar is displayed: Drag the webpage’s tab from the tab bar
# onto the appropriate tab group in the sidebar. If the sidebar is hidden,
# you can display it by choosing View ⇒ Show Sidebar or pressing
# ⌘ +Shift+L.

# %% [markdown]
# - If the sidebar is hidden: Click in the address box to make it active,
# and then drag the little icon that appears left of the address to the left
# side of the Safari window and pause. When the sidebar slides into
# view, drag the icon to the appropriate tab group and drop it there.

# %% [markdown]
# To see the Tab Overview page for a tab group with thumbnails of all the
# pages it contains (as shown in Figure 13-8), move the pointer over the
# tab group’s name, click the ellipsis (…) button that appears, and then
# click Show Tab Overview on the pop-up menu.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Стр. 366
#
# -----------

# %% [markdown]
# FIGURE 13-8: The Tab Overview for the Mac Stuff tab group.

# %% [markdown]
# To activate a tab group, click its name in the sidebar. The tab group’s
# tabs replace your current tabs.

# %% [markdown]
# Note that if you open a new tab when a tab group is active (selected in
# the sidebar), the new tab becomes part of the active group. Conversely, if
# you close a tab when a tab group is selected in the sidebar, the tab is
# removed from the group.

# %% [markdown]
# # Shared with You: Links from others

# %% [markdown]
# The Shared with You entry in the sidebar automatically gathers content
# that’s been shared with you. Click Shared with You and an overview
# page appears with thumbnails of all the photos, videos, articles, and
# more that have been shared with you by friends and family in the
# Messages app.

# %% [markdown]
# # Bookmarking your favorite pages

# %% [markdown]
# When you find a webpage you want to return to, bookmark it like this:

# %% [markdown]
# 1. Choose Bookmarks ⇒ Add Bookmark, press ⌘ +D, or click the
# Share icon and choose Add Bookmark to open the Add
# Bookmark dialog.

# %% [markdown]
# 2. Choose where to store the bookmark from the pop-up menu.

# %% [markdown]
# By default, Safari puts new bookmarks in the Favorites folder. The
# Favorites folder can get full pretty quickly, so it’s best to organize
# your bookmarks into a folder structure that suits your browsing
# needs.

# %% [markdown]
# 3. Rename the bookmark or use the name provided by Safari.

# %% [markdown]
# 4. (Optional) Add a brief description in the Description field.

# %% [markdown]
# 5. Click the Add button to close the dialog and save the bookmark.

# %% [markdown]
# # Finding your bookmarks in the sidebar

# %% [markdown]
# To return to a bookmarked page, click it in the Favorites bar (if you
# saved it there), choose Bookmarks ⇒ Show Bookmarks, press ⌘
# +Option+B, or click the Show Sidebar icon and then click Bookmarks to
# see all your bookmarks.

# %% [markdown]
# Стр. 367
#
# ----------

# %% [markdown]
# If you add a bookmark to the Favorites folder, it automatically appears in
# the Favorites bar. If you add the bookmark outside the Favorites folder
# in the sidebar, it will not appear in the Favorites bar but will be available
# at the bottom of the Bookmarks menu and in the Bookmarks sidebar.

# %% [markdown]
# To open a bookmarked page, click it once in the sidebar. To view the
# contents of a folder, click the folder name in the list.

# %% [markdown]
# To delete a bookmark, Control-click or right-click it and choose Delete.

# %% [markdown]
# # Лампочка
#
# ⌘ +click a folder in the Bookmarks window or Favorites bar to
# simultaneously open all the bookmarks it contains.

# %% [markdown]
# # Managing your favorites and the Favorites bar

# %% [markdown]
# Below the Search or Enter Website Name field is the Favorites bar,
# which is populated by default with icons for webpages that Apple thinks
# you might enjoy, including Apple, Yahoo!, Google Maps, YouTube, and
# Wikipedia.

# %% [markdown]
# # Лампочка
#
# If you don’t see the Favorites bar, choose View ⇒ Show
# Favorites Bar or press ⌘ +Shift+B. If you want to access a ton of
# bookmarks from your Favorites bar, put folders of bookmarks
# rather than individual bookmarks on the Favorites bar. The
# Favorites bar displays the folders as drop-down menus, and you can
# quickly navigate down the menus to the bookmarks you want to
# display.

# %% [markdown]
# Favorites is a folder of bookmarks that appear in the Favorites bar and
# Favorites page. Not all bookmarks are favorites, but all favorites are
# bookmarks.

# %% [markdown]
# # Keeping your Reading List

# %% [markdown]
# Стр. 368
#
# ----------

# %% [markdown]
# # Keeping your Reading List

# %% [markdown]
# The Safari sidebar also contains your Reading List, which serves as a
# repository for pages or links you want to read sometime but not right
# now. A Reading List item is a lot like a bookmark but easier to create on
# the fly, which makes the Reading List perfect for pages or links you
# don’t need to keep forever (that’s what bookmarks are for).

# %% [markdown]
# To add the page you’re viewing to your Reading List, click the Share
# icon and choose Add to Reading List. Alternatively, press ⌘+Shift+D.

# %% [markdown]
# To add a link to your Reading List without visiting the page, Shift-click
# that link. You’ll see an animation of a round item flying up to the
# Show/Hide Sidebar icon. Alternatively, Control-click or right-click the
# link, and then choose Add Link to Reading List from the contextual
# menu.

# %% [markdown]
# Right-click any item in your Reading List for additional options, such as
# marking the item as read or saving the item offline so you can read it
# when your Mac has no Internet connection.

# %% [markdown]
# To delete an item from the Reading List, Control-click or right-click the
# item and then choose Remove Item. To remove all items from the
# Reading List, Control-click or right-click any item and then choose
# Clear All Items.

# %% [markdown]
# # Лампочка
#
# If you have other Macs or Apple devices that sync with the same
# iCloud account, you can sync your Reading List among your
# devices by enabling Safari in the iCloud pane in the System
# Settings app.
