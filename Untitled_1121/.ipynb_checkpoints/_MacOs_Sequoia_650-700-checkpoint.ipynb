# %%
import os;import math;import sys;import datetime;
var='\\MacOs_Sequoia.ipynb'
print (var,':',os.path.getsize(os.path.abspath(os.curdir)+var)/math.pow(2, 20),' мегобайт ',datetime.datetime.now())
# Out:
# \MacOs_Sequoia.ipynb : 10.123122215270996  мегобайт  2025-03-05 17:01:25.795079

# %% [markdown]
# http://localhost:8888/files/Kip_papers/Untitled_1121/_OceanofPDF.com_macOS_Sequoia_For_Dummies_-_Guy_Hart-Davis.pdf

# %% [markdown]
# - Mail app
#     - blocking senders, 299
#     - checking mail, 287–288
#     - composing new message, 281–284
#     - Contacts app and, 286–287
#     - Mail Drop, 298
#     - mailboxes
#         - plain mailboxes, 291–292
#         - smart mailboxes, 292–293
#     - marking up images and PDF documents, 297
#     - Mute button, 299
#     - overview, 277–278
#     - Quick Look, 297
#     - rules, 295–297
#     - setting up, 278–279
#     - Settings window, 293
#     - signature, 293–295
#     - spam, 288–290
#     - toolbar icons, 279–281
#     - transferring large files, 298
#     - Unsubscribe button, 299
#     - Writing Tools, 284–286

# %% [markdown]
# 651

# %% [markdown]
# - Mail Drop, 298
# - mailboxes, Mail app
#     - plain mailboxes, 291–292
#     - smart mailboxes, 292–293
# - malware, 412–414
# - Maps app
#     - Contacts app and, 217–218
#     - Current Location, 213–214
#     - custom routes, 223–224
#     - cycling directions, 223
#     - flyovers, 225–226
#     - guides, 219–220
#     - Library feature, 218–219
#     - location cards, 226
#     - look arounds, 226, 227
#     - panning maps, 217
#     - public transportation, 223
#     - real time traffic info, 224–225
#     - Recents list, 220
#     - route maps and driving directions, 221–223
#     - Search feature, 214–215
#     - viewing maps, 215–216
#     - walking directions, 223
#     - zooming maps, 216–217

# %% [markdown]
# 652

# %% [markdown]
# - Markup Quick Action, 95–98
# - media, 331–332. See also multimedia; Music app
# - Memory movies, 23
# - menu bar, 40
# - menus
#     - Apple menu tree, 43–44
#     - contextual menus, 40–41
#     - disabled commands, 41–42
#     - keyboard shortcuts, 43–44
#     - menu bar, 40
#     - overview, 16
#     - submenus, 42–43
# - Messages app
#     - iMessage, 299–300
#     - text chats, 300–303

# %% [markdown]
# - Migration Assistant, 450
# - minimizing windows, 29–31
# - Mission Control, 174–180
# - More Gestures tab, Trackpad pane, 121–122
# - Mouse pane, 118–120
# - multimedia
#     - Books app, 352–355
#     - Photo Booth app, 357–358
#     - Podcasts app, 355–357
#     - Preview, 359–360
#     - QuickTime Player, 349–351
#     - TV app, 351–352
# - Music App
#     - adding songs, 340–342
#     - overview, 337–340
#     - Playlists, 345–348
#     - Radio, 342–345
# - Mute button, Mail app, 299

# %% [markdown]
# 653

# %% [markdown]
# # N
# - nested folders, 129–130, 150–151
# - networking
#     - file sharing
#         - Ethernet, 306
#         - Ethernet port, 306
#         - local devices, 306
#         - network, 306
#         - protocols, 306
#         - remote devices, 306
#         - setting up, 310–313
#         - switches, 307
#     - home-office network, 307–310
# - News app
#     - File menu, 234
#     - Follow Your Favorites screen, 233
#     - View menu, 233–234

# %% [markdown]
# 655

# %% [markdown]
# - No Access permission, 322
# - nonvolatile RAM (NVRAM), 426–427
# - Notes app, 205–209
# - Notification Center
#     - customizing settings, 200–202
#     - Focus feature, 203–204
#     - widgets, 202–203
# # O
# - offsite backups, 411
# - opening files and folders
#     - with app, 145–147
#     - with drag-and-drop, 145
#     - overview, 143–144
#     - with Quick Look feature, 145
# - operating systems
#     - overview, 8–9
#     - version names and numbers, 8

# %% [markdown]
# - organizational apps
#     - Calendar app
#         - creating calendars, 191
#         - deleting calendars, 192–193
#         - events, 193–195
#         - lists, 191
#         - overview, 189
#         - sharing and publishing calendars, 192
#         - views, 190
#     - Notes app, 205–209
#     - Notification Center
#         - customizing settings, 200–202
#         - Focus feature, 203–204
#         - widgets, 202–203
#     - Quick Note, 209
#     - Reminders app
#         - assigning reminders, 200
#         - creating and managing reminders, 198–199
#         - lists, 197–198
#         - overview, 196–197
#     - Screen Time, 209–211
# - Output & Input section, Sound pane, 123–124

# %% [markdown]
# 656

# %% [markdown]
# # P
# - panning maps, 217
# - parameter RAM (PRAM), 426–427
# - partitioning, 445
# - passkeys, Safari, 265–266
# - passwords, 327–329, 418–419
# - Passwords app, 448–450
# - pasting, Clipboard, 166
# - PDF files
#     - Create PDF Quick Action, 99–100
#     - marking
#     - viewing and converting in Preview, 359–360
# - permissions. See access and permissions
# - Photo Booth app, 357–358
# - plain mailboxes, Mail app, 291–292
# - Playlists
#     - Genius playlists, 348
#     - regular playlists, 345–346
#     - smart playlists, 347

# %% [markdown]
# 657

# %% [markdown]
# - Podcasts app, 355–357
# - Point & Click tab, Trackpad pane, 120–121
# - pointing, 16
# - PRAM (parameter RAM), 426–427
# - Preview feature, 359–360
# - printers and printing
#     - connecting printer to Mac, 365–366
#     - Page Setup, 372–373
#     - pre-printer prep, 365
#     - Preview app, 373–374
#     - Print dialogs, 374
#     - printer drivers, 370–371
#     - setting up printer, 366–370
#     - sharing printer, 331, 371
# - Privacy & Security pane, 419–420
# - Profiles feature, Safari, 260–264
# - prohibitory signs and messages, 422–423
# - Public folder, 318–319
# - public transportation directions, Maps app, 223

# %% [markdown]
# # Q
# - Quick Actions
#     - Create PDF Quick Action, 99–100
#     - Markup, 95–98
#     - Rotate, 95–96
#     - Trim, 98–100
# - Quick Look feature
#     - Mail app, 297
#     - opening files and folders with, 145
#     - overview, 167–168
#     - Share menu, 169
#     - Slideshow mode, 169–170
# - Quick Note, 209
# - QuickTime Player, 349–351

# %% [markdown]
# 658

# %% [markdown]
# # R
# - Radio
#     - Column Browser, 343–345
#     - Column Browser, 343–345
#     - overview, 342–343
# - RAM, 426–427, 437–438
# - Read & Write permission, 322
# - Read Only permission, 322
# - Reader view, Safari, 259
# - Reading List, Safari, 258
# - real time traffic info, Maps app, 224–225
# - Recents list, Maps app, 220
# - Recovery mode, 424
# - reinstalling macOS, 427

# %% [markdown]
# - Reminders app
#     - assigning reminders, 200
#     - creating and managing reminders, 198–199
#     - lists, 197–198
#     - overview, 196–197
# - remote access, 324–327
# - resizing windows, 37
# - resolution, display, 436–437
# - reverse scrolling, 119
# - right-click, 17
# - Rotate Counter-Clockwise tool, 97
# - Rotate Quick Action, 95–96
# - route maps, Maps app, 221–223
# - rules, Mail app, 295–297

# %% [markdown]
# 659

# %% [markdown]
# # S
# - Safari
#     - audio and video playback, 265
#     - Hide Distracting Items feature, 260
#     - Highlights feature, 260
#     - overview, 253–254
#     - passkeys, 265–266
#     - Profiles feature, 260–264
#     - sidebar
#         - bookmarks, 257
#         - Favorites bar, 257–258
#         - Reader view, 259
#         - Reading List, 258
#         - Shared with You feature, 256
#         - tab groups, 255–256
#         - website-specific settings, 258–259
#     - toolbar, 254–255
#     - web apps, 264–265

# %% [markdown]
# - saving files and folders
#     - Auto Save feature, 136–137
#     - basic save, 137–141
#     - Duplicate, 141–142
#     - Save As, 141–142
#     - Versions feature, 137, 139–143
# - scanners, 331
# - Screen Capture, 100–102
# - screen saver, 108–110
# - Screen Sharing, 329–330
# - Screen Time, 209–211
# - Scroll & Zoom tab, Trackpad pane, 121
# - scrolling, 31–33, 119
# - Search feature, Maps app, 214–215
# - secondary click, 17

# %% [markdown]
# 661

# %% [markdown]
# - security
#     - automatic updates, 414–415
#     - backing up data, 406
#         - brute-force method, 410
#         - commercial backup software, 410–411
#         - offsite backups, 411
#         - Time Machine, 406–409
#     - disabling sharing, 416
#     - FileVault, 416–417
#     - Lockdown mode, 417–418
#     - malware, 412–414
#     - passwords, 418–419
#     - Privacy & Security pane, 419–420
#     - viruses, 412–414

# %% [markdown]
# 662

# %% [markdown]
# - setting up Sequoia, 10–12
# - Settings window, Mail app, 293
# - Shape Style tool, 97
# - Shapes tool, 96–97
# - Shared with You feature, Safari, 256
# - sharing Mac
#     - access and permissions
#         - applying settings for, 322–324
#         - shared folders, 318–322
#         - users, 313–318
#     - Internet connection, 330–331
#     - media, 331–332
#     - networking, 306–310
#     - printers and scanners, 331
#     - remote access, 324–327
#     - resetting account passwords, 327–329
#     - Screen Sharing, 329–330
#     - security and, 416
#     - unsharing folders, 324
#     - via Bluetooth, 332

# %% [markdown]
# 663

# %% [markdown]
# - shortcut menus, 40–41
# - Shortcuts app, 238–239
# - shuffling windows, 37–39
# - Shut Down commands, 44
# - shutting down Mac, 18–19
# - sidebar
#     - Finder, 85
#     - Safari
#         - bookmarks, 257
#         - Favorites bar, 257–258
#         - Reader view, 259
#         - Reading List, 258
#         - Shared with You feature, 256
#         - tab groups, 255–256
#         - website-specific settings, 258–259

# %% [markdown]
# - Sign tool, 97
# - signature, Mail app, 293–295
# - Siri, 23, 160–163
# - Siri menu, 16
# - Sketch tool, 96
# - smart folders, 153–154
# - smart lists, Contacts app, 272–273
# - smart mailboxes, Mail app, 292–293
# - smart playlists, 347
# - Solid-State Drive (SSD), 439
# - Sort By command, Finder views, 76
# - Sound Effects section, Sound pane, 122–123
# - Sound pane
#     - Output & Input section, 123–124
#     - Sound Effects section, 122–123

# %% [markdown]
# 664

# %% [markdown]
# - spam, Mail app, 288–290
# - splitting windows, 29–31
# - Spoken Content feature, 389–390
# - Spotlight, 170–174
# - spring-loaded folders, 152–153
# - SSD (Solid-State Drive), 439
# - Stacks, 89–92
# - Stage Manager, 180–186
# - start-up crashes, 428
# - start-up crashes, 428
# - start-up screen, 9–10
# - Stickies applet, 452–453
# - Stocks app
#     - adding and removing stocks, funds, and indexes, 231
#     - charts, 232
#     - details view, 231
#     - overview, 230–231

# %% [markdown]
# 665

# %% [markdown]
# - storage, 429–430, 440
# - subfolders, 129–130, 150–151
# - submenus, 42–43
# - Summarize content feature, Apple Intelligence, 23
# - System folder, 133
# - System Information, 450–451
# - System Settings
#     - Appearance pane, 111–112
#     - Desktop & Dock pane, 112–114
#     - Keyboard pane, 114–116
#     - Keyboard Shortcuts dialog, 116–118
#     - Lock Screen pane, 110
#     - Mouse pane, 118–120
#     - overview, 103–105
#     - screen saver, 108–110
#     - Sound pane, 122–124
#     - Trackpad pane, 120–122
#     - wallpaper, 106–108

# %% [markdown]
# 666

# %% [markdown]
# # T
# - Tags pane, Finder, 84–85
# - tech-support hotline, 427
# - Terminal app, 451
# - text chats, 300–303
# - Text Replacement feature, 436
# - Text Style tool, 97
# - Text to Speech feature, 389–390
# - Text tool, 97
# - Thunderbolt, 440
# - Time Machine, 406–409
# - time saving tools
#     - Clipboard
#         - copying, 164–166
#         - overview, 163–164
#         - pasting
#         - Universal Clipboard, 166–167
#     - Control Center, 186–187
#     - Launchpad, 187–188
#     - Mission Control, 174–180
#     - overview, 159
#     - Quick Look, 167–170
#     - Siri, 160–163
#     - Spotlight, 170–174
#     - Stage Manager, 180–186

# %% [markdown]
# 667

# %% [markdown]
# - toolbar
#     - Finder, 64–66
#     - Safari, 254–255
# - Trackpad pane
#     - More Gestures tab, 121–122
#     - Point & Click tab, 120–121
#     - Scroll & Zoom tab, 121
# - Trash, 48–50
# - Trim Quick Action, 98–99
# - troubleshooting
#     - booting in Safe mode, 425–426
#     - First Aid feature, 423–425
#     - nonvolatile RAM, 426–427
#     - parameter RAM, 426–427
#     - prohibitory signs and messages, 422–423
#     - reinstalling macOS, 427
#     - start-up crashes, 428
#     - start-up disks, 422
#     - Storage feature, 429–430
#     - tech-support hotline, 427
# - TV app, 351–352
# - typing skills, 435

# %% [markdown]
# # U
# - Universal Clipboard, 166–167
# - Universal Control feature
#     - connecting iPad or Mac, 400–402
#     - disconnecting iPad or Mac, 402–403
#     - display options, 402
#     - enabling and configuring, 399–400
# - unmounted disks, 448
# - unsharing folders, 324
# - Unsubscribe button, Mail app, 299
# - USB device, 440
# - Use Groups command, Finder views, 76

# %% [markdown]
# 668

# %% [markdown]
# # V
# - Versions feature, 137, 139–143
# - View menu, News app, 233–234
# - viewing maps, 215–216
# - views
#     - Calendar app, 190
#     - Finder
#         - Clean Up By command, 76–77
#         - Clean Up command, 76
#         - Column view, 71–72
#         - Gallery view, 75
#         - Icon view, 72–73
#         - List view, 73–75
#         - Sort By command, 76
#         - Use Groups command, 76
# - viruses, 412–414
# - Voice Control feature, 386–388
# - Voice Memos app
#     - listening to voice memos, 235–236
#     - naming voice memos, 236
#     - recording voice memos, 235
#     - transcribing voice memos, 236
#     - trimming voice memos, 236–237
# - VoiceOver feature, 388–389

# %% [markdown]
# 669

# %% [markdown]
# # W
# - walking directions, Maps app, 223
# - wallpaper, 15, 106–108
# - web apps, Safari, 264–265
# - website-specific settings, Safari, 258–259
# - website-specific settings, Safari, 258–259
#     - adding to desktop, 93
#     - customizing, 94
#     - defined, 92
#     - Notification Center, 202–203
# - Widgets section, Desktop & Dock pane, 113
# - Wi-Fi connection, 245–251
# - wiggling/jiggling, 17
# - windows, 15
# - Windows section, Desktop & Dock pane, 113–114
# - Write Only permission, 322
# - Writing Tools, Mail app, 284–286

# %% [markdown]
# # Z
# - zapping, PRAM/NVRAM, 427
# - zooming
#     - maps, 216–217
#     - windows, 29–31
# # About the Author
# Guy Hart-Davis is the author of more than 180 computer books,
# including Teach Yourself VISUALLY iPhone 16; iPhone For Dummies,
# 2025 Edition; Teach Yourself VISUALLY MacBook Pro and MacBook
# Air; Killer ChatGPT Prompts: Harness the Power of AI for Success and
# Profit; macOS Sonoma For Dummies; Teach Yourself VISUALLY
# HTML and CSS, 2nd Edition; Teach Yourself VISUALLY Google
# Workspace; Teach Yourself VISUALLY Chromebook; Teach Yourself
# VISUALLY Word 2019; Teach Yourself VISUALLY iPad; and Teach
# Yourself VISUALLY Android Phones and Tablets, 2nd Edition.

# %% [markdown]
# 671

# %% [markdown]
# # Author’s Acknowledgments
# Many thanks to Steve Hayes for asking me to write this book, Hanna
# Sytsma for handling the administration, Lynn Northrup for editing the
# book skillfully, Doug Holland for reviewing the contents for technical
# accuracy and contributing helpful suggestions, Evelyn Wellborn for
# proofreading the pages closely.
# - Publisher’s Acknowledgments
# - Executive Editor: Steven Hayes
# - Senior Editorial Assistant: Hanna Sytsma
# - Project Editor: Lynn Northrup
# - Copy Editor: Lynn Northrup
# - Technical Editor: Doug Holland
# - Production Editor: Tamilmani Varadharaj
# - Cover Image: © Gerald Corsi/Getty Images

# %% [markdown]
# 673

# %% [markdown]
# ![image.png](attachment:image.png)
